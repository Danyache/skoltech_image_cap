# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"
# os.environ["CUDA_LAUNCH_BLOCKING"]="1"
import torch
import torch.nn.functional as F
import numpy as np
import json
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import skimage.transform
import argparse
from scipy.misc import imread, imresize
from PIL import Image
import pandas as pd

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from score import evalscores

# %%
import json

# %%
all_reports_df = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_tags_df.pkl')

# %%
all_reports_df.head(2)
# Out:
#                  images                                           FINDINGS  \
# 0  CXR2357_IM-0921-1001  Cardiomediastinal silhouette and pulmonary vas...
# 1  CXR2357_IM-0921-2001  Cardiomediastinal silhouette and pulmonary vas...
#
#                            IMPRESSION tags_major tags_automatic  \
# 0  No acute cardiopulmonary findings.   [normal]             []
# 1  No acute cardiopulmonary findings.   [normal]             []
#
#                                report  \
# 0  ./reports/ecgen-radiology/2357.xml
# 1  ./reports/ecgen-radiology/2357.xml
#
#                                          full_report  \
# 0  No acute cardiopulmonary findings. Cardiomedia...
# 1  No acute cardiopulmonary findings. Cardiomedia...
#
#                                   processed_captions  \
# 0  [no acute cardiopulmonary findings, cardiomedi...
# 1  [no acute cardiopulmonary findings, cardiomedi...
#
#                                   processed_findings  \
# 0  [cardiomediastinal silhouette and pulmonary va...
# 1  [cardiomediastinal silhouette and pulmonary va...
#
#                             preprocessed_full_report
# 0  no acute cardiopulmonary findings . cardiomedi...
# 1  no acute cardiopulmonary findings . cardiomedi...

# %%
def caption_image_beam_search(encoder, decoder, image_path, word_map, beam_size=3):
    """
    Reads an image and captions it with beam search.

    :param encoder: encoder model
    :param decoder: decoder model
    :param image_path: path to image
    :param word_map: word map
    :param beam_size: number of sequences to consider at each decode-step
    :return: caption, weights for visualization
    """

    k = beam_size
    vocab_size = len(word_map)

    # Read image and process
    img = imread(image_path)
    if len(img.shape) == 2:
        img = img[:, :, np.newaxis]
        img = np.concatenate([img, img, img], axis=2)
    img = imresize(img, (256, 256))
    img = img.transpose(2, 0, 1)
    img = img / 255.
    img = torch.FloatTensor(img).to(device)
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    transform = transforms.Compose([normalize])
    image = transform(img)  # (3, 256, 256)

    # Encode
    image = image.unsqueeze(0)  # (1, 3, 256, 256)
    encoder_out = encoder(image)  # (1, enc_image_size, enc_image_size, encoder_dim)
    enc_image_size = encoder_out.size(1)
    encoder_dim = encoder_out.size(3)

    # Flatten encoding
    encoder_out = encoder_out.view(1, -1, encoder_dim)  # (1, num_pixels, encoder_dim)
    num_pixels = encoder_out.size(1)

    # We'll treat the problem as having a batch size of k
    encoder_out = encoder_out.expand(k, num_pixels, encoder_dim)  # (k, num_pixels, encoder_dim)

    # Tensor to store top k previous words at each step; now they're just <start>
    k_prev_words = torch.LongTensor([[word_map['<start>']]] * k).to(device)  # (k, 1)

    # Tensor to store top k sequences; now they're just <start>
    seqs = k_prev_words  # (k, 1)

    # Tensor to store top k sequences' scores; now they're just 0
    top_k_scores = torch.zeros(k, 1).to(device)  # (k, 1)

    # Tensor to store top k sequences' alphas; now they're just 1s
    seqs_alpha = torch.ones(k, 1, enc_image_size, enc_image_size).to(device)  # (k, 1, enc_image_size, enc_image_size)

    # Lists to store completed sequences, their alphas and scores
    complete_seqs = list()
    complete_seqs_alpha = list()
    complete_seqs_scores = list()

    # Start decoding
    step = 1
    h, c = decoder.init_hidden_state(encoder_out)

    # s is a number less than or equal to k, because sequences are removed from this process once they hit <end>
    while True:

        embeddings = decoder.embedding(k_prev_words).squeeze(1)  # (s, embed_dim)

        awe, alpha = decoder.attention(encoder_out, h)  # (s, encoder_dim), (s, num_pixels)

        alpha = alpha.view(-1, enc_image_size, enc_image_size)  # (s, enc_image_size, enc_image_size)

        gate = decoder.sigmoid(decoder.f_beta(h))  # gating scalar, (s, encoder_dim)
        awe = gate * awe

        h, c = decoder.decode_step(torch.cat([embeddings, awe], dim=1), (h, c))  # (s, decoder_dim)

        scores = decoder.fc(h)  # (s, vocab_size)
        scores = F.log_softmax(scores, dim=1)

        # Add
        scores = top_k_scores.expand_as(scores) + scores

        # For the first step, all k points will have the same scores (since same k previous words, h, c)
        if step == 1:
            top_k_scores, top_k_words = scores[0].topk(k, 0, True, True)  # (s)
        else:
            # Unroll and find top scores, and their unrolled indices
            top_k_scores, top_k_words = scores.view(-1).topk(k, 0, True, True)  # (s)

        # Convert unrolled indices to actual indices of scores
        prev_word_inds = top_k_words / vocab_size  # (s)
        next_word_inds = top_k_words % vocab_size  # (s)

        # Add new words to sequences, alphas
        seqs = torch.cat([seqs[prev_word_inds], next_word_inds.unsqueeze(1)], dim=1)  # (s, step+1)
        seqs_alpha = torch.cat([seqs_alpha[prev_word_inds], alpha[prev_word_inds].unsqueeze(1)],
                               dim=1)  # (s, step+1, enc_image_size, enc_image_size)

        # Which sequences are incomplete (didn't reach <end>)?
        incomplete_inds = [ind for ind, next_word in enumerate(next_word_inds) if
                           next_word != word_map['<end>']]
        complete_inds = list(set(range(len(next_word_inds))) - set(incomplete_inds))

        # Set aside complete sequences
        if len(complete_inds) > 0:
            complete_seqs.extend(seqs[complete_inds].tolist())
            complete_seqs_alpha.extend(seqs_alpha[complete_inds].tolist())
            complete_seqs_scores.extend(top_k_scores[complete_inds])
        k -= len(complete_inds)  # reduce beam length accordingly

        # Proceed with incomplete sequences
        if k == 0:
            break
        seqs = seqs[incomplete_inds]
        seqs_alpha = seqs_alpha[incomplete_inds]
        h = h[prev_word_inds[incomplete_inds]]
        c = c[prev_word_inds[incomplete_inds]]
        encoder_out = encoder_out[prev_word_inds[incomplete_inds]]
        top_k_scores = top_k_scores[incomplete_inds].unsqueeze(1)
        k_prev_words = next_word_inds[incomplete_inds].unsqueeze(1)
        
        # Break if things have been going on too long
        if step > 50:
            break
        step += 1

    i = complete_seqs_scores.index(max(complete_seqs_scores))
    seq = complete_seqs[i]
    alphas = complete_seqs_alpha[i]

    return seq, alphas

# %%
def visualize_att(image_path, seq, alphas, rev_word_map, smooth=True, visualize=True):
    """
    Visualizes caption with weights at every word.

    Adapted from paper authors' repo: https://github.com/kelvinxu/arctic-captions/blob/master/alpha_visualization.ipynb

    :param image_path: path to image that has been captioned
    :param seq: caption
    :param alphas: weights
    :param rev_word_map: reverse word mapping, i.e. ix2word
    :param smooth: smooth weights?
    """
    image = Image.open(image_path)
    image = image.resize([14 * 24, 14 * 24], Image.LANCZOS)

    words = [rev_word_map[ind] for ind in seq]
    
    if visualize:
        for t in range(len(words)):
            if t > 50:
                break
            plt.subplot(np.ceil(len(words) / 5.), 5, t + 1)

            plt.text(0, 1, '%s' % (words[t]), color='black', backgroundcolor='white', fontsize=12)
            plt.imshow(image)
            current_alpha = alphas[t, :]
            if smooth:
                alpha = skimage.transform.pyramid_expand(current_alpha.numpy(), upscale=24, sigma=8)
            else:
                alpha = skimage.transform.resize(current_alpha.numpy(), [14 * 24, 14 * 24])
            if t == 0:
                plt.imshow(alpha, alpha=0)
            else:
                plt.imshow(alpha, alpha=0.8)
            plt.set_cmap(cm.Greys_r)
            plt.axis('off')
        plt.show()
    
    return words

# %%
parser = argparse.ArgumentParser(description='Show, Attend, and Tell - Tutorial - Generate Caption')

parser.add_argument('--img', '-i', default='/home/dchesakov/NLMCXR_data/myface.jpg', help='path to image')
parser.add_argument('--model', '-m', default='BEST_checkpoint_NLMCXR_v9_1_cap_per_img_6_min_word_freq.pth.tar', help='path to model')
parser.add_argument('--word_map', '-wm', default='/home/dchesakov/NLMCXR_data/WORDMAP_NLMCXR_v9_1_cap_per_img_6_min_word_freq.json',  help='path to word map JSON')
parser.add_argument('--beam_size', '-b', default=5, type=int, help='beam size for beam search')
parser.add_argument('--dont_smooth', dest='smooth', action='store_false', help='do not smooth alpha overlay')
# Out:
# _StoreFalseAction(option_strings=['--dont_smooth'], dest='smooth', nargs=0, const=False, default=True, type=None, choices=None, help='do not smooth alpha overlay', metavar=None)

# %%
'CXR3275_IM-1556-1003002'
# Out:
# 'CXR3275_IM-1556-1003002'

# %%
# Load model
args = parser.parse_args('')

# %%
checkpoint = torch.load(args.model)
decoder = checkpoint['decoder']
decoder = decoder.to(device)
decoder.eval()
encoder = checkpoint['encoder']
encoder = encoder.to(device)
encoder.eval()

# Load word map (word2ix)
with open(args.word_map, 'r') as j:
    word_map = json.load(j)
rev_word_map = {v: k for k, v in word_map.items()}  # ix2word

# Encode, decode with attention and beam search
# seq, alphas = caption_image_beam_search(encoder, decoder, args.img, word_map, args.beam_size)
# alphas = torch.FloatTensor(alphas)

# # Visualize caption and attention of best sequence
# visualize_att(args.img, seq, alphas, rev_word_map, args.smooth)
# Out:
# /home/dchesakov/.local/lib/python3.7/site-packages/torch/serialization.py:453: SourceChangeWarning: source code of class 'models.DecoderWithAttention' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
word_map
# Out:
# {'ankle': 1,
#  'expanded': 2,
#  'overload': 3,
#  'innominate': 4,
#  'evaluate': 5,
#  'chronic': 6,
#  'enlarged': 7,
#  'moderately': 8,
#  'dextro': 9,
#  'very': 10,
#  'concerning': 11,
#  'primary': 12,
#  'crowding': 13,
#  'characterization': 14,
#  'overlie': 15,
#  'previous': 16,
#  'fragment': 17,
#  'inflammatory': 18,
#  'calcification': 19,
#  'overt': 20,
#  'diaphragm': 21,
#  'clearing': 22,
#  'an': 23,
#  'mastectomy': 24,
#  'blunted': 25,
#  'anterior': 26,
#  'vascular': 27,
#  'film': 28,
#  'wedge': 29,
#  'severe': 30,
#  'humerus': 31,
#  'granulomatous': 32,
#  'sulci': 33,
#  '-': 34,
#  'superior': 35,
#  'atherosclerotic': 36,
#  'joint': 37,
#  'closure': 38,
#  'followup': 39,
#  'subtle': 40,
#  'middle': 41,
#  'traumatic': 42,
#  'humeral': 43,
#  'marked': 44,
#  'portions': 45,
#  'overall': 46,
#  'crowded': 47,
#  'tubing': 48,
#  'minimally': 49,
#  'airways': 50,
#  'improved': 51,
#  'healing': 52,
#  'spurring': 53,
#  'bilateral': 54,
#  'graft': 55,
#  'therapy': 56,
#  'fixation': 57,
#  'demineralization': 58,
#  'side': 59,
#  'displaced': 60,
#  'evident': 61,
#  'width': 62,
#  'demonstrates': 63,
#  'consistent': 64,
#  'bowel': 65,
#  'incidentally': 66,
#  'reveal': 67,
#  'greater': 68,
#  'differential': 69,
#  'procedure': 70,
#  'both': 71,
#  'prominent': 72,
#  'metastatic': 73,
#  'been': 74,
#  'jugular': 75,
#  'surgery': 76,
#  'axillary': 77,
#  'no': 78,
#  'senescent': 79,
#  'tuberculous': 80,
#  'defibrillator': 81,
#  'suggestion': 82,
#  'if': 83,
#  'projectile': 84,
#  'bronchitis': 85,
#  'bullet': 86,
#  ',': 87,
#  'be': 88,
#  'bullae': 89,
#  'adjacent': 90,
#  'terminating': 91,
#  'exams': 92,
#  'trapping': 93,
#  'dish': 94,
#  'some': 95,
#  'remarkable': 96,
#  'greatest': 97,
#  'history': 98,
#  'pelvis': 99,
#  'diminished': 100,
#  'discrete': 101,
#  'collapse': 102,
#  'represents': 103,
#  '3': 104,
#  'unclear': 105,
#  'notification': 106,
#  'obstruction': 107,
#  'unchanged': 108,
#  'background': 109,
#  'kub': 110,
#  'endotracheal': 111,
#  'large': 112,
#  'including': 113,
#  'courses': 114,
#  'now': 115,
#  '10th': 116,
#  'bodies': 117,
#  'see': 118,
#  'dated': 119,
#  'based': 120,
#  't1': 121,
#  'zones': 122,
#  'please': 123,
#  'complete': 124,
#  'age': 125,
#  'within': 126,
#  'notified': 127,
#  'tissue': 128,
#  'nodule': 129,
#  'spine': 130,
#  'demonstrated': 131,
#  'volume': 132,
#  'stomach': 133,
#  'level': 134,
#  'above': 135,
#  'technical': 136,
#  'considerations': 137,
#  'subcutaneous': 138,
#  'atherosclerosis': 139,
#  'there': 140,
#  'atrial': 141,
#  'bases': 142,
#  'displacement': 143,
#  'evaluated': 144,
#  'not': 145,
#  'projects': 146,
#  'deformities': 147,
#  'broken': 148,
#  'right-sided': 149,
#  'obscuration': 150,
#  'suspicious': 151,
#  'evaluation': 152,
#  'removal': 153,
#  'posterolateral': 154,
#  'calcifications': 155,
#  'one': 156,
#  '(': 157,
#  'loops': 158,
#  'replacement': 159,
#  'obstructive': 160,
#  'additional': 161,
#  'benign': 162,
#  'junction': 163,
#  'inflammation': 164,
#  '7th': 165,
#  'renal': 166,
#  'cleared': 167,
#  'femur': 168,
#  'shows': 169,
#  'apical': 170,
#  'residuals': 171,
#  '10': 172,
#  'soft': 173,
#  'inferiorly': 174,
#  'lines': 175,
#  'appreciated': 176,
#  'confirm': 177,
#  'exposure': 178,
#  'maintained': 179,
#  'causing': 180,
#  'suggesting': 181,
#  'lobar': 182,
#  'stimulator': 183,
#  'portion': 184,
#  'remote': 185,
#  'picc': 186,
#  'endplate': 187,
#  'supine': 188,
#  'high': 189,
#  'sutures': 190,
#  'apices': 191,
#  'between': 192,
#  'aortic': 193,
#  'corresponding': 194,
#  'anticipated': 195,
#  'represent': 196,
#  'decrease': 197,
#  'a': 198,
#  'region': 199,
#  'notable': 200,
#  'scars': 201,
#  'presence': 202,
#  'loss': 203,
#  'vasculature': 204,
#  'arthritis': 205,
#  'pleura': 206,
#  'flattening': 207,
#  'again': 208,
#  'considering': 209,
#  'ill-defined': 210,
#  'incidental': 211,
#  'rounded': 212,
#  'clavicle': 213,
#  'alternatively': 214,
#  'pathologic': 215,
#  'pulmonary': 216,
#  'external': 217,
#  'cavity': 218,
#  'posttraumatic': 219,
#  'overlapping': 220,
#  'deviation': 221,
#  'acute': 222,
#  'markedly': 223,
#  '6': 224,
#  'bullous': 225,
#  'tissues': 226,
#  'characteristic': 227,
#  'placed': 228,
#  ']': 229,
#  'malignancy': 230,
#  'scan': 231,
#  'interval': 232,
#  'clips': 233,
#  'fibrosis': 234,
#  'localized': 235,
#  'opacity': 236,
#  'fluid': 237,
#  'recommend': 238,
#  'tubes': 239,
#  'any': 240,
#  'abnormalities': 241,
#  'rotated': 242,
#  'fractured': 243,
#  'elevated': 244,
#  'space': 245,
#  'significantly': 246,
#  'clear': 247,
#  'bypass': 248,
#  'old': 249,
#  'cervical': 250,
#  '7': 251,
#  'thoracotomy': 252,
#  'throughout': 253,
#  'otherwise': 254,
#  'tumor': 255,
#  'widened': 256,
#  'exaggeration': 257,
#  'appropriate': 258,
#  'layering': 259,
#  'ventricle': 260,
#  'another': 261,
#  'line': 262,
#  'rib': 263,
#  'following': 264,
#  'particularly': 265,
#  'nodular': 266,
#  'scar': 267,
#  'nipple': 268,
#  'spinal': 269,
#  'clinical': 270,
#  'colon': 271,
#  'retraction': 272,
#  'correlation': 273,
#  'edema': 274,
#  'cardiopulmonary': 275,
#  'suspected': 276,
#  'discussed': 277,
#  'view': 278,
#  'improvement': 279,
#  'parenchyma': 280,
#  'hiatal': 281,
#  'fusion': 282,
#  'dr': 283,
#  'which': 284,
#  'arthritic': 285,
#  'neck': 286,
#  'pa': 287,
#  'thoracic': 288,
#  'descending': 289,
#  'question': 290,
#  'change': 291,
#  'absence': 292,
#  'process': 293,
#  'finding': 294,
#  'hernia': 295,
#  'suggested': 296,
#  'patient': 297,
#  'desired': 298,
#  'rightward': 299,
#  'collection': 300,
#  'remain': 301,
#  'joints': 302,
#  'positioning': 303,
#  'for': 304,
#  'thickening': 305,
#  'emphysema': 306,
#  '>': 307,
#  'hilum': 308,
#  'study': 309,
#  'lesions': 310,
#  'irregularity': 311,
#  'positional': 312,
#  'numerous': 313,
#  'of': 314,
#  'overlies': 315,
#  'apex': 316,
#  'inlet': 317,
#  'material': 318,
#  'vertebral': 319,
#  'habitus': 320,
#  'prosthesis': 321,
#  'postoperative': 322,
#  'in': 323,
#  'may': 324,
#  'levels': 325,
#  'fracture': 326,
#  'intraperitoneal': 327,
#  'peripheral': 328,
#  'lower': 329,
#  'consolidations': 330,
#  'approximately': 331,
#  'prior': 332,
#  'obvious': 333,
#  'mediastinal': 334,
#  'exam': 335,
#  'progression': 336,
#  'wall': 337,
#  'markers': 338,
#  'osteoarthritis': 339,
#  'include': 340,
#  'tube': 341,
#  'can': 342,
#  'hilar': 343,
#  'preoperative': 344,
#  'setting': 345,
#  'exaggerated': 346,
#  'partial': 347,
#  'artifact': 348,
#  'favored': 349,
#  'vein': 350,
#  'osseous': 351,
#  'mild': 352,
#  'relative': 353,
#  'exclude': 354,
#  'pads': 355,
#  'most': 356,
#  'identified': 357,
#  '4': 358,
#  'silhouettes': 359,
#  'tunneled': 360,
#  'pacemaker': 361,
#  'the': 362,
#  '9th': 363,
#  'under': 364,
#  'collections': 365,
#  'scapular': 366,
#  'tuberculosis': 367,
#  'irregular': 368,
#  't5': 369,
#  'examinations': 370,
#  'pneumonitis': 371,
#  'multifocal': 372,
#  'low': 373,
#  'svc': 374,
#  'widening': 375,
#  'addition': 376,
#  'total': 377,
#  'node': 378,
#  'splenic': 379,
#  'scattered': 380,
#  'infiltrate': 381,
#  'configuration': 382,
#  'disease': 383,
#  'by': 384,
#  'lungs': 385,
#  'subluxation': 386,
#  'residual': 387,
#  '1': 388,
#  'medial': 389,
#  'postsurgical': 390,
#  'accentuated': 391,
#  'borderline': 392,
#  'round': 393,
#  'relatively': 394,
#  'caliber': 395,
#  'unfolded': 396,
#  'dedicated': 397,
#  'cardio': 398,
#  'diaphragms': 399,
#  'changes': 400,
#  'sulcus': 401,
#  'coronary': 402,
#  'characterized': 403,
#  'inflated': 404,
#  'shoulder': 405,
#  'm': 406,
#  'are': 407,
#  'sclerotic': 408,
#  'differences': 409,
#  'leads': 410,
#  'parenchymal': 411,
#  't10': 412,
#  'would': 413,
#  'hours': 414,
#  'slight': 415,
#  'indeterminate': 416,
#  'scoliosis': 417,
#  'engorgement': 418,
#  'comparisons': 419,
#  'technique': 420,
#  'alveolar': 421,
#  'interstitial': 422,
#  'smaller': 423,
#  'results': 424,
#  'abdominal': 425,
#  'calcified': 426,
#  'breast': 427,
#  'destructive': 428,
#  'elevation': 429,
#  'prosthetic': 430,
#  'arterial': 431,
#  'critical': 432,
#  'consider': 433,
#  'views': 434,
#  'dissection': 435,
#  'without': 436,
#  'stable': 437,
#  'hyperinflation': 438,
#  'lumbar': 439,
#  'two': 440,
#  'narrowing': 441,
#  'attenuation': 442,
#  'definite': 443,
#  't6': 444,
#  'performed': 445,
#  'trachea': 446,
#  'lung': 447,
#  '.': 448,
#  'artifactual': 449,
#  'cannot': 450,
#  'these': 451,
#  'moderate': 452,
#  'elements': 453,
#  'mitral': 454,
#  'stability': 455,
#  'extremity': 456,
#  'recommended': 457,
#  'status': 458,
#  'femoral': 459,
#  'right': 460,
#  'upper': 461,
#  'streaky': 462,
#  'motion': 463,
#  'measuring': 464,
#  'limits': 465,
#  'increased': 466,
#  'irregularities': 467,
#  'deformity': 468,
#  'diffusely': 469,
#  'oblique': 470,
#  'indicated': 471,
#  'ap': 472,
#  'suspicion': 473,
#  'convexity': 474,
#  'underlying': 475,
#  'pathology': 476,
#  '0': 477,
#  'sarcoidosis': 478,
#  'neoplasm': 479,
#  'larger': 480,
#  'due': 481,
#  'at': 482,
#  'decreasing': 483,
#  'oriented': 484,
#  'more': 485,
#  '2': 486,
#  'reveals': 487,
#  'convincing': 488,
#  'abnormal': 489,
#  'bronchi': 490,
#  'infiltrates': 491,
#  'minimal': 492,
#  'contour': 493,
#  'compatible': 494,
#  'abnormality': 495,
#  'foreign': 496,
#  'possibly': 497,
#  'findings': 498,
#  'extensive': 499,
#  'clinically': 500,
#  'unremarkable': 501,
#  'and': 502,
#  'lymph': 503,
#  'left-sided': 504,
#  'representing': 505,
#  'continued': 506,
#  'blunting': 507,
#  'consolidating': 508,
#  'partially': 509,
#  'suggest': 510,
#  'few': 511,
#  'increasing': 512,
#  'mediastinum': 513,
#  'xxxx': 514,
#  'helpful': 515,
#  'terminates': 516,
#  'incompletely': 517,
#  'receipt': 518,
#  'sized': 519,
#  'cm': 520,
#  'either': 521,
#  'to': 522,
#  'distal': 523,
#  'visible': 524,
#  'stool': 525,
#  'consolidation': 526,
#  'compartment': 527,
#  'other': 528,
#  'cortical': 529,
#  'intravenous': 530,
#  'atrium': 531,
#  'tip': 532,
#  'versus': 533,
#  'were': 534,
#  'this': 535,
#  '5th': 536,
#  'iv': 537,
#  'useful': 538,
#  'resolution': 539,
#  'failure': 540,
#  'largest': 541,
#  'tips': 542,
#  'congestive': 543,
#  'though': 544,
#  'concern': 545,
#  'sequelae': 546,
#  'tenderness': 547,
#  'on': 548,
#  'segment': 549,
#  'conspicuous': 550,
#  'fissure': 551,
#  'vertebrae': 552,
#  'series': 553,
#  'head': 554,
#  'involving': 555,
#  'indicate': 556,
#  'appearing': 557,
#  'time': 558,
#  'airway': 559,
#  'document': 560,
#  'uncertain': 561,
#  'remains': 562,
#  'wedging': 563,
#  'should': 564,
#  'curvilinear': 565,
#  'ascending': 566,
#  'diffuse': 567,
#  'enlargement': 568,
#  'radiographs': 569,
#  'tracheostomy': 570,
#  'histoplasmosis': 571,
#  'up': 572,
#  'density': 573,
#  'essentially': 574,
#  'flowing': 575,
#  'ij': 576,
#  'limited': 577,
#  'remaining': 578,
#  'probably': 579,
#  'post': 580,
#  's-shaped': 581,
#  'dilated': 582,
#  'abdomen': 583,
#  'asymmetric': 584,
#  'multiple': 585,
#  'device': 586,
#  'pectus': 587,
#  'surgical': 588,
#  'quality': 589,
#  'shadows': 590,
#  'formation': 591,
#  'fractures': 592,
#  'dense': 593,
#  'basal': 594,
#  'lesion': 595,
#  'retained': 596,
#  'cabg': 597,
#  'markings': 598,
#  'evidence': 599,
#  'mm': 600,
#  'aorta': 601,
#  'base': 602,
#  'multilevel': 603,
#  'posteriorly': 604,
#  'consideration': 605,
#  'innumerable': 606,
#  'does': 607,
#  'mass': 608,
#  'structure': 609,
#  'quadrant': 610,
#  'overlying': 611,
#  'comparison': 612,
#  'aerated': 613,
#  'predominantly': 614,
#  'part': 615,
#  'obscure': 616,
#  'obscures': 617,
#  'tortuous': 618,
#  'suggestive': 619,
#  'cavitation': 620,
#  'projecting': 621,
#  'related': 622,
#  ':': 623,
#  'l': 624,
#  'body': 625,
#  'factors': 626,
#  'left': 627,
#  'curvature': 628,
#  'show': 629,
#  'as': 630,
#  'sclerosis': 631,
#  'secondary': 632,
#  'significant': 633,
#  'l1': 634,
#  'possibility': 635,
#  'granuloma': 636,
#  'pleural': 637,
#  'confluent': 638,
#  'portable': 639,
#  'screw': 640,
#  'knee': 641,
#  'vague': 642,
#  'diameter': 643,
#  'expected': 644,
#  'obscured': 645,
#  'than': 646,
#  'lobes': 647,
#  'zone': 648,
#  'allowing': 649,
#  'area': 650,
#  'placement': 651,
#  'stripe': 652,
#  'focus': 653,
#  'injury': 654,
#  'lobe': 655,
#  'developing': 656,
#  'through': 657,
#  'thorax': 658,
#  'several': 659,
#  'shape': 660,
#  'bronchiectasis': 661,
#  'icd': 662,
#  'result': 663,
#  'cyst': 664,
#  'lymphadenopathy': 665,
#  'located': 666,
#  'pneumonia': 667,
#  'it': 668,
#  'superimposed': 669,
#  'questionable': 670,
#  'dislocation': 671,
#  'first': 672,
#  'resolving': 673,
#  'hypoventilation': 674,
#  'better': 675,
#  ';': 676,
#  'detail': 677,
#  'axilla': 678,
#  'have': 679,
#  'internal': 680,
#  'bilaterally': 681,
#  'benefit': 682,
#  'p': 683,
#  'difficult': 684,
#  'focal': 685,
#  'suggests': 686,
#  'lucent': 687,
#  'symmetric': 688,
#  'normally': 689,
#  'known': 690,
#  'granulomas': 691,
#  'only': 692,
#  'amount': 693,
#  'bony': 694,
#  'fat': 695,
#  'venous': 696,
#  'development': 697,
#  'diagnosis': 698,
#  'imaging': 699,
#  'colonic': 700,
#  'months': 701,
#  'transverse': 702,
#  'sided': 703,
#  'radiographic': 704,
#  'along': 705,
#  'three': 706,
#  'examination': 707,
#  'aspect': 708,
#  'vertebra': 709,
#  'effusions': 710,
#  'septal': 711,
#  'position': 712,
#  'entirely': 713,
#  'coarsened': 714,
#  'that': 715,
#  'cuffing': 716,
#  'midline': 717,
#  'hypertension': 718,
#  'effusion': 719,
#  'after': 720,
#  'recent': 721,
#  'worse': 722,
#  'containing': 723,
#  'your': 724,
#  'ensure': 725,
#  'free': 726,
#  'aneurysm': 727,
#  'recurrence': 728,
#  'single': 729,
#  'spaces': 730,
#  'marginal': 731,
#  'skin': 732,
#  'before': 733,
#  'periphery': 734,
#  'gastroesophageal': 735,
#  'excavatum': 736,
#  'posterior': 737,
#  'ovoid': 738,
#  'contrast': 739,
#  'infection': 740,
#  'tb': 741,
#  'early': 742,
#  'chf': 743,
#  'proximal': 744,
#  'with': 745,
#  'noted': 746,
#  'present': 747,
#  'features': 748,
#  'report': 749,
#  'appears': 750,
#  'primordial': 751,
#  't12': 752,
#  'lateral': 753,
#  'films': 754,
#  'note': 755,
#  'specifically': 756,
#  'aeration': 757,
#  'dialysis': 758,
#  'valve': 759,
#  'compared': 760,
#  'appear': 761,
#  'fragments': 762,
#  'persistent': 763,
#  'regions': 764,
#  'normal': 765,
#  'excluded': 766,
#  '4th': 767,
#  'pericardial': 768,
#  'images': 769,
#  'pneumothorax': 770,
#  'empyema': 771,
#  'reflecting': 772,
#  'atelectasis': 773,
#  'has': 774,
#  'hip': 775,
#  'silhouette': 776,
#  'suture': 777,
#  'weeks': 778,
#  'appearance': 779,
#  'reactive': 780,
#  'liver': 781,
#  'intact': 782,
#  'disc': 783,
#  'x': 784,
#  'bone': 785,
#  'worsening': 786,
#  'margin': 787,
#  'its': 788,
#  'nodules': 789,
#  'image': 790,
#  'measures': 791,
#  'rotator': 792,
#  'described': 793,
#  'fibrotic': 794,
#  'also': 795,
#  'densities': 796,
#  'congestion': 797,
#  'increase': 798,
#  'technically': 799,
#  'epigastric': 800,
#  'scarring': 801,
#  'structures': 802,
#  'cholecystectomy': 803,
#  'seen': 804,
#  'resection': 805,
#  'discoid': 806,
#  'mid': 807,
#  'somewhat': 808,
#  'documented': 809,
#  'masses': 810,
#  'further': 811,
#  'determine': 812,
#  'ribs': 813,
#  'unfolding': 814,
#  'like': 815,
#  'location': 816,
#  '5': 817,
#  'cancer': 818,
#  'although': 819,
#  'from': 820,
#  'similar': 821,
#  'inspiratory': 822,
#  'thin': 823,
#  'top': 824,
#  'projection': 825,
#  'obtained': 826,
#  'given': 827,
#  'nonspecific': 828,
#  'skeletal': 829,
#  'artery': 830,
#  'approximating': 831,
#  'sternum': 832,
#  't11': 833,
#  'generator': 834,
#  'dislocations': 835,
#  'advanced': 836,
#  'aspiration': 837,
#  'accounting': 838,
#  'enteric': 839,
#  'or': 840,
#  'size': 841,
#  'carina': 842,
#  'central': 843,
#  'small': 844,
#  'degenerative': 845,
#  'basilar': 846,
#  'overlap': 847,
#  '8': 848,
#  '/': 849,
#  'areas': 850,
#  'healed': 851,
#  '6th': 852,
#  'volumes': 853,
#  'resolved': 854,
#  'opacities': 855,
#  'ct': 856,
#  'about': 857,
#  'follow': 858,
#  'feeding': 859,
#  'obliquely': 860,
#  'correlate': 861,
#  'contours': 862,
#  'osteopenia': 863,
#  'but': 864,
#  'shunt': 865,
#  'monitor': 866,
#  'remainder': 867,
#  'studies': 868,
#  'chest': 869,
#  'radiograph': 870,
#  'combination': 871,
#  'less': 872,
#  'gross': 873,
#  'infectious': 874,
#  'projected': 875,
#  'telephone': 876,
#  'reflect': 877,
#  'since': 878,
#  'lobectomy': 879,
#  'associated': 880,
#  'kyphosis': 881,
#  'warranted': 882,
#  'slightly': 883,
#  'glenoid': 884,
#  'alignment': 885,
#  'out': 886,
#  'distribution': 887,
#  'probable': 888,
#  '8th': 889,
#  'copd': 890,
#  'engorged': 891,
#  'removed': 892,
#  'however': 893,
#  'apparent': 894,
#  'is': 895,
#  'generalized': 896,
#  'air': 897,
#  'flattened': 898,
#  'end': 899,
#  'considered': 900,
#  'callus': 901,
#  'catheter': 902,
#  '9': 903,
#  'destruction': 904,
#  ')': 905,
#  'subclavian': 906,
#  'interstitium': 907,
#  'available': 908,
#  'frontal': 909,
#  'typical': 910,
#  'possible': 911,
#  'developed': 912,
#  'coarse': 913,
#  'recess': 914,
#  'heart': 915,
#  'arteries': 916,
#  'prominence': 917,
#  'pattern': 918,
#  'shift': 919,
#  'stents': 920,
#  'below': 921,
#  'negative': 922,
#  'patchy': 923,
#  'active': 924,
#  '8mm': 925,
#  'inferior': 926,
#  'review': 927,
#  'treatment': 928,
#  'indistinct': 929,
#  'carcinoma': 930,
#  'ventricular': 931,
#  'reflects': 932,
#  'atypical': 933,
#  'previously': 934,
#  'cardiac': 935,
#  'was': 936,
#  'ectasia': 937,
#  'could': 938,
#  'outside': 939,
#  'near': 940,
#  'visualized': 941,
#  'airspace': 942,
#  'cardiothoracic': 943,
#  'includes': 944,
#  'stent': 945,
#  'consists': 946,
#  'demonstrate': 947,
#  'etiology': 948,
#  'mildly': 949,
#  'cystic': 950,
#  'centrally': 951,
#  't9': 952,
#  'over': 953,
#  'decreased': 954,
#  'rotation': 955,
#  'fourth': 956,
#  'reticular': 957,
#  'well': 958,
#  'grossly': 959,
#  'fullness': 960,
#  '<unk>': 961,
#  '<end>': 962,
#  '<start>': 963,
#  '<pad>': 0}

# %%
def get_print(img_name, visualize=True, print_res=True):
    parser = argparse.ArgumentParser(description='Show, Attend, and Tell - Tutorial - Generate Caption')
    parser.add_argument('--img', '-i', default=f'/home/dchesakov/NLMCXR_data/images/{img_name}.png', help='path to image')
    parser.add_argument('--model', '-m', default='BEST_checkpoint_NLMCXR_v9_1_cap_per_img_6_min_word_freq.pth.tar', help='path to model')
    parser.add_argument('--word_map', '-wm', default='/home/dchesakov/NLMCXR_data/WORDMAP_NLMCXR_v9_1_cap_per_img_6_min_word_freq.json',  help='path to word map JSON')
    parser.add_argument('--beam_size', '-b', default=5, type=int, help='beam size for beam search')
    parser.add_argument('--dont_smooth', dest='smooth', action='store_false', help='do not smooth alpha overlay')
    
    args = args = parser.parse_args('')
    
    checkpoint = torch.load(args.model)
    decoder = checkpoint['decoder']
    decoder = decoder.to(device)
    decoder.eval()
    encoder = checkpoint['encoder']
    encoder = encoder.to(device)
    encoder.eval()

    # Load word map (word2ix)
    with open(args.word_map, 'r') as j:
        word_map = json.load(j)
    rev_word_map = {v: k for k, v in word_map.items()}  # ix2word

    # Encode, decode with attention and beam search
    seq, alphas = caption_image_beam_search(encoder, decoder, args.img, word_map, args.beam_size)
    alphas = torch.FloatTensor(alphas)
    
    if print_res:
        print(asd[ asd['images'] == f'{img_name}']['processed_findings'].iloc[0])

    # Visualize caption and attention of best sequence
    words = visualize_att(args.img, seq, alphas, rev_word_map, args.smooth, visualize=visualize)
    
    return words

# %%
import pandas as pd

# %%
asd = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_df.pkl')

# %%
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

all_reports_df = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_tags_df.pkl')
    # all_reports_df = all_reports_df[ all_reports_df['processed_findings'].notnull() ]
# train_df, val_df, test_df = train_validate_test_split(all_reports_df, .9, .05, seed=42)
train_df = all_reports_df[:-600]
val_df = all_reports_df[-600:-300]
test_df = all_reports_df[-300:]

# %%
# all_reports_df = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_df.pkl')
# all_reports_df['processed_captions'] = [eval(cap) for cap in all_reports_df['processed_captions']]
# all_reports_df = all_reports_df[ all_reports_df['processed_findings'].notnull() ]

# train_df = all_reports_df[:-600]
# val_df = all_reports_df[-600:-300]
# test_df = all_reports_df[-300:]

# %%
get_print('CXR2992_IM-1379-2002')
# Out:
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ['the lungs are clear', 'heart size is normal', 'no pneumothorax', 'calcified granuloma within the right lung base']
# ['<start>',
#  'no',
#  'acute',
#  'cardiopulmonary',
#  'findings',
#  '.',
#  'the',
#  '<unk>',
#  'silhouette',
#  'and',
#  'pulmonary',
#  'vasculature',
#  'are',
#  'within',
#  'normal',
#  'limits',
#  'in',
#  'size',
#  '.',
#  'the',
#  'lungs',
#  'are',
#  'clear',
#  'of',
#  'focal',
#  'airspace',
#  'disease',
#  ',',
#  'pneumothorax',
#  ',',
#  'or',
#  'pleural',
#  'effusion',
#  '.',
#  'there',
#  'are',
#  'no',
#  'acute',
#  'bony',
#  'findings',
#  '.',
#  '<end>']

# %%
get_print('CXR2992_IM-1379-2002')
# Out:
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ['the lungs are clear', 'heart size is normal', 'no pneumothorax', 'calcified granuloma within the right lung base']
# ['<start>',
#  'no',
#  'acute',
#  'cardiopulmonary',
#  'findings',
#  '.',
#  'the',
#  '<unk>',
#  'silhouette',
#  'and',
#  'pulmonary',
#  'vasculature',
#  'are',
#  'within',
#  'normal',
#  'limits',
#  'in',
#  'size',
#  '.',
#  'the',
#  'lungs',
#  'are',
#  'clear',
#  'of',
#  'focal',
#  'airspace',
#  'disease',
#  ',',
#  'pneumothorax',
#  ',',
#  'or',
#  'pleural',
#  'effusion',
#  '.',
#  'there',
#  'are',
#  'no',
#  'acute',
#  'bony',
#  'findings',
#  '.',
#  '<end>']

# %%
train_df.head(3)
# Out:
#                       images  \
# 0       CXR2357_IM-0921-1001
# 1       CXR2357_IM-0921-2001
# 0  CXR3620_IM-1791-1001-0001
#
#                                             FINDINGS  \
# 0  Cardiomediastinal silhouette and pulmonary vas...
# 1  Cardiomediastinal silhouette and pulmonary vas...
# 0  The cardiac silhouette is near upper limits of...
#
#                                           IMPRESSION  \
# 0                 No acute cardiopulmonary findings.
# 1                 No acute cardiopulmonary findings.
# 0  1. Minimal left basilar atelectasis or scar. 2...
#
#                                           tags_major  \
# 0                                           [normal]
# 1                                           [normal]
# 0  [pulmonary atelectasis, base, left, mild, cica...
#
#                                       tags_automatic  \
# 0                                                 []
# 1                                                 []
# 0  [atelectases, calcified granuloma, scar, atele...
#
#                                report  \
# 0  ./reports/ecgen-radiology/2357.xml
# 1  ./reports/ecgen-radiology/2357.xml
# 0  ./reports/ecgen-radiology/3620.xml
#
#                                          full_report  \
# 0  No acute cardiopulmonary findings. Cardiomedia...
# 1  No acute cardiopulmonary findings. Cardiomedia...
# 0  1. Minimal left basilar atelectasis or scar. 2...
#
#                                   processed_captions  \
# 0  [no acute cardiopulmonary findings, cardiomedi...
# 1  [no acute cardiopulmonary findings, cardiomedi...
# 0  [minimal left basilar atelectasis or scar, no ...
#
#                                   processed_findings  \
# 0  [cardiomediastinal silhouette and pulmonary va...
# 1  [cardiomediastinal silhouette and pulmonary va...
# 0  [the cardiac silhouette is near upper limits o...
#
#                             preprocessed_full_report
# 0  no acute cardiopulmonary findings . cardiomedi...
# 1  no acute cardiopulmonary findings . cardiomedi...
# 0  minimal left basilar atelectasis or scar . no ...

# %%
test_df.head(3)
# Out:
#                  images                                           FINDINGS  \
# 1  CXR1484_IM-0313-2001  Calcified left lower lobe granuloma. No focal ...
# 0  CXR2767_IM-1212-1001  Lungs are clear. No pleural effusion or pneumo...
# 1  CXR2767_IM-1212-2001  Lungs are clear. No pleural effusion or pneumo...
#
#                               IMPRESSION  \
# 1  No acute cardiopulmonary abnormality.
# 0         No evidence of active disease.
# 1         No evidence of active disease.
#
#                                           tags_major  \
# 1  [calcified granuloma, lung, lower lobe, left, ...
# 0                        [spine, degenerative, mild]
# 1                        [spine, degenerative, mild]
#
#                      tags_automatic                              report  \
# 1  [degenerative change, granuloma]  ./reports/ecgen-radiology/1484.xml
# 0             [degenerative change]  ./reports/ecgen-radiology/2767.xml
# 1             [degenerative change]  ./reports/ecgen-radiology/2767.xml
#
#                                          full_report  \
# 1  No acute cardiopulmonary abnormality. Calcifie...
# 0  No evidence of active disease. Lungs are clear...
# 1  No evidence of active disease. Lungs are clear...
#
#                                   processed_captions  \
# 1  [no acute cardiopulmonary abnormality, calcifi...
# 0  [no evidence of active disease, lungs are clea...
# 1  [no evidence of active disease, lungs are clea...
#
#                                   processed_findings  \
# 1  [calcified left lower lobe granuloma, no focal...
# 0  [lungs are clear, no pleural effusion or pneum...
# 1  [lungs are clear, no pleural effusion or pneum...
#
#                             preprocessed_full_report
# 1  no acute cardiopulmonary abnormality . calcifi...
# 0  no evidence of active disease . lungs are clea...
# 1  no evidence of active disease . lungs are clea...

# %%
test_predicts = []
test_images = test_df.images.values

# %%
train_predicts = []
train_images = train_df.images.values

# %%
from tqdm import tqdm_notebook

# %%
# for img_name in tqdm_notebook(train_images):
#     words = get_print(img_name, visualize=False, print_res=False)
#     train_predicts.append(words)

# %%
for img_name in tqdm_notebook(test_images):
    words = get_print(img_name, visualize=False, print_res=False)
    test_predicts.append(words)
# Out:
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
test_predicts
# Out:
# [['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   'and',
#   'contour',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   ',',
#   'without',
#   'evidence',
#   'of',
#   'infiltrate',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pneumothorax',
#   'or',
#   'effusion',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   'with',
#   'no',
#   'focal',
#   'infiltrate',
#   ',',
#   'pleural',
#   'effusion',
#   ',',
#   'or',
#   '<unk>',
#   '.',
#   '<unk>',
#   'silhouette',
#   'is',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'xxxx',
#   'and',
#   'soft',
#   'tissues',
#   'are',
#   'unremarkable',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'not',
#   'significantly',
#   'enlarged',
#   '.',
#   'there',
#   'are',
#   'atherosclerotic',
#   'changes',
#   'of',
#   'the',
#   'aorta',
#   '.',
#   'arthritic',
#   'changes',
#   'of',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'noted',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   'and',
#   'contour',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   ',',
#   'without',
#   'evidence',
#   'of',
#   'infiltrate',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pneumothorax',
#   'or',
#   'effusion',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'not',
#   'significantly',
#   'enlarged',
#   '.',
#   'there',
#   'are',
#   'atherosclerotic',
#   'changes',
#   'of',
#   'the',
#   'aorta',
#   '.',
#   'arthritic',
#   'changes',
#   'of',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'noted',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'disease',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'is',
#   'normal',
#   'size',
#   'and',
#   'configuration',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   '<unk>',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pneumothorax',
#   ',',
#   'pleural',
#   'effusion',
#   ',',
#   'or',
#   'focal',
#   'consolidation',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   'with',
#   'no',
#   'focal',
#   'infiltrate',
#   ',',
#   'pleural',
#   'effusion',
#   ',',
#   'or',
#   '<unk>',
#   '.',
#   '<unk>',
#   'silhouette',
#   'is',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'xxxx',
#   'and',
#   'soft',
#   'tissues',
#   'are',
#   'unremarkable',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   'with',
#   'no',
#   'focal',
#   'infiltrate',
#   ',',
#   'pleural',
#   'effusion',
#   ',',
#   'or',
#   '<unk>',
#   '.',
#   '<unk>',
#   'silhouette',
#   'is',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'xxxx',
#   'and',
#   'soft',
#   'tissues',
#   'are',
#   'unremarkable',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
# ...
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'and',
#   'pleural',
#   'spaces',
#   'show',
#   'no',
#   'acute',
#   'abnormality',
#   '.',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'findings',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'contours',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'bony',
#   'structures',
#   'are',
#   'intact',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'is',
#   'normal',
#   'in',
#   'size',
#   '.',
#   'the',
#   'mediastinum',
#   'is',
#   'unremarkable',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   'with',
#   'no',
#   'focal',
#   'infiltrate',
#   ',',
#   'pleural',
#   'effusion',
#   ',',
#   'or',
#   '<unk>',
#   '.',
#   '<unk>',
#   'silhouette',
#   'is',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'xxxx',
#   'and',
#   'soft',
#   'tissues',
#   'are',
#   'unremarkable',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'evidence',
#   'of',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'size',
#   'and',
#   'pulmonary',
#   '<unk>',
#   'appear',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'free',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   '.',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   'is',
#   'seen',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'pulmonary',
#   'disease',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'there',
#   'is',
#   'no',
#   'pleural',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'mediastinum',
#   'are',
#   'normal',
#   '.',
#   'the',
#   'skeletal',
#   'structures',
#   'are',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'silhouettes',
#   'are',
#   'normal',
#   '.',
#   'pulmonary',
#   'vasculature',
#   'is',
#   'normal',
#   '.',
#   'no',
#   'pneumothorax',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'no',
#   'acute',
#   'bony',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'findings',
#   '.',
#   'cardiac',
#   'and',
#   'mediastinal',
#   'contours',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   '.',
#   'bony',
#   'structures',
#   'are',
#   'intact',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'findings',
#   '.',
#   '.',
#   'the',
#   '<unk>',
#   'silhouette',
#   'and',
#   'pulmonary',
#   'vasculature',
#   'are',
#   'within',
#   'normal',
#   'limits',
#   'in',
#   'size',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'of',
#   'focal',
#   'airspace',
#   'disease',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'there',
#   'are',
#   'no',
#   'acute',
#   'bony',
#   'findings',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'acute',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'the',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   '.',
#   'specifically',
#   ',',
#   'no',
#   'evidence',
#   'of',
#   'focal',
#   'consolidation',
#   ',',
#   'pneumothorax',
#   ',',
#   'or',
#   'pleural',
#   'effusion',
#   '.',
#   'cardio',
#   'mediastinal',
#   'silhouette',
#   'is',
#   'unremarkable',
#   '.',
#   'visualized',
#   'osseous',
#   'structures',
#   'of',
#   'the',
#   'thorax',
#   'are',
#   'without',
#   'acute',
#   'abnormality',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'the',
#   'heart',
#   'and',
#   'lungs',
#   'have',
#   'xxxx',
#   'xxxx',
#   'in',
#   'the',
#   'interval',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>'],
#  ['<start>',
#   'no',
#   'active',
#   'disease',
#   '.',
#   'both',
#   'lungs',
#   'are',
#   'clear',
#   'and',
#   'expanded',
#   '.',
#   'heart',
#   'and',
#   'mediastinum',
#   'normal',
#   '.',
#   '<end>']]

# %%
max_len = 100

# %%
test_image_captions = [[sents.split()][:max_len] for sents in test_df['preprocessed_full_report']]

# %%
max_len=100

# test_image_captions = [[[x for l in sents for x in l.split()][:max_len]] for sents in test_df['processed_findings']]
    
test_image_captions = []
for sents in test_df['processed_findings']:
    cap = sents[0].split()
    for sent in sents[1:]:
        cap.append(',')
        cap.extend(sent.split())
    test_image_captions.append([cap[:max_len]])

# %%
# max_len=100
  
# test_image_captions = []
# for sents in train_df['processed_findings']:
#     cap = sents[0].split()
#     for sent in sents[1:]:
#         cap.append(',')
#         cap.extend(sent.split())
#     test_image_captions.append([cap[:max_len]])

# %%
np.argmax(list(map(len, test_predicts)))
# Out:
# 2

# %%
test_predicts = [words[1:-1] for words in test_predicts]

# %%
evalscores(test_predicts, test_image_captions)
# Out:
# Bleu_1: 0.319
# Bleu_2: 0.195
# Bleu_3: 0.129
# Bleu_4: 0.088
# ROUGE_L: 0.290
# CIDEr: 0.285

# %%
evalscores(test_predicts, test_image_captions)
# Out:
# Bleu_1: 0.319
# Bleu_2: 0.190
# Bleu_3: 0.125
# Bleu_4: 0.084
# ROUGE_L: 0.269
# CIDEr: 0.208

# %%
train_predicts = [words[1:-1] for words in train_predicts]

# %%
evalscores(test_predicts, test_image_captions)
# Out:
# Bleu_1: 0.343
# Bleu_2: 0.203
# Bleu_3: 0.131
# Bleu_4: 0.087
# ROUGE_L: 0.266
# CIDEr: 0.202

# %%
evalscores(train_predicts, test_image_captions)
# Out:
# Bleu_1: 0.345
# Bleu_2: 0.222
# Bleu_3: 0.164
# Bleu_4: 0.129
# ROUGE_L: 0.299
# CIDEr: 0.587

# %% [markdown]
# ## Предсказание вместе с GPT-2

# %%
from transformers import (WEIGHTS_NAME, AdamW, get_linear_schedule_with_warmup, get_constant_schedule, get_cosine_schedule_with_warmup,
                                  BertConfig, BertForMaskedLM, BertTokenizer,
                                  GPT2Config, GPT2LMHeadModel, GPT2Tokenizer,
                                  OpenAIGPTConfig, OpenAIGPTLMHeadModel, OpenAIGPTTokenizer,
                                  RobertaConfig, RobertaForMaskedLM, RobertaTokenizer,
                                  DistilBertConfig, DistilBertForMaskedLM, DistilBertTokenizer)
# Out:
# I0429 14:15:33.346531 139748746278720 file_utils.py:41] PyTorch version 1.2.0 available.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from transformers import GPT2Tokenizer, GPT2Model

import os
import numpy as np

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

import torch

# %%
tokenizer = GPT2Tokenizer.from_pretrained('/home/dchesakov/transformers/output3')
# Out:
# I0429 14:16:15.112533 139748746278720 tokenization_utils.py:895] Model name '/home/dchesakov/transformers/output3' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2). Assuming '/home/dchesakov/transformers/output3' is a path, a model identifier, or url to a directory containing tokenizer files.
# I0429 14:16:15.114603 139748746278720 tokenization_utils.py:924] Didn't find file /home/dchesakov/transformers/output3/added_tokens.json. We won't load it.
# I0429 14:16:15.116124 139748746278720 tokenization_utils.py:977] loading file /home/dchesakov/transformers/output3/vocab.json
# I0429 14:16:15.116693 139748746278720 tokenization_utils.py:977] loading file /home/dchesakov/transformers/output3/merges.txt
# I0429 14:16:15.117269 139748746278720 tokenization_utils.py:977] loading file None
# I0429 14:16:15.117909 139748746278720 tokenization_utils.py:977] loading file /home/dchesakov/transformers/output3/special_tokens_map.json
# I0429 14:16:15.118707 139748746278720 tokenization_utils.py:977] loading file /home/dchesakov/transformers/output3/tokenizer_config.json

# %%
gpt_model = GPT2LMHeadModel.from_pretrained('/home/dchesakov/transformers/output3', pad_token_id=tokenizer.eos_token_id)
# Out:
# I0429 14:17:18.166229 139748746278720 configuration_utils.py:284] loading configuration file /home/dchesakov/transformers/output3/config.json
# I0429 14:17:18.167824 139748746278720 configuration_utils.py:322] Model config GPT2Config {
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "pad_token_id": 50256,
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "vocab_size": 50257
# }
#
# I0429 14:17:18.169551 139748746278720 modeling_utils.py:610] loading weights file /home/dchesakov/transformers/output3/pytorch_model.bin

# %%
tokenizer.encode("Hello, my dog is cute", add_special_tokens=False)
# Out:
# [15496, 11, 616, 3290, 318, 13779]

# %%
input_ids = torch.tensor(tokenizer.encode('Hi hello', add_special_tokens=True)).unsqueeze(0)

# %%
gpt_model(input_ids)[1][0].shape
# Out:
# torch.Size([2, 1, 12, 2, 64])

# %%
gpt_vocab = tokenizer.get_vocab()

# %%
def caption_image_beam_search_gpt(encoder, decoder, image_path, word_map, beam_size=3):
    """
    Reads an image and captions it with beam search.

    :param encoder: encoder model
    :param decoder: decoder model
    :param image_path: path to image
    :param word_map: word map
    :param beam_size: number of sequences to consider at each decode-step
    :return: caption, weights for visualization
    """

    k = beam_size
    vocab_size = len(word_map)

    # Read image and process
    img = imread(image_path)
    if len(img.shape) == 2:
        img = img[:, :, np.newaxis]
        img = np.concatenate([img, img, img], axis=2)
    img = imresize(img, (256, 256))
    img = img.transpose(2, 0, 1)
    img = img / 255.
    img = torch.FloatTensor(img).to(device)
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    transform = transforms.Compose([normalize])
    image = transform(img)  # (3, 256, 256)

    # Encode
    image = image.unsqueeze(0)  # (1, 3, 256, 256)
    encoder_out = encoder(image)  # (1, enc_image_size, enc_image_size, encoder_dim)
    enc_image_size = encoder_out.size(1)
    encoder_dim = encoder_out.size(3)

    # Flatten encoding
    encoder_out = encoder_out.view(1, -1, encoder_dim)  # (1, num_pixels, encoder_dim)
    num_pixels = encoder_out.size(1)

    # We'll treat the problem as having a batch size of k
    encoder_out = encoder_out.expand(k, num_pixels, encoder_dim)  # (k, num_pixels, encoder_dim)

    # Tensor to store top k previous words at each step; now they're just <start>
    k_prev_words = torch.LongTensor([[word_map['<start>']]] * k).to(device)  # (k, 1)

    # Tensor to store top k sequences; now they're just <start>
    seqs = k_prev_words  # (k, 1)

    # Tensor to store top k sequences' scores; now they're just 0
    top_k_scores = torch.zeros(k, 1).to(device)  # (k, 1)

    # Tensor to store top k sequences' alphas; now they're just 1s
    seqs_alpha = torch.ones(k, 1, enc_image_size, enc_image_size).to(device)  # (k, 1, enc_image_size, enc_image_size)

    # Lists to store completed sequences, their alphas and scores
    complete_seqs = list()
    complete_seqs_alpha = list()
    complete_seqs_scores = list()

    # Start decoding
    step = 1
    h, c = decoder.init_hidden_state(encoder_out)
    gpt_koeff = 0.

    # s is a number less than or equal to k, because sequences are removed from this process once they hit <end>
    while True:
        # print(step)
        
        embeddings = decoder.embedding(k_prev_words).squeeze(1)  # (s, embed_dim)

        awe, alpha = decoder.attention(encoder_out, h)  # (s, encoder_dim), (s, num_pixels)

        alpha = alpha.view(-1, enc_image_size, enc_image_size)  # (s, enc_image_size, enc_image_size)

        gate = decoder.sigmoid(decoder.f_beta(h))  # gating scalar, (s, encoder_dim)
        awe = gate * awe

        h, c = decoder.decode_step(torch.cat([embeddings, awe], dim=1), (h, c))  # (s, decoder_dim)

        scores = decoder.fc(h)  # (s, vocab_size)
        scores = F.log_softmax(scores, dim=1)
        
        gpt_scores = idxs2gpt_predictions(seqs)
        gpt_scores = F.log_softmax(gpt_scores, dim=1)
        
        if step > 2:
            scores = top_k_scores.expand_as(scores) + (1-gpt_koeff)*scores + gpt_koeff*gpt_scores.cuda() # (s, vocab_size)
        else:
            scores = top_k_scores.expand_as(scores) + scores
        

        # For the first step, all k points will have the same scores (since same k previous words, h, c)
        if step == 1:
            top_k_scores, top_k_words = scores[0].topk(k, 0, True, True)  # (s)
        else:
            # Unroll and find top scores, and their unrolled indices
            top_k_scores, top_k_words = scores.view(-1).topk(k, 0, True, True)  # (s)
            

        # Convert unrolled indices to actual indices of scores
        prev_word_inds = top_k_words / vocab_size  # (s)
        next_word_inds = top_k_words % vocab_size  # (s)

        # Add new words to sequences, alphas
        seqs = torch.cat([seqs[prev_word_inds], next_word_inds.unsqueeze(1)], dim=1)  # (s, step+1)
        seqs_alpha = torch.cat([seqs_alpha[prev_word_inds], alpha[prev_word_inds].unsqueeze(1)],
                               dim=1)  # (s, step+1, enc_image_size, enc_image_size)

        # Which sequences are incomplete (didn't reach <end>)?
        incomplete_inds = [ind for ind, next_word in enumerate(next_word_inds) if
                           next_word != word_map['<end>']]
        complete_inds = list(set(range(len(next_word_inds))) - set(incomplete_inds))

        # Set aside complete sequences
        if len(complete_inds) > 0:
            complete_seqs.extend(seqs[complete_inds].tolist())
            complete_seqs_alpha.extend(seqs_alpha[complete_inds].tolist())
            complete_seqs_scores.extend(top_k_scores[complete_inds])
            # return (complete_seqs, complete_seqs_alpha, complete_seqs_scores)
            
        k -= len(complete_inds)  # reduce beam length accordingly

        # Proceed with incomplete sequences
        if k == 0:
            break
        seqs = seqs[incomplete_inds]
        seqs_alpha = seqs_alpha[incomplete_inds]
        h = h[prev_word_inds[incomplete_inds]]
        c = c[prev_word_inds[incomplete_inds]]
        encoder_out = encoder_out[prev_word_inds[incomplete_inds]]
        top_k_scores = top_k_scores[incomplete_inds].unsqueeze(1)
        k_prev_words = next_word_inds[incomplete_inds].unsqueeze(1)

        # Break if things have been going on too long
        if step > 50:
            break
        step += 1
    try:
        i = complete_seqs_scores.index(max(complete_seqs_scores))
        seq = complete_seqs[i]
        alphas = complete_seqs_alpha[i]

        return seq, alphas
    except:
        return complete_seqs_scores, complete_seqs

# %%
def visualize_att_gpt(image_path, seq, alphas, rev_word_map, smooth=True, visualize=True):
    """
    Visualizes caption with weights at every word.

    Adapted from paper authors' repo: https://github.com/kelvinxu/arctic-captions/blob/master/alpha_visualization.ipynb

    :param image_path: path to image that has been captioned
    :param seq: caption
    :param alphas: weights
    :param rev_word_map: reverse word mapping, i.e. ix2word
    :param smooth: smooth weights?
    """
    image = Image.open(image_path)
    image = image.resize([14 * 24, 14 * 24], Image.LANCZOS)

    words = [rev_word_map[ind] for ind in seq]
    
    print(words)
    words = tokenizer.decode(tokenizer.encode(words[1:-1])).replace('.', ' . ').split()
    
    
    if visualize:
        for t in range(len(words)):
            if t > 50:
                break
            plt.subplot(np.ceil(len(words) / 5.), 5, t + 1)

            plt.text(0, 1, '%s' % (words[t]), color='black', backgroundcolor='white', fontsize=12)
            plt.imshow(image)
            current_alpha = alphas[t, :]
            if smooth:
                alpha = skimage.transform.pyramid_expand(current_alpha.numpy(), upscale=24, sigma=8)
            else:
                alpha = skimage.transform.resize(current_alpha.numpy(), [14 * 24, 14 * 24])
            if t == 0:
                plt.imshow(alpha, alpha=0)
            else:
                plt.imshow(alpha, alpha=0.8)
            plt.set_cmap(cm.Greys_r)
            plt.axis('off')
        plt.show()
    
    return words

# %%
parser = argparse.ArgumentParser(description='Show, Attend, and Tell - Tutorial - Generate Caption')

parser.add_argument('--img', '-i', default='/home/dchesakov/NLMCXR_data/myface.jpg', help='path to image')
parser.add_argument('--model', '-m', default='BEST_checkpoint_NLMCXR_vgpt_1_cap_per_img_0_min_word_freq.pth.tar', help='path to model')
parser.add_argument('--word_map', '-wm', default='/home/dchesakov/NLMCXR_data/WORDMAP_NLMCXR_vgpt_1_cap_per_img_0_min_word_freq.json',  help='path to word map JSON')
parser.add_argument('--beam_size', '-b', default=5, type=int, help='beam size for beam search')
parser.add_argument('--dont_smooth', dest='smooth', action='store_false', help='do not smooth alpha overlay')
# Out:
# _StoreFalseAction(option_strings=['--dont_smooth'], dest='smooth', nargs=0, const=False, default=True, type=None, choices=None, help='do not smooth alpha overlay', metavar=None)

# %%
'CXR3275_IM-1556-1003002'
# Out:
# 'CXR3275_IM-1556-1003002'

# %%
# Load model
args = parser.parse_args('')

# %%
checkpoint = torch.load(args.model)
decoder = checkpoint['decoder']
decoder = decoder.to(device)
decoder.eval()
encoder = checkpoint['encoder']
encoder = encoder.to(device)
encoder.eval()

# Load word map (word2ix)
with open(args.word_map, 'r') as j:
    word_map = json.load(j)
rev_word_map = {v: k for k, v in word_map.items()}  # ix2word

# Encode, decode with attention and beam search
# seq, alphas = caption_image_beam_search(encoder, decoder, args.img, word_map, args.beam_size)
# alphas = torch.FloatTensor(alphas)

# # Visualize caption and attention of best sequence
# visualize_att(args.img, seq, alphas, rev_word_map, args.smooth)

# %%
img_name = 'CXR2992_IM-1379-2002'
img = f'/home/dchesakov/NLMCXR_data/images/{img_name}.png'

# %%
vocab_gpt = tokenizer.get_vocab()

# %%
rev_vocab_gpt = {i:v for v, i in vocab_gpt.items()}

# %%
def idxs2gpt_predictions(batch_idx):
    predictions = torch.ones((batch_idx.shape[0], len(word_map)))
    
    for j, idx in enumerate(batch_idx):
        tokens = [rev_word_map[int(i)] for i in idx]
        torch_tokens = torch.tensor(tokenizer.encode(tokens)).unsqueeze(0)
        predictions[j, :] = gpt_model(torch_tokens)[0][0][-1][gpt_indexes]
    
    return predictions

# %%
for i, a in enumerate([21, 21, 21]):
    break

# %%
i, a
# Out:
# (0, 21)

# %%
# len(gpt_indexes)

# %%
len(word_map)
# Out:
# 2395

# %%
gpt_indexes = []
err_tokens = []

for token in word_map.keys():
    try:
        gpt_indexes.append(gpt_vocab[token])
    except:
        gpt_indexes.append(gpt_vocab['<|endoftext|>'])
        err_tokens.append(token)

# %%
err_tokens
# Out:
# ['<unk>', '<end>', '<start>', '<pad>']

# %%
a = caption_image_beam_search_gpt(encoder, decoder, img, word_map, 5)
# Out:
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
idxs2gpt_predictions(seqs).shape
# Out:
# torch.Size([5, 2395])

# %%
k_prev_words, seqs = caption_image_beam_search_gpt(encoder, decoder, img, word_map, 5)
# Out:
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
k_prev_words
# Out:
# tensor([[  2],
#         [152],
#         [ 59],
#         [196],
#         [323]], device='cuda:0')

# %%
seqs
# Out:
# tensor([[2394,    1,    2],
#         [2394,    1,  152],
#         [2394,   76,   59],
#         [2394,    1,  196],
#         [2394,  788,  323]], device='cuda:0')

# %%
rev_word_map[int(i)]
# Out:
# '<pad>'

# %%
tokens = [rev_word_map[int(i)] for i in seqs[0]]

# %%
tokens.append('<pad>')

# %%
# tokens = [rev_word_map[int(i)] for i in seqs[0]]
torch_tokens = torch.tensor(tokenizer.encode(tokens)).unsqueeze(0)

# %%
tokenizer.decode([50256])
# Out:
# '<|endoftext|>'

# %%
torch_tokens
# Out:
# tensor([[50256,  3919, 14352, 50256]])

# %%
gpt_model(torch_tokens)[0][0][-1][gpt_indexes].shape
# Out:
# torch.Size([2395])

# %%
rev_vocab_gpt[14352]
# Out:
# 'Ġacute'

# %%
top_k_scores.expand_as(scores).shape
# Out:
# torch.Size([5, 2395])

# %%
top_k_scores.expand_as(scores) + scores
# Out:
# tensor([[2394,    1,    2],
#         [2394,    1,  152],
#         [2394,   76,   59],
#         [2394,    1,  196],
#         [2394,  788,  323]], device='cuda:0')

# %%
top_k_scores
# Out:
# tensor([[-0.5094],
#         [-3.1064],
#         [-3.2940],
#         [-3.4707],
#         [-4.2222]], device='cuda:0', grad_fn=<UnsqueezeBackward0>)

# %%
scores.shape
# Out:
# torch.Size([5, 2395])

# %%
scores.view(-1).topk(5, 0, True, True)
# Out:
# torch.return_types.topk(
# values=tensor([-0.8322, -2.9614, -3.1134, -3.5566, -3.6613], device='cuda:0',
#        grad_fn=<TopkBackward>),
# indices=tensor([   3,  154, 2452, 7339,  215], device='cuda:0'))

# %%
scores.view(-1).topk(5)
# Out:
# torch.return_types.topk(
# values=tensor([-0.8322, -2.9614, -3.1134, -3.5566, -3.6613], device='cuda:0',
#        grad_fn=<TopkBackward>),
# indices=tensor([   3,  154, 2452, 7339,  215], device='cuda:0'))

# %%
len(complete_seqs_alpha[0][-1])
# Out:
# 14

# %%
complete_seqs_scores[0]
# Out:
# tensor(-8.5671, device='cuda:0', grad_fn=<SelectBackward>)

# %%
i = complete_seqs_scores.index(max(complete_seqs_scores))

# %%
max(complete_seqs_scores)
# Out:
# tensor(-8.5671, device='cuda:0', grad_fn=<SelectBackward>)

# %%
seq = complete_seqs[i]

# %%
complete_seqs[0]
# Out:
# [2394,
#  1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  154,
#  8,
#  52,
#  106,
#  54,
#  21,
#  58,
#  59,
#  8,
#  52,
#  103,
#  11,
#  236,
#  237,
#  54,
#  222,
#  223,
#  8,
#  52,
#  23,
#  19,
#  24,
#  8,
#  2393]

# %%
tokenizer.decode(tokenizer.encode([rev_word_map[i] for i in seq][1:-1]))
# Out:
# 'no acute cardiopulmonary disease. the heart is normal in size. the mediastinum is unremarkable. the lungs are clear.'

# %%
tokenizer.encode([rev_word_map[i] for i in seq])
# Out:
# [50256,
#  3919,
#  14352,
#  2657,
#  14922,
#  377,
#  36639,
#  4369,
#  764,
#  262,
#  2612,
#  318,
#  3487,
#  287,
#  2546,
#  764,
#  262,
#  16957,
#  459,
#  259,
#  388,
#  318,
#  49733,
#  45543,
#  764,
#  262,
#  21726,
#  389,
#  1598,
#  764,
#  50256]

# %%
word_map
# Out:
# {'no': 1,
#  'Ġacute': 2,
#  'Ġcard': 3,
#  'iop': 4,
#  'ul': 5,
#  'monary': 6,
#  'Ġfindings': 7,
#  'Ġ.': 8,
#  'i': 9,
#  'omed': 10,
#  'ast': 11,
#  'inal': 12,
#  'Ġsilhouette': 13,
#  'Ġand': 14,
#  'Ġpulmonary': 15,
#  'Ġvas': 16,
#  'cul': 17,
#  'ature': 18,
#  'Ġare': 19,
#  'Ġwithin': 20,
#  'Ġnormal': 21,
#  'Ġlimits': 22,
#  'Ġlungs': 23,
#  'Ġclear': 24,
#  'Ġno': 25,
#  'Ġpneum': 26,
#  'oth': 27,
#  'or': 28,
#  'ax': 29,
#  'Ġor': 30,
#  'Ġple': 31,
#  'ural': 32,
#  'Ġeff': 33,
#  'usion': 34,
#  'Ġos': 35,
#  'se': 36,
#  'ous': 37,
#  'min': 38,
#  'imal': 39,
#  'Ġleft': 40,
#  'Ġbas': 41,
#  'ilar': 42,
#  'Ġat': 43,
#  'elect': 44,
#  'asis': 45,
#  'Ġscar': 46,
#  'Ġ,': 47,
#  'Ġdisplaced': 48,
#  'Ġrib': 49,
#  'Ġfractures': 50,
#  'Ġdemonstrated': 51,
#  'Ġthe': 52,
#  'Ġcardiac': 53,
#  'Ġis': 54,
#  'Ġnear': 55,
#  'Ġupper': 56,
#  'Ġof': 57,
#  'Ġin': 58,
#  'Ġsize': 59,
#  'Ġcaliber': 60,
#  'Ġthere': 61,
#  'Ġminimal': 62,
#  'Ġx': 63,
#  'xxx': 64,
#  'Ġlung': 65,
#  'Ġbase': 66,
#  'Ġotherwise': 67,
#  'Ġgrossly': 68,
#  'Ġa': 69,
#  'Ġsmall': 70,
#  'Ġcalc': 71,
#  'ified': 72,
#  'Ġgran': 73,
#  'oma': 74,
#  'Ġlobe': 75,
#  'heart': 76,
#  'Ġpneumonia': 77,
#  'Ġnod': 78,
#  'ules': 79,
#  'Ġmasses': 80,
#  'v': 81,
#  'ague': 82,
#  'Ġdensity': 83,
#  'Ġright': 84,
#  'Ġrelated': 85,
#  'Ġto': 86,
#  'Ġsc': 87,
#  'ap': 88,
#  'ular': 89,
#  'Ġtip': 90,
#  'Ġsuper': 91,
#  'imposed': 92,
#  'Ġribs': 93,
#  'Ġconsider': 94,
#  'Ġob': 95,
#  'lique': 96,
#  'Ġimages': 97,
#  'Ġexclude': 98,
#  'Ġtrue': 99,
#  'ule': 100,
#  'Ġabnorm': 101,
#  'ality': 102,
#  'Ġmedi': 103,
#  'Ġcont': 104,
#  'ours': 105,
#  'Ġheart': 106,
#  'Ġfocal': 107,
#  'Ġconsolidation': 108,
#  'Ġb': 109,
#  'ony': 110,
#  'Ġvague': 111,
#  'Ġmid': 112,
#  'Ġnot': 113,
#  'Ġvisual': 114,
#  'ized': 115,
#  'Ġon': 116,
#  'Ġlateral': 117,
#  'Ġexam': 118,
#  'Ġabnormalities': 119,
#  'Ġlarge': 120,
#  'usions': 121,
#  'Ġspace': 122,
#  'Ġop': 123,
#  'ac': 124,
#  'ities': 125,
#  'Ġthor': 126,
#  'ic': 127,
#  'Ġsp': 128,
#  'ond': 129,
#  'yl': 130,
#  'osis': 131,
#  'Ġstable': 132,
#  'Ġdeform': 133,
#  'Ġsegments': 134,
#  'ilaterally': 135,
#  'Ġinvolving': 136,
#  'Ġmultiple': 137,
#  'Ġverte': 138,
#  'bral': 139,
#  'Ġbodies': 140,
#  'Ġspine': 141,
#  'Ġwhich': 142,
#  'Ġappear': 143,
#  'Ġcompared': 144,
#  'Ġprevious': 145,
#  'Ġprocess': 146,
#  'Ġfor': 147,
#  'our': 148,
#  'Ġnormally': 149,
#  'Ġinflated': 150,
#  'Ġwithout': 151,
#  'Ġevidence': 152,
#  'Ġairspace': 153,
#  'Ġdisease': 154,
#  'us': 155,
#  'patch': 156,
#  'y': 157,
#  'Ġal': 158,
#  've': 159,
#  'olar': 160,
#  'Ġinfiltr': 161,
#  'ates': 162,
#  'l': 163,
#  'ung': 164,
#  'Ġprobably': 165,
#  'Ġanterior': 166,
#  'Ġsegment': 167,
#  'Ġ7': 168,
#  'Ġmm': 169,
#  'Ġopacity': 170,
#  'Ġover': 171,
#  'lying': 172,
#  'Ġmost': 173,
#  'Ġrepresents': 174,
#  'Ġpatient': 175,
#  "'s": 176,
#  'Ġnipple': 177,
#  'Ġrecommend': 178,
#  'Ġfilms': 179,
#  'Ġas': 180,
#  'Ġit': 181,
#  'Ġmay': 182,
#  'Ġrepresent': 183,
#  'Ġwell': 184,
#  'Ġbeing': 185,
#  'Ġrecalled': 186,
#  'Ġfrom': 187,
#  'Ġroom': 188,
#  'Ġfilm': 189,
#  'Ġintr': 190,
#  'ath': 191,
#  'Ġappearance': 192,
#  'Ġareas': 193,
#  'Ġappears': 194,
#  'Ġintact': 195,
#  'Ġactive': 196,
#  'Ġvascular': 197,
#  'ity': 198,
#  'Ġfree': 199,
#  'Ġseen': 200,
#  'Ġlev': 201,
#  'os': 202,
#  'col': 203,
#  'iosis': 204,
#  'ol': 205,
#  'umb': 206,
#  'ar': 207,
#  'Ġpresent': 208,
#  'Ġlow': 209,
#  'Ġvolumes': 210,
#  'Ġtr': 211,
#  'ache': 212,
#  'a': 213,
#  'line': 214,
#  'Ġradi': 215,
#  'ographic': 216,
#  'Ġmetast': 217,
#  'atic': 218,
#  'ification': 219,
#  'Ġrepresenting': 220,
#  'Ġstructures': 221,
#  'Ġunrem': 222,
#  'arkable': 223,
#  'right': 224,
#  'Ġaspect': 225,
#  'm': 226,
#  'ild': 227,
#  'ome': 228,
#  'g': 229,
#  'aly': 230,
#  'Ġathe': 231,
#  'ros': 232,
#  'clerosis': 233,
#  'Ġinfiltrate': 234,
#  'Ġtop': 235,
#  'in': 236,
#  'um': 237,
#  'ort': 238,
#  'cler': 239,
#  'otic': 240,
#  'Ġmild': 241,
#  'Ġchronic': 242,
#  'Ġchanges': 243,
#  't': 244,
#  'uous': 245,
#  '-': 246,
#  'exp': 247,
#  'anded': 248,
#  'Ġidentified': 249,
#  'b': 250,
#  'ilateral': 251,
#  'Ġlarger': 252,
#  'Ġthan': 253,
#  'Ġabnormal': 254,
#  'Ġbe': 255,
#  'Ġdue': 256,
#  'Ġdifferential': 257,
#  'Ġdiagnosis': 258,
#  'Ġincludes': 259,
#  'Ġinfection': 260,
#  'Ġaspiration': 261,
#  'yp': 262,
#  'ical': 263,
#  'Ġdistribution': 264,
#  'Ġed': 265,
#  'ema': 266,
#  'Ġbilateral': 267,
#  'Ġmoderate': 268,
#  'Ġadjacent': 269,
#  'Ġbases': 270,
#  'Ġlimited': 271,
#  'Ġassessment': 272,
#  'Ġobscured': 273,
#  'Ġmargins': 274,
#  'Ġpre': 275,
#  'operative': 276,
#  'chest': 277,
#  'ograph': 278,
#  'Ġstern': 279,
#  'otomy': 280,
#  'Ġcost': 281,
#  'oph': 282,
#  'ren': 283,
#  'Ġexcluded': 284,
#  'Ġimage': 285,
#  'Ġpa': 286,
#  'Ġview': 287,
#  'Ġdegener': 288,
#  'ative': 289,
#  'Ġthroughout': 290,
#  'Ġfinding': 291,
#  'Ġlower': 292,
#  'Ġcervical': 293,
#  'Ġfusion': 294,
#  'Ġold': 295,
#  'Ġhealed': 296,
#  'Ġposterior': 297,
#  'Ġem': 298,
#  'phy': 299,
#  'ma': 300,
#  'Ġad': 301,
#  'en': 302,
#  'opathy': 303,
#  'Ġinter': 304,
#  'stitial': 305,
#  'Ġprominence': 306,
#  'Ġsignificant': 307,
#  'p': 308,
#  'Ġdetail': 309,
#  'Ġsecondary': 310,
#  'Ġbody': 311,
#  'Ġhabit': 312,
#  'Ġsoft': 313,
#  'Ġtissue': 314,
#  'Ġagain': 315,
#  'Ġcompatible': 316,
#  'Ġwith': 317,
#  'Ġsome': 318,
#  'Ġoverall': 319,
#  'Ġslightly': 320,
#  'Ġsmaller': 321,
#  'Ġsince': 322,
#  'Ġchest': 323,
#  'ib': 324,
#  'as': 325,
#  'Ġsub': 326,
#  'gment': 327,
#  'al': 328,
#  'ring': 329,
#  'Ġremain': 330,
#  'Ġhype': 331,
#  'rex': 332,
#  'Ġpersistent': 333,
#  'Ġpost': 334,
#  'Ġprimary': 335,
#  'Ġtuberculosis': 336,
#  'Ġspaces': 337,
#  'interstitial': 338,
#  'Ġmarkings': 339,
#  'Ġfib': 340,
#  'rosis': 341,
#  'Ġunchanged': 342,
#  'Ġred': 343,
#  'emon': 344,
#  'stration': 345,
#  'Ġconsistent': 346,
#  'Ġhistory': 347,
#  'omas': 348,
#  'Ġgreater': 349,
#  'Ġh': 350,
#  'il': 351,
#  'Ġpret': 352,
#  'r': 353,
#  'Ġregion': 354,
#  'Ġt': 355,
#  'Ġthis': 356,
#  'Ġdoes': 357,
#  'Ġlook': 358,
#  'Ġlike': 359,
#  'Ġan': 360,
#  'Ġmore': 361,
#  'un': 362,
#  'rem': 363,
#  'Ġjoint': 364,
#  'Ġair': 365,
#  'Ġprominent': 366,
#  'Ġper': 367,
#  'ard': 368,
#  'ial': 369,
#  'Ġfat': 370,
#  'Ġnoted': 371,
#  'ih': 372,
#  'Ġregions': 373,
#  'Ġoste': 374,
#  'ophy': 375,
#  'tes': 376,
#  'Ġalso': 377,
#  'ifications': 378,
#  'Ġprojecting': 379,
#  'Ġprior': 380,
#  'Ġsequ': 381,
#  'ela': 382,
#  'om': 383,
#  'at': 384,
#  'sp': 385,
#  'ine': 386,
#  'Ġfrontal': 387,
#  'Ġviews': 388,
#  'Ġshow': 389,
#  'Ġthree': 390,
#  'Ġavailable': 391,
#  'Ġreview': 392,
#  'Ġany': 393,
#  'Ġvisible': 394,
#  'Ġfluid': 395,
#  'Ġintra': 396,
#  'per': 397,
#  'itone': 398,
#  'Ġunder': 399,
#  'Ġdi': 400,
#  'aph': 401,
#  'rag': 402,
#  'Ġseveral': 403,
#  'Ġhilar': 404,
#  'Ġnegative': 405,
#  'Ġsurgical': 406,
#  'Ġdist': 407,
#  'Ġcl': 408,
#  'av': 409,
#  'icle': 410,
#  'Ġcardio': 411,
#  'Ġsilhou': 412,
#  'ettes': 413,
#  'Ġexamination': 414,
#  'Ġwas': 415,
#  'Ġobtained': 416,
#  'Ġdemonstrate': 417,
#  'aces': 418,
#  'Ġdensely': 419,
#  'Ġlymph': 420,
#  'Ġsuggest': 421,
#  'Ġhist': 422,
#  'opl': 423,
#  'asm': 424,
#  'Ġexposure': 425,
#  'Ġconsolid': 426,
#  'ating': 427,
#  'Ġconvincing': 428,
#  'Ġif': 429,
#  'Ġsymptoms': 430,
#  'Ġpersist': 431,
#  'Ġrepeat': 432,
#  'Ġstudy': 433,
#  'Ġone': 434,
#  'Ġwere': 435,
#  'Ġpar': 436,
#  'Ġperipheral': 437,
#  'Ġportion': 438,
#  'Ġarter': 439,
#  's': 440,
#  'light': 441,
#  'Ġinflammatory': 442,
#  'Ġchange': 443,
#  'Ġfeatures': 444,
#  'Ġcombination': 445,
#  'Ġstreak': 446,
#  'Ġpatch': 447,
#  'Ġtriangular': 448,
#  'Ġprojected': 449,
#  'Ġdefinite': 450,
#  'Ġtypical': 451,
#  'Ġconsidering': 452,
#  'Ġdifferences': 453,
#  'Ġtechnical': 454,
#  'Ġfactors': 455,
#  'unch': 456,
#  'anged': 457,
#  'Ġplate': 458,
#  'like': 459,
#  'Ġhorizontal': 460,
#  'Ġboth': 461,
#  'Ġthrough': 462,
#  'Ġlob': 463,
#  'Ġcur': 464,
#  'vil': 465,
#  'ear': 466,
#  'Ġalong': 467,
#  'Ġsul': 468,
#  'cus': 469,
#  'Ġskin': 470,
#  'fold': 471,
#  'Ġfracture': 472,
#  'Ġcall': 473,
#  'Ġ9': 474,
#  'th': 475,
#  'iat': 476,
#  'Ġher': 477,
#  'nia': 478,
#  'st': 479,
#  'it': 480,
#  'ium': 481,
#  'Ġcontaining': 482,
#  'Ġsized': 483,
#  'Ġtort': 484,
#  'u': 485,
#  'osity': 486,
#  'Ġ/': 487,
#  'Ġect': 488,
#  'asia': 489,
#  'Ġexaggerated': 490,
#  'Ġk': 491,
#  'ph': 492,
#  'Ġwedge': 493,
#  'Ġ2': 494,
#  'Ġapex': 495,
#  'Ġcurv': 496,
#  'Ġdiffuse': 497,
#  'open': 498,
#  'ia': 499,
#  'Ġrad': 500,
#  'iod': 501,
#  'ense': 502,
#  'Ġforeign': 503,
#  'sided': 504,
#  'Ġdemonstration': 505,
#  'Ġremains': 506,
#  'Ġlevel': 507,
#  'Ġs': 508,
#  'vc': 509,
#  'Ġmass': 510,
#  'Ġlesions': 511,
#  'cle': 512,
#  'ared': 513,
#  'Ġmiddle': 514,
#  'Ġbl': 515,
#  'ting': 516,
#  'Ġhave': 517,
#  'Ġcleared': 518,
#  'Ġinterval': 519,
#  'Ġexpanded': 520,
#  'oper': 521,
#  'Ġbone': 522,
#  'Ġevaluation': 523,
#  'Ġreveals': 524,
#  'Ġzones': 525,
#  'Ġelbow': 526,
#  'Ġforearm': 527,
#  'Ġtraumatic': 528,
#  'Ġankle': 529,
#  'foot': 530,
#  'ane': 531,
#  'Ġent': 532,
#  'hes': 533,
#  'Ġtechnique': 534,
#  'Ġdisl': 535,
#  'ocation': 536,
#  'Ġtissues': 537,
#  'Ġaround': 538,
#  'Ġplant': 539,
#  'te': 540,
#  'Ġmort': 541,
#  'ise': 542,
#  'Ġspecifically': 543,
#  'Ġnote': 544,
#  'Ġclosure': 545,
#  'Ġdevice': 546,
#  'Ġappropriate': 547,
#  'Ġage': 548,
#  'clear': 549,
#  'Ġcentral': 550,
#  'pers': 551,
#  'istent': 552,
#  'Ġsimilar': 553,
#  'Ġimproved': 554,
#  'hyp': 555,
#  'oin': 556,
#  'flation': 557,
#  'Ġling': 558,
#  'Ġang': 559,
#  'ulate': 560,
#  'left': 561,
#  'Ġpic': 562,
#  'c': 563,
#  'Ġincreased': 564,
#  'Ġreflect': 565,
#  'Ġunderlying': 566,
#  'Ġpossibly': 567,
#  'Ġinfectious': 568,
#  'Ġet': 569,
#  'iology': 570,
#  'Ġposts': 571,
#  'urgical': 572,
#  'Ġplease': 573,
#  'Ġthat': 574,
#  'Ġadditional': 575,
#  'Ġimaging': 576,
#  'Ġclinically': 577,
#  'Ġindicated': 578,
#  'Ġcorrelate': 579,
#  'Ġoverlay': 580,
#  'Ġwidening': 581,
#  'Ġcharacteristic': 582,
#  'Ġinjury': 583,
#  'Ġskeletal': 584,
#  'Ġarea': 585,
#  'ob': 586,
#  'ulated': 587,
#  'Ġstripe': 588,
#  'Ġstructure': 589,
#  'Ġenlarged': 590,
#  'Ġnode': 591,
#  'Ġcould': 592,
#  'Ġevaluated': 593,
#  'Ġfurther': 594,
#  'Ġc': 595,
#  'ill': 596,
#  'defined': 597,
#  'long': 598,
#  'Ġbased': 599,
#  'Ġexact': 600,
#  'Ġunclear': 601,
#  'Ġfollow': 602,
#  'up': 603,
#  'Ġsuggested': 604,
#  'Ġconfirm': 605,
#  'Ġclearing': 606,
#  'Ġstability': 607,
#  'Ġill': 608,
#  'Ġsomewhat': 609,
#  'Ġremainder': 610,
#  'Ġbypass': 611,
#  'Ġgraft': 612,
#  'ing': 613,
#  'Ġalthough': 614,
#  'Ġp': 615,
#  'Ġcan': 616,
#  'Ġconfirmation': 617,
#  'Ġcomparison': 618,
#  'Ġstudies': 619,
#  'Ġhas': 620,
#  'Ġoutside': 621,
#  'Ġreport': 622,
#  'Ġadd': 623,
#  'ended': 624,
#  'Ġcritical': 625,
#  'Ġresult': 626,
#  'Ġnotification': 627,
#  'Ġdocumented': 628,
#  'Ġprim': 629,
#  'ordial': 630,
#  'Ġquestions': 631,
#  'Ġregarding': 632,
#  'Ġinterpretation': 633,
#  'Ġ13': 634,
#  'Ġrelatively': 635,
#  'Ġdense': 636,
#  'Ġbut': 637,
#  'Ġobviously': 638,
#  'Ġcorresponding': 639,
#  'Ġseries': 640,
#  'Ġdestruction': 641,
#  'ind': 642,
#  'etermin': 643,
#  'ate': 644,
#  'Ġlocal': 645,
#  'ize': 646,
#  'Ġsuspect': 647,
#  'Ġap': 648,
#  'Ġdimension': 649,
#  'Ġ3': 650,
#  'rd': 651,
#  'Ġ4': 652,
#  'Ġbeyond': 653,
#  'Ġfold': 654,
#  'Ġartifact': 655,
#  'Ġirregular': 656,
#  'Ġind': 657,
#  'em': 658,
#  'mat': 659,
#  'Ġparticularly': 660,
#  'Ġperiphery': 661,
#  'card': 662,
#  'Ġcongestion': 663,
#  'Ġprobable': 664,
#  'stable': 665,
#  'Ġopportunity': 666,
#  'Ġassist': 667,
#  'Ġcare': 668,
#  'Ġyour': 669,
#  'Ġabout': 670,
#  'Ġcertified': 671,
#  'ologist': 672,
#  'Ġbron': 673,
#  'ch': 674,
#  'ov': 675,
#  'ascular': 676,
#  'Ġcrowd': 677,
#  'Ġdeveloping': 678,
#  'Ġles': 679,
#  'ion': 680,
#  'Ġresolution': 681,
#  'Ġrecommended': 682,
#  'Ġquestionable': 683,
#  'Ġextension': 684,
#  'Ġsurface': 685,
#  'small': 686,
#  'Ġearly': 687,
#  'Ġweeks': 688,
#  'Ġhelpful': 689,
#  'f': 690,
#  'ocal': 691,
#  'ula': 692,
#  'Ġpartial': 693,
#  'Ġjunction': 694,
#  'Ġconcerning': 695,
#  'Ġup': 696,
#  'Ġensure': 697,
#  'Ġchronically': 698,
#  'xxxx': 699,
#  'low': 700,
#  'Ġvolume': 701,
#  'Ġmildly': 702,
#  'negative': 703,
#  'ations': 704,
#  'prom': 705,
#  'inent': 706,
#  'Ġovert': 707,
#  'Ġch': 708,
#  'Ġsen': 709,
#  'escent': 710,
#  'Ġknown': 711,
#  'Ġdated': 712,
#  'Ġsuspicious': 713,
#  'Ġmult': 714,
#  'ile': 715,
#  'vel': 716,
#  'Ġdisc': 717,
#  'Ġde': 718,
#  'xt': 719,
#  'roc': 720,
#  'ur': 721,
#  'ographs': 722,
#  'Ġafter': 723,
#  'Ġtherapy': 724,
#  'Ġ8': 725,
#  '12': 726,
#  'Ġlord': 727,
#  'Ġbefore': 728,
#  'Ġanticipated': 729,
#  'chi': 730,
#  'ect': 731,
#  'ent': 732,
#  'Ġhere': 733,
#  'Ġassociated': 734,
#  'Ġperhaps': 735,
#  'Ġslight': 736,
#  'Ġprogression': 737,
#  'Ġscattered': 738,
#  'soft': 739,
#  'Ġneck': 740,
#  'Ġfailure': 741,
#  'way': 742,
#  'Ġl': 743,
#  'aryn': 744,
#  'ge': 745,
#  'ah': 746,
#  'Ġhyper': 747,
#  'lucent': 748,
#  'Ġhyp': 749,
#  'fl': 750,
#  'ated': 751,
#  'Ġapparent': 752,
#  'Ġprojection': 753,
#  'Ġimmediately': 754,
#  'Ġretro': 755,
#  'iac': 756,
#  'Ġconf': 757,
#  'luence': 758,
#  'Ġoverlapping': 759,
#  'Ġshadows': 760,
#  'Ġoverl': 761,
#  'ies': 762,
#  'Ġcommon': 763,
#  'Ġduct': 764,
#  'uture': 765,
#  'Ġmaterial': 766,
#  'Ġsuggesting': 767,
#  'Ġsurgery': 768,
#  'Ġsignificantly': 769,
#  'Ġar': 770,
#  'ritic': 771,
#  'ron': 772,
#  'Ġversus': 773,
#  'Ġreflecting': 774,
#  'Ġconcern': 775,
#  'Ġcm': 776,
#  'Ġother': 777,
#  'Ġabdomen': 778,
#  'Ġscan': 779,
#  'Ġ40': 780,
#  'Ġ%': 781,
#  'Ġcav': 782,
#  'itary': 783,
#  'Ġparamed': 784,
#  'moderate': 785,
#  'Ġloc': 786,
#  'Ġrotation': 787,
#  'normal': 788,
#  'Ġdestructive': 789,
#  'cal': 790,
#  'Ġappearing': 791,
#  'Ġconsists': 792,
#  'ura': 793,
#  'Ġclinical': 794,
#  'Ġsetting': 795,
#  'Ġobsc': 796,
#  'uration': 797,
#  'Ġexpected': 798,
#  'Ġlocation': 799,
#  'Ġnotably': 800,
#  'Ġnotable': 801,
#  'Ġdemonstrates': 802,
#  'Ġfew': 803,
#  'Ġband': 804,
#  'Ġclips': 805,
#  'Ġquad': 806,
#  'rant': 807,
#  'Ġnone': 808,
#  'Ġ6': 809,
#  'Ġmonths': 810,
#  'Ġaccessory': 811,
#  'zy': 812,
#  'Ġf': 813,
#  'iss': 814,
#  'ure': 815,
#  'Ġsevere': 816,
#  'Ġwed': 817,
#  'ging': 818,
#  'Ġapproximately': 819,
#  '1': 820,
#  'Ġhigh': 821,
#  'red': 822,
#  'Ġelevated': 823,
#  'Ġhe': 824,
#  'mid': 825,
#  'oat': 826,
#  'rial': 827,
#  'Ġelevation': 828,
#  'Ġthese': 829,
#  'Ġdrainage': 830,
#  'Ġcat': 831,
#  'heter': 832,
#  'Ġthick': 833,
#  'ening': 834,
#  'app': 835,
#  'arent': 836,
#  'Ġconfiguration': 837,
#  'diff': 838,
#  'use': 839,
#  'there': 840,
#  'Ġflowing': 841,
#  'Ġid': 842,
#  'ost': 843,
#  'Ġ(': 844,
#  'Ġdish': 845,
#  'Ġ)': 846,
#  'inter': 847,
#  'val': 848,
#  'Ġenlarg': 849,
#  'ement': 850,
#  'Ġhighly': 851,
#  'Ġmal': 852,
#  'ign': 853,
#  'ancy': 854,
#  'Ġintraven': 855,
#  'Ġcontrast': 856,
#  'Ġdr': 857,
#  'Ġnotified': 858,
#  'Ġresults': 859,
#  'Ġby': 860,
#  'Ġtelephone': 861,
#  'Ġacknowledged': 862,
#  'Ġreceipt': 863,
#  'Ġmeasuring': 864,
#  '.': 865,
#  '5': 866,
#  '8': 867,
#  'Ġne': 868,
#  'h': 869,
#  'ype': 870,
#  'Ġexaminations': 871,
#  'Ġreveal': 872,
#  'Ġassess': 873,
#  'Ġinf': 874,
#  'rah': 875,
#  'Ġ5': 876,
#  'Ġcircum': 877,
#  'scribed': 878,
#  'Ġcar': 879,
#  'atum': 880,
#  'Ġnumerous': 881,
#  'let': 882,
#  'to': 883,
#  'Ġshift': 884,
#  'Ġmeasures': 885,
#  'Ġbroken': 886,
#  'Ġ1': 887,
#  'Ġ-': 888,
#  'atures': 889,
#  'ways': 890,
#  'position': 891,
#  'Ġcolon': 892,
#  'Ġumb': 893,
#  'Ġpiercing': 894,
#  'Ġshape': 895,
#  'Ġpreviously': 896,
#  'Ġ<': 897,
#  'br': 898,
#  '>': 899,
#  'Ġdescribed': 900,
#  'cut': 901,
#  'aneous': 902,
#  'Ġsh': 903,
#  'unt': 904,
#  'Ġtubing': 905,
#  'Ġwall': 906,
#  'Ġinability': 907,
#  'the': 908,
#  '3': 909,
#  'Ġdetermine': 910,
#  'Ġaer': 911,
#  'Ġarteries': 912,
#  'Ġraising': 913,
#  'Ġquestion': 914,
#  'Ġhypertension': 915,
#  'Ġnon': 916,
#  'Ġcrowded': 917,
#  'Ġsup': 918,
#  'Ġevent': 919,
#  'ration': 920,
#  'Ġnons': 921,
#  'pe': 922,
#  'cific': 923,
#  'Ġcx': 924,
#  'Ġtechnically': 925,
#  'Ġdecreased': 926,
#  'op': 927,
#  'Ġbreast': 928,
#  'Ġoverlap': 929,
#  'ices': 930,
#  'Ġobscure': 931,
#  'Ġstatus': 932,
#  'changes': 933,
#  'd': 934,
#  'Ġplacement': 935,
#  'status': 936,
#  'Ġreduced': 937,
#  'Ġsuspicion': 938,
#  'pre': 939,
#  'viously': 940,
#  'Ġtoday': 941,
#  'Ġdefinitive': 942,
#  'third': 943,
#  'ronic': 944,
#  'Ġbull': 945,
#  'ae': 946,
#  'es': 947,
#  'Ġworse': 948,
#  'Ġcollections': 949,
#  'multiple': 950,
#  'Ġcorrelation': 951,
#  'Ġperformed': 952,
#  'Ġartery': 953,
#  'Ġexample': 954,
#  'Ġ12': 955,
#  'Ġcannot': 956,
#  'pen': 957,
#  'et': 958,
#  'rated': 959,
#  'Ġloss': 960,
#  'Ġtumor': 961,
#  'Ġhem': 962,
#  'ith': 963,
#  'ward': 964,
#  'Ġwarranted': 965,
#  'rosc': 966,
#  'pected': 967,
#  'Ġobstruct': 968,
#  'ive': 969,
#  'Ġcharacterization': 970,
#  'Ġsuggestive': 971,
#  'Ġtreatment': 972,
#  'Ġcomplete': 973,
#  'Ġresidual': 974,
#  'Ġmedial': 975,
#  'Ġfeeding': 976,
#  'Ġtube': 977,
#  'Ġpasses': 978,
#  'Ġbelow': 979,
#  'cl': 980,
#  'ian': 981,
#  'Ġline': 982,
#  'Ġcourses': 983,
#  'Ġprost': 984,
#  'hetic': 985,
#  'Ġhum': 986,
#  'eral': 987,
#  'Ġhead': 988,
#  'Ġcal': 989,
#  'Ġzone': 990,
#  'Ġwould': 991,
#  'Ġdiscuss': 992,
#  'Ġcase': 993,
#  'Ġthanks': 994,
#  'Ġsymm': 995,
#  'etr': 996,
#  'ically': 997,
#  'Ġevident': 998,
#  'etric': 999,
#  'Ġtwo': 1000,
#  ...}

# %%
def get_print_gpt(img_name, visualize=True, print_res=True):
    parser = argparse.ArgumentParser(description='Show, Attend, and Tell - Tutorial - Generate Caption')
    parser.add_argument('--img', '-i', default=f'/home/dchesakov/NLMCXR_data/images/{img_name}.png', help='path to image')
    parser.add_argument('--model', '-m', default='BEST_checkpoint_NLMCXR_vgpt_1_cap_per_img_0_min_word_freq.pth.tar', help='path to model')
    parser.add_argument('--word_map', '-wm', default='/home/dchesakov/NLMCXR_data/WORDMAP_NLMCXR_vgpt_1_cap_per_img_0_min_word_freq.json',  help='path to word map JSON')
    parser.add_argument('--beam_size', '-b', default=5, type=int, help='beam size for beam search')
    parser.add_argument('--dont_smooth', dest='smooth', action='store_false', help='do not smooth alpha overlay')
    
    args = args = parser.parse_args('')
    
    checkpoint = torch.load(args.model)
    decoder = checkpoint['decoder']
    decoder = decoder.to(device)
    decoder.eval()
    encoder = checkpoint['encoder']
    encoder = encoder.to(device)
    encoder.eval()

    # Load word map (word2ix)
    with open(args.word_map, 'r') as j:
        word_map = json.load(j)
    rev_word_map = {v: k for k, v in word_map.items()}  # ix2word

    # Encode, decode with attention and beam search
    seq, alphas = caption_image_beam_search_gpt(encoder, decoder, args.img, word_map, args.beam_size)
    alphas = torch.FloatTensor(alphas)
    
    if print_res:
        print(asd[ asd['images'] == f'{img_name}']['processed_findings'].iloc[0])

    # Visualize caption and attention of best sequence
    words = visualize_att_gpt(args.img, seq, alphas, rev_word_map, args.smooth, visualize=visualize)
    
    return words

# %%
import pandas as pd

# %%
asd = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_df.pkl')

# %%
def train_validate_test_split(df, train_percent=.6, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test

all_reports_df = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_tags_df.pkl')
    # all_reports_df = all_reports_df[ all_reports_df['processed_findings'].notnull() ]
# train_df, val_df, test_df = train_validate_test_split(all_reports_df, .9, .05, seed=42)
train_df = all_reports_df[:-600]
val_df = all_reports_df[-600:-300]
test_df = all_reports_df[-300:]

# %%
# all_reports_df = pd.read_pickle('/home/dchesakov/NLMCXR_data/all_reports_df.pkl')
# all_reports_df['processed_captions'] = [eval(cap) for cap in all_reports_df['processed_captions']]
# all_reports_df = all_reports_df[ all_reports_df['processed_findings'].notnull() ]

# train_df = all_reports_df[:-600]
# val_df = all_reports_df[-600:-300]
# test_df = all_reports_df[-300:]

# %%
get_print_gpt('CXR2992_IM-1379-2002')
# Out:
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ['the lungs are clear', 'heart size is normal', 'no pneumothorax', 'calcified granuloma within the right lung base']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġdisease', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['no',
#  'acute',
#  'cardiopulmonary',
#  'disease',
#  '.',
#  'the',
#  'heart',
#  'is',
#  'normal',
#  'in',
#  'size',
#  '.',
#  'the',
#  'mediastinum',
#  'is',
#  'unremarkable',
#  '.',
#  'the',
#  'lungs',
#  'are',
#  'clear',
#  '.']

# %%
get_print('CXR2992_IM-1379-2002')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-524d7b9d6bbc> in <module>
# ----> 1 get_print('CXR2992_IM-1379-2002')
#
# NameError: name 'get_print' is not defined

# %%
train_df.head(3)
# Out:
#                       images  \
# 0       CXR2357_IM-0921-1001
# 1       CXR2357_IM-0921-2001
# 0  CXR3620_IM-1791-1001-0001
#
#                                             FINDINGS  \
# 0  Cardiomediastinal silhouette and pulmonary vas...
# 1  Cardiomediastinal silhouette and pulmonary vas...
# 0  The cardiac silhouette is near upper limits of...
#
#                                           IMPRESSION  \
# 0                 No acute cardiopulmonary findings.
# 1                 No acute cardiopulmonary findings.
# 0  1. Minimal left basilar atelectasis or scar. 2...
#
#                                           tags_major  \
# 0                                           [normal]
# 1                                           [normal]
# 0  [pulmonary atelectasis, base, left, mild, cica...
#
#                                       tags_automatic  \
# 0                                                 []
# 1                                                 []
# 0  [atelectases, calcified granuloma, scar, atele...
#
#                                report  \
# 0  ./reports/ecgen-radiology/2357.xml
# 1  ./reports/ecgen-radiology/2357.xml
# 0  ./reports/ecgen-radiology/3620.xml
#
#                                          full_report  \
# 0  No acute cardiopulmonary findings. Cardiomedia...
# 1  No acute cardiopulmonary findings. Cardiomedia...
# 0  1. Minimal left basilar atelectasis or scar. 2...
#
#                                   processed_captions  \
# 0  [no acute cardiopulmonary findings, cardiomedi...
# 1  [no acute cardiopulmonary findings, cardiomedi...
# 0  [minimal left basilar atelectasis or scar, no ...
#
#                                   processed_findings  \
# 0  [cardiomediastinal silhouette and pulmonary va...
# 1  [cardiomediastinal silhouette and pulmonary va...
# 0  [the cardiac silhouette is near upper limits o...
#
#                             preprocessed_full_report
# 0  no acute cardiopulmonary findings . cardiomedi...
# 1  no acute cardiopulmonary findings . cardiomedi...
# 0  minimal left basilar atelectasis or scar . no ...

# %%
test_df.head(3)
# Out:
#                  images                                           FINDINGS  \
# 1  CXR1484_IM-0313-2001  Calcified left lower lobe granuloma. No focal ...
# 0  CXR2767_IM-1212-1001  Lungs are clear. No pleural effusion or pneumo...
# 1  CXR2767_IM-1212-2001  Lungs are clear. No pleural effusion or pneumo...
#
#                               IMPRESSION  \
# 1  No acute cardiopulmonary abnormality.
# 0         No evidence of active disease.
# 1         No evidence of active disease.
#
#                                           tags_major  \
# 1  [calcified granuloma, lung, lower lobe, left, ...
# 0                        [spine, degenerative, mild]
# 1                        [spine, degenerative, mild]
#
#                      tags_automatic                              report  \
# 1  [degenerative change, granuloma]  ./reports/ecgen-radiology/1484.xml
# 0             [degenerative change]  ./reports/ecgen-radiology/2767.xml
# 1             [degenerative change]  ./reports/ecgen-radiology/2767.xml
#
#                                          full_report  \
# 1  No acute cardiopulmonary abnormality. Calcifie...
# 0  No evidence of active disease. Lungs are clear...
# 1  No evidence of active disease. Lungs are clear...
#
#                                   processed_captions  \
# 1  [no acute cardiopulmonary abnormality, calcifi...
# 0  [no evidence of active disease, lungs are clea...
# 1  [no evidence of active disease, lungs are clea...
#
#                                   processed_findings  \
# 1  [calcified left lower lobe granuloma, no focal...
# 0  [lungs are clear, no pleural effusion or pneum...
# 1  [lungs are clear, no pleural effusion or pneum...
#
#                             preprocessed_full_report
# 1  no acute cardiopulmonary abnormality . calcifi...
# 0  no evidence of active disease . lungs are clea...
# 1  no evidence of active disease . lungs are clea...

# %%
test_predicts = []
test_images = test_df.images.values

# %%
train_predicts = []
train_images = train_df.images.values

# %%
from tqdm import tqdm_notebook

# %%
# for img_name in tqdm_notebook(train_images):
#     words = get_print(img_name, visualize=False, print_res=False)
#     train_predicts.append(words)

# %%
get_print_gpt(test_images[0], visualize=False, print_res=False)
# Out:
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['no',
#  'acute',
#  'cardiopulmonary',
#  'abnormalities',
#  '.',
#  'the',
#  'heart',
#  'is',
#  'normal',
#  'in',
#  'size',
#  '.',
#  'the',
#  'mediastinum',
#  'is',
#  'unremarkable',
#  '.',
#  'the',
#  'lungs',
#  'are',
#  'clear',
#  '.']

# %%
max_len = 100

# %%
test_image_captions = [[sents.split()][:max_len] for sents in test_df['preprocessed_full_report']]

# %%
err_idx = []
ok_idx = []

for i, img_name in tqdm_notebook(enumerate(test_images)):
    try:
        words = get_print_gpt(img_name, visualize=False, print_res=False)
        test_predicts.append(words)
        ok_idx.append(i)
    except:
        err_idx.append(i)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġcard', 'i', 'omed', 'i', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġwithin', 'Ġnormal', 'Ġlimits', 'Ġfor', 'Ġsize', 'Ġand', 'Ġcont', 'our', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', 'Ġno', 'Ġpneum', 'oth', 'or', 'ax', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġdisease', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġb', 'ilaterally', 'Ġ.', 'Ġspecifically', 'Ġ,', 'Ġno', 'Ġevidence', 'Ġof', 'Ġfocal', 'Ġconsolidation', 'Ġ,', 'Ġpneum', 'oth', 'or', 'ax', 'Ġ,', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', 'Ġcardio', 'Ġmedi', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġcard', 'i', 'omed', 'i', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġwithin', 'Ġnormal', 'Ġlimits', 'Ġfor', 'Ġsize', 'Ġand', 'Ġcont', 'our', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', 'Ġno', 'Ġpneum', 'oth', 'or', 'ax', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġdisease', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġdisease', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġb', 'ilaterally', 'Ġ.', 'Ġspecifically', 'Ġ,', 'Ġno', 'Ġevidence', 'Ġof', 'Ġfocal', 'Ġconsolidation', 'Ġ,', 'Ġpneum', 'oth', 'or', 'ax', 'Ġ,', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', 'Ġcardio', 'Ġmedi', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġb', 'ilaterally', 'Ġ.', 'Ġspecifically', 'Ġ,', 'Ġno', 'Ġevidence', 'Ġof', 'Ġfocal', 'Ġconsolidation', 'Ġ,', 'Ġpneum', 'oth', 'or', 'ax', 'Ġ,', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', 'Ġcardio', 'Ġmedi', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġb', 'ilaterally', 'Ġ.', 'Ġspecifically', 'Ġ,', 'Ġno', 'Ġevidence', 'Ġof', 'Ġfocal', 'Ġconsolidation', 'Ġ,', 'Ġpneum', 'oth', 'or', 'ax', 'Ġ,', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', 'Ġcardio', 'Ġmedi', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġcard', 'i', 'omed', 'i', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġwithin', 'Ġnormal', 'Ġlimits', 'Ġfor', 'Ġsize', 'Ġand', 'Ġcont', 'our', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnorm', 'ality', 'Ġ.', 'Ġthe', 'Ġcard', 'i', 'omed', 'i', 'ast', 'inal', 'Ġsilhouette', 'Ġis', 'Ġwithin', 'Ġnormal', 'Ġlimits', 'Ġfor', 'Ġsize', 'Ġand', 'Ġcont', 'our', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', 'Ġno', 'Ġpneum', 'oth', 'or', 'ax', 'Ġor', 'Ġple', 'ural', 'Ġeff', 'usion', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġabnormalities', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']
# ['<start>', 'no', 'Ġacute', 'Ġcard', 'iop', 'ul', 'monary', 'Ġdisease', 'Ġ.', 'Ġthe', 'Ġheart', 'Ġis', 'Ġnormal', 'Ġin', 'Ġsize', 'Ġ.', 'Ġthe', 'Ġmedi', 'ast', 'in', 'um', 'Ġis', 'Ġunrem', 'arkable', 'Ġ.', 'Ġthe', 'Ġlungs', 'Ġare', 'Ġclear', 'Ġ.', '<end>']

# %%
max_len = 100

test_image_captions = [[sents.split()][:max_len] for sents in test_df['preprocessed_full_report']]

# %%
for img_name in tqdm_notebook(test_images):
    try:
        image_path = f'/home/dchesakov/NLMCXR_data/images/{img_name}.png'
        a, b = caption_image_beam_search_gpt(encoder, decoder, image_path, word_map, beam_size=3) 
        break
    except:
        pass
# Out:
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /home/dchesakov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
model

# %%
# get_print_gpt(img_name, visualize=False, print_res=False)

# %%
test_predicts[126]
# Out:
# ['no',
#  'acute',
#  'cardiopulmonary',
#  'abnormality',
#  '.',
#  'the',
#  'cardiomediastinal',
#  'silhouette',
#  'and',
#  'pulmonary',
#  'vasculature',
#  'are',
#  'within',
#  'normal',
#  'limits',
#  '.',
#  'there',
#  'is',
#  'no',
#  'pneumothorax',
#  'or',
#  'pleural',
#  'effusion',
#  '.',
#  'there',
#  'are',
#  'no',
#  'focal',
#  'areas',
#  'of',
#  'consolidation',
#  '.']

# %%
test_image_captions[126]
# Out:
# [['no',
#   'cardiopulmonary',
#   'abnormality',
#   '.',
#   'heart',
#   'size',
#   'is',
#   'within',
#   'normal',
#   'limits',
#   '.',
#   'cardiomediastinal',
#   'silhouette',
#   'is',
#   'normal',
#   '.',
#   'lungs',
#   'are',
#   'clear',
#   'bilaterally',
#   'without',
#   'effusion',
#   'or',
#   'pneumothorax',
#   '.',
#   'no',
#   'bony',
#   'or',
#   'soft',
#   'tissue',
#   'abnormalities',
#   '.']]

# %%
evalscores(test_predicts, test_image_captions)
# Out:
# Bleu_1: 0.234
# Bleu_2: 0.148
# Bleu_3: 0.101
# Bleu_4: 0.071
# ROUGE_L: 0.271
# CIDEr: 0.275

# %%
[[word_map['<start>']]] * 10
# Out:
# [[2394],
#  [2394],
#  [2394],
#  [2394],
#  [2394],
#  [2394],
#  [2394],
#  [2394],
#  [2394],
#  [2394]]
