# %%
import argparse
import sys 
import pandas as pd
import numpy as np

sys.path.append('/home/dchesakov/fairseq-image-captioning')

import data
import json
import os
import tqdm

from sacremoses import MosesTokenizer


def load_annotations(coco_dir):
    with open(os.path.join(coco_dir, 'annotations', f'captions_train2014.json')) as f:
        annotations = json.load(f)['annotations']

    with open(os.path.join(coco_dir, 'annotations', f'captions_val2014.json')) as f:
        annotations.extend(json.load(f)['annotations'])

    return annotations


def select_captions(annotations, image_ids):
    """Select captions of given image_ids and return them with their image IDs.
    """

    # for fast lookup
    image_ids = set(image_ids)

    captions = []
    caption_image_ids = []

    for annotation in annotations:
        image_id = annotation['image_id']
        if image_id in image_ids:
            captions.append(annotation['caption'].replace('\n', ''))
            caption_image_ids.append(image_id)

    return captions, caption_image_ids


def tokenize_captions(captions, lang='en'):
    """Tokenizes captions list with Moses tokenizer.
    """

    tokenizer = MosesTokenizer(lang=lang)
    return [tokenizer.tokenize(caption, return_str=True) for caption in captions]


def write_captions(captions, filename, lowercase=True):
    with open(filename, 'w') as f:
        for caption in captions:
            if lowercase:
                caption = caption.lower()
            f.write(caption + '\n')


def write_image_ids(image_ids, filename):
    with open(filename, 'w') as f:
        for image_id in image_ids:
            f.write(f'{image_id}\n')


def main(args):
    os.makedirs(args.output_dir, exist_ok=True)

    # Load annotations of MS-COCO training and validation set
    annotations = load_annotations(args.ms_coco_dir)

    # Read image ids of given split
    image_ids = data.read_split_image_ids(args.split)

    # Select captions and their image IDs from annotations
    captions, caption_image_ids = select_captions(annotations, image_ids)

    print('Tokenize captions ...')
    captions = tokenize_captions(tqdm.tqdm(captions))

    captions_filename = os.path.join(args.output_dir, f'{args.split}-captions.tok.en')
    caption_image_ids_filename = os.path.join(args.output_dir, f'{args.split}-ids.txt')

    write_captions(captions, captions_filename)
    print(f'Wrote tokenized captions to {captions_filename}.')

    write_image_ids(caption_image_ids, caption_image_ids_filename)
    print(f'Wrote caption image IDs to {caption_image_ids_filename}.')

# %%
annotations = load_annotations('/home/dchesakov/fairseq-image-captioning/ms-coco')

# %%
# Out:
# [{'image_id': 318556,
#   'id': 48,
#   'caption': 'A very clean and well decorated empty bathroom'},
#  {'image_id': 116100,
#   'id': 67,
#   'caption': 'A panoramic view of a kitchen and all of its appliances.'},
#  {'image_id': 318556,
#   'id': 126,
#   'caption': 'A blue and white bathroom with butterfly themed wall tiles.'},
#  {'image_id': 116100,
#   'id': 148,
#   'caption': 'A panoramic photo of a kitchen and dining room'},
#  {'image_id': 379340,
#   'id': 173,
#   'caption': 'A graffiti-ed stop sign across the street from a red car '},
#  {'image_id': 379340,
#   'id': 188,
#   'caption': 'A vandalized stop sign and a red beetle on the road'},
#  {'image_id': 318556,
#   'id': 219,
#   'caption': 'A bathroom with a border of butterflies and blue paint on the walls above it.'},
#  {'image_id': 318556,
#   'id': 255,
#   'caption': 'An angled view of a beautifully decorated bathroom.'},
#  {'image_id': 134754,
#   'id': 272,
#   'caption': 'The two people are walking down the beach.'},
#  {'image_id': 538480,
#   'id': 288,
#   'caption': 'A sink and a toilet inside a small bathroom.'},
#  {'image_id': 476220,
#   'id': 314,
#   'caption': 'An empty kitchen with white and black appliances.'},
#  {'image_id': 299675,
#   'id': 328,
#   'caption': 'A white square kitchen with tile floor that needs repairs '},
#  {'image_id': 32275,
#   'id': 352,
#   'caption': 'The vanity contains two sinks with a towel for each.'},
#  {'image_id': 302443,
#   'id': 411,
#   'caption': 'Several metal balls sit in the sand near a group of people.'},
#  {'image_id': 134754,
#   'id': 425,
#   'caption': 'Two people carrying surf boards on a beach.'},
#  {'image_id': 25470,
#   'id': 519,
#   'caption': 'A kitchen with brown cabinets, tile backsplash, and grey counters.'},
#  {'image_id': 513461,
#   'id': 572,
#   'caption': 'A surfer, a woman, and a child walk on the beach.'},
#  {'image_id': 18691,
#   'id': 653,
#   'caption': 'A few people sit on a dim transportation system. '},
#  {'image_id': 285579,
#   'id': 668,
#   'caption': 'A person, protected from the rain by their umbrella, walks down the road.'},
#  {'image_id': 266366,
#   'id': 674,
#   'caption': 'The bathroom with a toilet has an interesting sink.'},
#  {'image_id': 226658,
#   'id': 710,
#   'caption': 'Two women preparing food in a kitchen, one at the sink and one at the table'},
#  {'image_id': 299675,
#   'id': 715,
#   'caption': 'A white kitchen in a home with the light on.'},
#  {'image_id': 124567,
#   'id': 729,
#   'caption': 'A cat stuck in a car with a slightly opened window.'},
#  {'image_id': 293605,
#   'id': 750,
#   'caption': 'Two bicycles and a woman walking in front of a shop'},
#  {'image_id': 321194,
#   'id': 760,
#   'caption': 'Green tiled backsplash highlighted by low overhead lighting.'},
#  {'image_id': 479495,
#   'id': 764,
#   'caption': 'A bicycle is parked by a bench at night.'},
#  {'image_id': 539984,
#   'id': 818,
#   'caption': 'A brown horse is grazing grass near a red house.'},
#  {'image_id': 28231,
#   'id': 819,
#   'caption': 'A black car is near someone riding a bike.'},
#  {'image_id': 538480,
#   'id': 873,
#   'caption': 'White pedestal sink and toilet located in a poorly lit bathroom.'},
#  {'image_id': 350235,
#   'id': 877,
#   'caption': 'This is a pick-up game of shirts and skins basketball'},
#  {'image_id': 314265,
#   'id': 928,
#   'caption': 'A toilet, sink, bathtub with shower, mirror and cabinet\n'},
#  {'image_id': 389006,
#   'id': 946,
#   'caption': 'A kitchen with a countertop that includes an Apple phone.'},
#  {'image_id': 134754,
#   'id': 1022,
#   'caption': 'Two teenagers at a white sanded beach with surfboards.'},
#  {'image_id': 31813,
#   'id': 1029,
#   'caption': 'A surfer riding his bike to the beach.'},
#  {'image_id': 538480,
#   'id': 1098,
#   'caption': 'Clean indoor bathroom with tiled floor and good lighting.'},
#  {'image_id': 465049,
#   'id': 1124,
#   'caption': 'A closeup of a red fire hydrant including the chains.'},
#  {'image_id': 360334,
#   'id': 1161,
#   'caption': 'A man standing in the kitchen with his arms crossed'},
#  {'image_id': 524679,
#   'id': 1184,
#   'caption': 'A purple bus and a man dressed as a nun on a tall bicycle.'},
#  {'image_id': 279672,
#   'id': 1193,
#   'caption': 'An herb that is in front of a toaster oven.'},
#  {'image_id': 385716,
#   'id': 1199,
#   'caption': 'Lady carrying a purse walking along side a man.'},
#  {'image_id': 44816,
#   'id': 1231,
#   'caption': 'Clean bathroom that is brightly colored and has a window'},
#  {'image_id': 116100,
#   'id': 1273,
#   'caption': 'A wide angle view of the kitchen work area'},
#  {'image_id': 302443,
#   'id': 1419,
#   'caption': 'People standing around many silver round balls on the ground.'},
#  {'image_id': 360306,
#   'id': 1450,
#   'caption': 'A man working at a kitchen counter in a room illuminated by sunlight.'},
#  {'image_id': 122802,
#   'id': 1502,
#   'caption': 'A man standing in a kitchen with granite countertops.'},
#  {'image_id': 539984,
#   'id': 1532,
#   'caption': 'A skinny horse is grazing in a field.'},
#  {'image_id': 28231,
#   'id': 1533,
#   'caption': 'A person on a bicycle is riding in front of a car.  '},
#  {'image_id': 515040,
#   'id': 1537,
#   'caption': 'Seagulls flying overhead while trucks sit in a parking lot.'},
#  {'image_id': 299675,
#   'id': 1558,
#   'caption': 'A kitchen with a tile floor has cabinets with no doors, a dishwasher, a sink, and a refrigerator.'},
#  {'image_id': 161657,
#   'id': 1561,
#   'caption': 'A modern bathroom contains many glass and tile pieces'},
#  {'image_id': 266366,
#   'id': 1568,
#   'caption': 'A demonstration of a well maintained hotel bathroom'},
#  {'image_id': 72704,
#   'id': 1599,
#   'caption': 'A black cat making an angry face while sitting on the bathroom floor '},
#  {'image_id': 266366,
#   'id': 1607,
#   'caption': 'A clean, mediocre motel bathroom with a nice sink.'},
#  {'image_id': 321194,
#   'id': 1609,
#   'caption': 'A kitchen counter is illuminated by a hood light'},
#  {'image_id': 385716,
#   'id': 1628,
#   'caption': 'A city sidewalk is lined with lamp posts'},
#  {'image_id': 28149,
#   'id': 1670,
#   'caption': 'A bathroom with a TV near the mirror'},
#  {'image_id': 257263,
#   'id': 1717,
#   'caption': 'A public restroom toilet has been photographed in sepia'},
#  {'image_id': 520049,
#   'id': 1749,
#   'caption': 'Photo of a man riding an old styled bicycle near what appears to be the Golden Gate Bridge.'},
#  {'image_id': 124567,
#   'id': 1797,
#   'caption': 'A cat peeking out a car window that is rolled down'},
#  {'image_id': 503598,
#   'id': 1848,
#   'caption': 'There is some pet food in the floor in an empty kitchen'},
#  {'image_id': 230843,
#   'id': 1868,
#   'caption': 'A young boy surfing  in low waves.'},
#  {'image_id': 231029,
#   'id': 1900,
#   'caption': 'The top of a kitchen cabinet covered with brass pots and pans.'},
#  {'image_id': 174028,
#   'id': 1930,
#   'caption': 'A woman is shaving her face while sitting on a wooden bench.'},
#  {'image_id': 480489,
#   'id': 1954,
#   'caption': 'The sky is full of colorful kites along a mountain.'},
#  {'image_id': 520049,
#   'id': 1986,
#   'caption': 'A man rides a bicycle across the river. '},
#  {'image_id': 385716,
#   'id': 1994,
#   'caption': 'A man and a woman stand on the sidewalk lined with street lights.'},
#  {'image_id': 538480,
#   'id': 2067,
#   'caption': 'a bathroom with toilet and sink and blue wall'},
#  {'image_id': 56972,
#   'id': 2101,
#   'caption': 'A bathroom in white has a cupboard above the sink.'},
#  {'image_id': 187042,
#   'id': 2189,
#   'caption': 'A bike and a raft sit atop a boat on the water.'},
#  {'image_id': 31813,
#   'id': 2199,
#   'caption': 'a surfer rides his bike down the street'},
#  {'image_id': 101891,
#   'id': 2214,
#   'caption': 'Bicycles, cars and a trash can in a garage.'},
#  {'image_id': 360306,
#   'id': 2215,
#   'caption': 'A man in shorts standing at the kitchen sink.'},
#  {'image_id': 124567,
#   'id': 2256,
#   'caption': 'A cat standing on a car seat looking out the car window.'},
#  {'image_id': 90359,
#   'id': 2295,
#   'caption': 'A man jumping his bicycle onto a bench.'},
#  {'image_id': 360334,
#   'id': 2418,
#   'caption': 'young man with folded arms standing in the kitchen '},
#  {'image_id': 90359,
#   'id': 2490,
#   'caption': 'A man balancing a bike on a bench.'},
#  {'image_id': 213532,
#   'id': 2519,
#   'caption': 'Black and white image of two children paying attention. '},
#  {'image_id': 302443,
#   'id': 2547,
#   'caption': 'Silver balls are lined up in the sand as people mill about in the background.'},
#  {'image_id': 24091,
#   'id': 2560,
#   'caption': 'A compact car with bicycles mounted on the roof. '},
#  {'image_id': 302443,
#   'id': 2574,
#   'caption': 'Silver balls on sand with people walking around. '},
#  {'image_id': 372427,
#   'id': 2589,
#   'caption': 'A crisp neutral bathroom embellished with modern treatments.'},
#  {'image_id': 376047,
#   'id': 2609,
#   'caption': 'A kitchen scene with stainless steel appliance and a checkered pattern floor.'},
#  {'image_id': 577876,
#   'id': 2646,
#   'caption': 'A lady talking a self portrait in a fancy bathroom.'},
#  {'image_id': 47093,
#   'id': 2671,
#   'caption': 'A woman walking and talking on a cell phone.'},
#  {'image_id': 266366,
#   'id': 2678,
#   'caption': 'A modern hotel bathroom with accessories set out.'},
#  {'image_id': 299675,
#   'id': 2689,
#   'caption': 'A white kitchen without doors on the cabinets.'},
#  {'image_id': 374873,
#   'id': 2736,
#   'caption': 'A man on top of a snowy mountain with skis.'},
#  {'image_id': 32275,
#   'id': 2755,
#   'caption': 'A clean restroom with towels and washcloths laid out.'},
#  {'image_id': 360334,
#   'id': 2772,
#   'caption': 'A man standing in a white kitchen with his arms folded.'},
#  {'image_id': 360053,
#   'id': 2806,
#   'caption': 'A stuffed animal is laying on the bed by a window.'},
#  {'image_id': 25470,
#   'id': 2823,
#   'caption': 'A kitchen contains black countertops, brown cabinets, and a red and white tile blacksplash.'},
#  {'image_id': 517565,
#   'id': 2898,
#   'caption': 'A wooden toilet seat sits open in an empty bathroom.'},
#  {'image_id': 543882,
#   'id': 2922,
#   'caption': 'A decorated table covered with plates of food and vegetables. '},
#  {'image_id': 134754,
#   'id': 2972,
#   'caption': 'A couple at the beach walking with their surf boards.'},
#  {'image_id': 517565,
#   'id': 3069,
#   'caption': 'A bathroom with a sink shower and toilette.'},
#  {'image_id': 389006,
#   'id': 3085,
#   'caption': 'A phone and a computer on a kitchen counter.'},
#  {'image_id': 124567,
#   'id': 3099,
#   'caption': 'A person is taking a photo of a cat in a car.'},
#  {'image_id': 38682,
#   'id': 3180,
#   'caption': 'a picture of a man riding a bicycle at night'},
#  {'image_id': 539984,
#   'id': 3182,
#   'caption': 'A large hours is eating grass in a field. '},
#  {'image_id': 28231,
#   'id': 3183,
#   'caption': 'A blurry bike rider zooms past a new Mercedes. '},
#  {'image_id': 374873,
#   'id': 3204,
#   'caption': 'A group of skiers stand atop a snowy peak.'},
#  {'image_id': 568117,
#   'id': 3249,
#   'caption': 'Thee cats sleeping on a bed with a person.'},
#  {'image_id': 56972,
#   'id': 3268,
#   'caption': 'A bathroom sink and cabinet featuring everything white'},
#  {'image_id': 389006,
#   'id': 3280,
#   'caption': 'A phone lies on the counter in a modern kitchen.'},
#  {'image_id': 302443,
#   'id': 3309,
#   'caption': 'silver balls laying on the ground around a smaller red ball. '},
#  {'image_id': 31813,
#   'id': 3324,
#   'caption': 'A man riding a bicycle on a road carrying a surf board.'},
#  {'image_id': 186620,
#   'id': 3375,
#   'caption': 'A young man playing a game of Frisbee.'},
#  {'image_id': 360306,
#   'id': 3436,
#   'caption': 'A man is washing dishes in the kitchen sink.'},
#  {'image_id': 38682,
#   'id': 3453,
#   'caption': 'A man with a backpack rides a bicycle.'},
#  {'image_id': 213532,
#   'id': 3467,
#   'caption': 'A boy holding his arm around the shoulders of the girl sitting next to him. '},
#  {'image_id': 568117,
#   'id': 3504,
#   'caption': 'Three cats sleeping with their owners on a bed.'},
#  {'image_id': 38682,
#   'id': 3531,
#   'caption': 'A man using his bicycle to go down a street.'},
#  {'image_id': 360306,
#   'id': 3532,
#   'caption': 'A man standing in a kitchen with a baby and dog.'},
#  {'image_id': 318556,
#   'id': 3555,
#   'caption': 'A clock that blends in with the wall hangs in a bathroom. '},
#  {'image_id': 116100,
#   'id': 3583,
#   'caption': 'multiple photos of a brown and white kitchen. '},
#  {'image_id': 186620,
#   'id': 3645,
#   'caption': 'A man extends his hand out to catch a frisbee.'},
#  {'image_id': 226658,
#   'id': 3677,
#   'caption': 'A set table with silverware, glasses and a bottle of wine.'},
#  {'image_id': 279672,
#   'id': 3701,
#   'caption': 'A vegetable in front of a toaster oven.'},
#  {'image_id': 376047,
#   'id': 3716,
#   'caption': 'A kitchen with new age appliances and equipment.'},
#  {'image_id': 480489,
#   'id': 3769,
#   'caption': 'A large kite in the shape of the bottom half of a woman.'},
#  {'image_id': 517565,
#   'id': 3804,
#   'caption': 'A bathroom with a toilet and a sink.'},
#  {'image_id': 231029,
#   'id': 3856,
#   'caption': 'A kitchen with some old fashioned kitchen ware.'},
#  {'image_id': 122802,
#   'id': 3863,
#   'caption': 'An old man in the middle of his kitchen.'},
#  {'image_id': 4377,
#   'id': 3871,
#   'caption': 'A group of people playing a game of croquet.'},
#  {'image_id': 314265,
#   'id': 3886,
#   'caption': 'A small bathroom painted white with an empty shower.'},
#  {'image_id': 90359,
#   'id': 3891,
#   'caption': 'a man does a trick on a bike on a bench'},
#  {'image_id': 31813,
#   'id': 3912,
#   'caption': 'A man on a bike carrying a surfboard under his arm.'},
#  {'image_id': 24091,
#   'id': 3922,
#   'caption': 'A car with a bunch of bicycles strapped to its roof.'},
#  {'image_id': 18691,
#   'id': 3962,
#   'caption': 'six people on a bus at night time'},
#  {'image_id': 539984,
#   'id': 3965,
#   'caption': 'A brown horse is grazing in the grass.'},
#  {'image_id': 28231,
#   'id': 3966,
#   'caption': 'A blurry bicycle riders goes by a black car.'},
#  {'image_id': 517565,
#   'id': 3981,
#   'caption': 'Bathroom shot of an open toilet and sink.'},
#  {'image_id': 72704,
#   'id': 4005,
#   'caption': 'a black cat sits next to laundry on the floor'},
#  {'image_id': 360053,
#   'id': 4060,
#   'caption': "a white bear laying on a bed with someone's hand on the other side"},
#  {'image_id': 213532,
#   'id': 4067,
#   'caption': 'A boy places his arm around a friend.'},
#  {'image_id': 515040,
#   'id': 4078,
#   'caption': 'A seagull perches on top of a van.'},
#  {'image_id': 480489,
#   'id': 4090,
#   'caption': 'The parachutes fly through the sky next to each other.'},
#  {'image_id': 174028,
#   'id': 4132,
#   'caption': 'two girls sitting on a bench eating lunch'},
#  {'image_id': 32275,
#   'id': 4186,
#   'caption': 'The bathroom counter is stocked with towels and supplies.'},
#  {'image_id': 503598,
#   'id': 4197,
#   'caption': 'A kitchen sink, counter, pots, and a dog dish.'},
#  {'image_id': 189278,
#   'id': 4206,
#   'caption': 'A chef opens up an oven in a kitchen.'},
#  {'image_id': 170045,
#   'id': 4221,
#   'caption': 'a woman standing beside a clean kitchen island'},
#  {'image_id': 18691,
#   'id': 4280,
#   'caption': 'random people sitting in a public tranport bus.'},
#  {'image_id': 416172,
#   'id': 4399,
#   'caption': 'A kitchen being prepared to get newly painted. '},
#  {'image_id': 360306,
#   'id': 4402,
#   'caption': 'A man in a kitchen with his family in a house.'},
#  {'image_id': 72704,
#   'id': 4434,
#   'caption': 'a black cat sitting next to dirty clothes on the bathroom floor'},
#  {'image_id': 374873,
#   'id': 4461,
#   'caption': 'Group of skiers atop a mountain looking over edge.'},
#  {'image_id': 309517,
#   'id': 4617,
#   'caption': 'A person standing in front of a large body of water as the sun sets.'},
#  {'image_id': 293605,
#   'id': 4635,
#   'caption': 'A woman walks by a couple of shop windows.'},
#  {'image_id': 350235,
#   'id': 4648,
#   'caption': 'A group of people playing a game of basketball.'},
#  {'image_id': 274682,
#   'id': 4662,
#   'caption': 'An empty bathroom with a large mirror and sink.'},
#  {'image_id': 374873,
#   'id': 4749,
#   'caption': 'A man poses for a picture on top of a snowy hill.'},
#  {'image_id': 174028,
#   'id': 4759,
#   'caption': 'A girl demonstrating the act of shaving sitting on a bench.'},
#  {'image_id': 314265,
#   'id': 4771,
#   'caption': 'White bathroom with glass shelves and wood sink.'},
#  {'image_id': 480489,
#   'id': 4783,
#   'caption': 'assorted decorations laying around on a plastic tarp'},
#  {'image_id': 186620,
#   'id': 4806,
#   'caption': 'A man in a courtyard reaches out to catch a Frisbee.'},
#  {'image_id': 230843,
#   'id': 4817,
#   'caption': 'A young boy is standing on a surfboard and riding a wave.'},
#  {'image_id': 350235,
#   'id': 4825,
#   'caption': 'a group of men standing around while one seems angry at the others. '},
#  {'image_id': 480545,
#   'id': 4921,
#   'caption': 'A set of stairs lead to a toilet and cabinet in a bathroom.'},
#  {'image_id': 210082,
#   'id': 4928,
#   'caption': 'Double doors open into a bathroom with a footed tub.'},
#  {'image_id': 379340,
#   'id': 4940,
#   'caption': 'A red stop sign with a Bush bumper sticker under the word stop.'},
#  {'image_id': 44816,
#   'id': 5026,
#   'caption': 'A toilet sits next to a sink in a bathroom.'},
#  {'image_id': 474031,
#   'id': 5044,
#   'caption': 'An empty kitchen has walls painted white. '},
#  {'image_id': 543882,
#   'id': 5070,
#   'caption': 'A buffet of different types of food sitting on a buffet table.'},
#  {'image_id': 25470,
#   'id': 5109,
#   'caption': 'A clean, organized, kitchen cabinet and countertop area.'},
#  {'image_id': 274682,
#   'id': 5127,
#   'caption': 'A bathroom with two sinks and a closet. '},
#  {'image_id': 47093,
#   'id': 5158,
#   'caption': 'A female student is talking on her phone while walking.'},
#  {'image_id': 503598,
#   'id': 5169,
#   'caption': 'There is a small kitchen with wooden cabinets and pet bowls on the floor.'},
#  {'image_id': 32275,
#   'id': 5188,
#   'caption': 'There is a clean bathroom counter and sink.'},
#  {'image_id': 474031,
#   'id': 5203,
#   'caption': 'A kitchen area with a microwave and refrigerator.'},
#  {'image_id': 385716,
#   'id': 5276,
#   'caption': 'A city sidewalk with storefronts on the right.'},
#  {'image_id': 72704,
#   'id': 5295,
#   'caption': 'A black cat sits on a bathroom floor next to some laundry.'},
#  {'image_id': 38682,
#   'id': 5304,
#   'caption': 'A person with a backpack on riding by on a bike.'},
#  {'image_id': 479495,
#   'id': 5315,
#   'caption': 'A bike on the platform of a public transportation stop at night.'},
#  {'image_id': 309517,
#   'id': 5334,
#   'caption': 'The silhouette of a person standing in front of a sunset over water. '},
#  {'image_id': 429065,
#   'id': 5373,
#   'caption': 'A colorful tent is stationed on a bike lane.'},
#  {'image_id': 72704,
#   'id': 5376,
#   'caption': 'A cat sitting on a bath rug next to a pile of clothes.'},
#  {'image_id': 24091,
#   'id': 5395,
#   'caption': 'A car with several bikes on a bike rack. '},
#  {'image_id': 285579,
#   'id': 5453,
#   'caption': 'A person walking outside in the rain with a green umbrella. '},
#  {'image_id': 465049,
#   'id': 5483,
#   'caption': 'A fire hydrant with chains is painted red.'},
#  {'image_id': 2448,
#   'id': 5495,
#   'caption': 'Two kitchen stools sitting in front of an island in a kitchen\n'},
#  {'image_id': 577876,
#   'id': 5499,
#   'caption': 'A woman takes a selfie in front of a restroom mirror.'},
#  {'image_id': 465049,
#   'id': 5501,
#   'caption': 'A red fire hydrant wrapped in a red chain on a sidewalk.'},
#  {'image_id': 279672,
#   'id': 5507,
#   'caption': 'An evergreen sprig is sitting on top of an appliance.'},
#  {'image_id': 539984,
#   'id': 5513,
#   'caption': 'A brown horse grazes in an open field next to trees.'},
#  {'image_id': 28231,
#   'id': 5514,
#   'caption': 'A man rides a bike past a black car in a parking lot.'},
#  {'image_id': 161749,
#   'id': 5536,
#   'caption': 'Two dogs stand in a kitchen beneath their owner.'},
#  {'image_id': 44816,
#   'id': 5551,
#   'caption': 'A pristine bathroom sits waiting to be used'},
#  {'image_id': 435091,
#   'id': 5555,
#   'caption': 'A woman smiles at a man who is wearing a colorful sarong.'},
#  {'image_id': 385626,
#   'id': 5613,
#   'caption': 'Woman riding a bicycle down an empty street.'},
#  {'image_id': 180141,
#   'id': 5719,
#   'caption': "A family sits at a table together enjoying each other's company"},
#  {'image_id': 330238,
#   'id': 5721,
#   'caption': 'A crowd of skiers prepare to ski down snow covered slopes.'},
#  {'image_id': 180141,
#   'id': 5731,
#   'caption': 'A family is playing a karaoke video game.'},
#  {'image_id': 330238,
#   'id': 5733,
#   'caption': 'Many skiiers are gathered at the base of a hill, while several travel down it.'},
#  {'image_id': 134754,
#   'id': 5759,
#   'caption': 'A guy and a girl are walking on the beach holding surfboards.'},
#  {'image_id': 230843,
#   'id': 5798,
#   'caption': 'A surfer rides his surf board on some very small waves.'},
#  {'image_id': 47093,
#   'id': 5803,
#   'caption': 'A young woman walking down the street while talking on her cell phone'},
#  {'image_id': 515040,
#   'id': 5887,
#   'caption': 'A white van parked out side of a large white building.'},
#  {'image_id': 538480,
#   'id': 5901,
#   'caption': 'a blue bathroom with a sink and toilet'},
#  {'image_id': 515040,
#   'id': 5902,
#   'caption': 'A white van sits outside of a white building.'},
#  {'image_id': 174028,
#   'id': 5935,
#   'caption': 'A girl trusts another girl to shave her while sitting back to back.'},
#  {'image_id': 285579,
#   'id': 5975,
#   'caption': 'A student walks in the rain with a green umbrella.'},
#  {'image_id': 499237,
#   'id': 5981,
#   'caption': 'Towels are neatly stacked on a shelf in the bathroom.'},
#  {'image_id': 4377,
#   'id': 5986,
#   'caption': 'A game of croquet is being played in a back yard.'},
#  {'image_id': 231029,
#   'id': 6001,
#   'caption': 'A kitchen with copper pots on pot racks and on the stove'},
#  {'image_id': 543882,
#   'id': 6012,
#   'caption': 'A buffet table at a restaurant, covered with food.'},
#  {'image_id': 299675,
#   'id': 6061,
#   'caption': 'A white kitchen filled with pots, pans and dishes.'},
#  {'image_id': 360334,
#   'id': 6114,
#   'caption': 'A man folds his arms in a kitchen.'},
#  {'image_id': 180141,
#   'id': 6121,
#   'caption': 'A family watches while two boys play a singing game.'},
#  {'image_id': 330238,
#   'id': 6123,
#   'caption': 'Hikers climb up a snow-covered mountain in the winter.'},
#  {'image_id': 101891,
#   'id': 6126,
#   'caption': 'Clutter blocks antique cars from leaving the garage'},
#  {'image_id': 577876,
#   'id': 6132,
#   'caption': 'A woman takes a photo of her reflection in a bathroom mirror.'},
#  {'image_id': 4377,
#   'id': 6148,
#   'caption': 'Two guys and a girl playing croquet in the yard.'},
#  {'image_id': 515040,
#   'id': 6184,
#   'caption': 'A white van parked with a seagull standing on top of it.'},
#  {'image_id': 213532,
#   'id': 6188,
#   'caption': 'One kid has his arm wrapped around the other kid'},
#  {'image_id': 466800,
#   'id': 6208,
#   'caption': 'A view of a fancy spa like bathroom with a blue tiled tub.'},
#  {'image_id': 279939,
#   'id': 6276,
#   'caption': 'A bathroom contains a toilet, sink, and bathtub.'},
#  {'image_id': 274682,
#   'id': 6279,
#   'caption': 'A white bathroom with a walk in closet is shown.'},
#  {'image_id': 18691,
#   'id': 6284,
#   'caption': 'There are only a few people in the bus.'},
#  {'image_id': 435091,
#   'id': 6293,
#   'caption': 'Man and woman with group of scissors on table.'},
#  {'image_id': 187042,
#   'id': 6329,
#   'caption': 'A boat in the water with a raft and a bike loaded at one end of it'},
#  {'image_id': 279939,
#   'id': 6333,
#   'caption': 'The white bathroom has orange, blue, and gray accents.'},
#  {'image_id': 210082,
#   'id': 6365,
#   'caption': 'A free-standing bathroom near an open door and table.'},
#  {'image_id': 170045,
#   'id': 6372,
#   'caption': 'A woman standing behind the island in the kitchen'},
#  {'image_id': 18691,
#   'id': 6449,
#   'caption': 'A group of people are riding the bus.'},
#  {'image_id': 577876,
#   'id': 6456,
#   'caption': 'A woman takes her picture in the mirror in the bathroom.'},
#  {'image_id': 257263,
#   'id': 6463,
#   'caption': 'A restroom with the toilet in the corner.'},
#  {'image_id': 25470,
#   'id': 6471,
#   'caption': 'A kitchen has red bricks lining the counter.'},
#  {'image_id': 360053,
#   'id': 6529,
#   'caption': 'A white teddy bear is laying on a bed in a dimly lit room.'},
#  {'image_id': 360053,
#   'id': 6532,
#   'caption': 'A teddy bear lying face down on a bedspread covered mattress in front of a window'},
#  {'image_id': 230843,
#   'id': 6539,
#   'caption': 'A young boy is standing on a surfboard in the water.'},
#  {'image_id': 31813,
#   'id': 6546,
#   'caption': 'A man rides a bike down the street while holding a surfboard. '},
#  {'image_id': 568117,
#   'id': 6609,
#   'caption': 'Three cats are sleeping on a bed with a person. '},
#  {'image_id': 513461,
#   'id': 6623,
#   'caption': 'A person holding a surf board on a beach. '},
#  {'image_id': 309517,
#   'id': 6642,
#   'caption': 'A person is standing in front of the ocean at sunset. '},
#  {'image_id': 526165,
#   'id': 6652,
#   'caption': 'Loving couple pose together behind a fruit-adorned cake.'},
#  {'image_id': 429065,
#   'id': 6720,
#   'caption': 'A biker rides through a tent in a bike lane.'},
#  {'image_id': 161749,
#   'id': 6724,
#   'caption': "Two stands standing on the floor by their owner's legs"},
#  {'image_id': 32275,
#   'id': 6739,
#   'caption': 'A hotel bathroom with stone counter and mirror'},
#  {'image_id': 476220,
#   'id': 6809,
#   'caption': 'A refrigerator and stove are in a small kitchen area. '},
#  {'image_id': 465049,
#   'id': 6815,
#   'caption': 'The chain of a red fire hydrant is the focus.'},
#  {'image_id': 435091,
#   'id': 6833,
#   'caption': 'A shirtless man wearing a pink towel in the kitchen with a woman drinking wine.'},
#  {'image_id': 309517,
#   'id': 6837,
#   'caption': 'A dark profile of a person set before a sunset on the beach.'},
#  {'image_id': 25470,
#   'id': 6888,
#   'caption': 'A kitchen with wood cabinets and granite counter tops.'},
#  {'image_id': 285579,
#   'id': 6902,
#   'caption': 'An individual covers himself under an umbrella on a rainy day.'},
#  {'image_id': 416172,
#   'id': 6907,
#   'caption': 'The corner of an empty kitchen with cleaning products all over the counter.'},
#  {'image_id': 4377,
#   'id': 6925,
#   'caption': 'A group of four people playing croquet on a lawn.'},
#  {'image_id': 174028,
#   'id': 6964,
#   'caption': 'two females sitting on a bench one is being the arms for the other.'},
#  {'image_id': 122802,
#   'id': 7013,
#   'caption': 'A man stands in the middle of his granite counter-topped kitchen.'},
#  {'image_id': 231029,
#   'id': 7057,
#   'caption': 'A restaurant kitchen with bowls and pans ready for the night.'},
#  {'image_id': 334790,
#   'id': 7100,
#   'caption': 'A young man jumping his skate board over a cement seating area.'},
#  {'image_id': 517565,
#   'id': 7170,
#   'caption': 'An empty bathroom with the toilet seat up.'},
#  {'image_id': 14750,
#   'id': 7178,
#   'caption': 'A bicycle with a basket is parked at the side of a building'},
#  {'image_id': 44816,
#   'id': 7189,
#   'caption': 'An empty bathroom painted yellow with an open window.'},
#  {'image_id': 573518,
#   'id': 7281,
#   'caption': 'A black colored keyboard for a computer system.'},
#  {'image_id': 226658,
#   'id': 7313,
#   'caption': 'A woman having a slice of bread with jelly.'},
#  {'image_id': 285579,
#   'id': 7340,
#   'caption': 'A man walking in the rain crossing a street while holding an umbrella.'},
#  {'image_id': 499237,
#   'id': 7367,
#   'caption': 'A table with towels on top of it placed under a mirror.'},
#  {'image_id': 124567,
#   'id': 7386,
#   'caption': 'A cat sitting on top of the passenger seat of a car.'},
#  {'image_id': 568117,
#   'id': 7437,
#   'caption': 'A person is sleeping on the same bed as three cats'},
#  {'image_id': 2448,
#   'id': 7562,
#   'caption': 'A kitchen counter with chairs, refrigerator, and cupboards. '},
#  {'image_id': 513461,
#   'id': 7649,
#   'caption': 'A family standing next to the ocean on a sandy beach with a surf board.'},
#  {'image_id': 321194,
#   'id': 7675,
#   'caption': 'A kitchen sink next to an empty counter with a tiled wall.'},
#  {'image_id': 253464,
#   'id': 7749,
#   'caption': 'A mid sized bathroom with toilette, shower and vanity mirror above a sink.'},
#  {'image_id': 122802,
#   'id': 7790,
#   'caption': 'A man leaning forward on a counter top.'},
#  {'image_id': 257263,
#   'id': 7852,
#   'caption': 'A toilet is equipped with support bars for the disabled.'},
#  {'image_id': 28149,
#   'id': 7907,
#   'caption': 'A television reflected off a mirror near a counter top.'},
#  {'image_id': 568117,
#   'id': 7953,
#   'caption': "Two black cats nap as a white cat lays on a sleeping person's chest."},
#  {'image_id': 465049,
#   'id': 8036,
#   'caption': 'A fire hydrant and the chain attached to it.'},
#  {'image_id': 520049,
#   'id': 8040,
#   'caption': 'Man riding on a very old version of a personal bicycle. '},
#  {'image_id': 476220,
#   'id': 8066,
#   'caption': 'Small kitchen in a personal home with dual sinks.'},
#  {'image_id': 435091,
#   'id': 8078,
#   'caption': 'Man dressed in a wrap in a personal kitchen.'},
#  {'image_id': 291827,
#   'id': 8134,
#   'caption': 'Two boys with surf boards walking out into the ocean.'},
#  {'image_id': 480545,
#   'id': 8143,
#   'caption': 'The bathroom door next to the laundry room is open.'},
#  {'image_id': 478007,
#   'id': 8163,
#   'caption': 'A bathroom sink and counter with a large mirror above it.'},
#  {'image_id': 309517,
#   'id': 8250,
#   'caption': 'Man standing like a shadow in front of the ocean.'},
#  {'image_id': 279939,
#   'id': 8277,
#   'caption': 'A small bathroom with a white toilette and bath tub.'},
#  {'image_id': 461221,
#   'id': 8300,
#   'caption': 'A kitchen with a over stove and toaster oven including a microwave.'},
#  {'image_id': 416909,
#   'id': 8301,
#   'caption': 'An un occupied bathroom with a shower toilette and sink.'},
#  {'image_id': 480545,
#   'id': 8305,
#   'caption': 'Through the door view of a small white bathroom. '},
#  {'image_id': 416172,
#   'id': 8308,
#   'caption': 'Dirty kitchen with cleaning supplies placed allover the counters.'},
#  {'image_id': 376047,
#   'id': 8312,
#   'caption': 'Silver and white colored personal kitchen with yellow tiling.'},
#  {'image_id': 293605,
#   'id': 8325,
#   'caption': 'Woman walking down the street past a wig shop.'},
#  {'image_id': 377955,
#   'id': 8400,
#   'caption': 'A silver car parked in a shopping center parking lot.'},
#  {'image_id': 480545,
#   'id': 8422,
#   'caption': 'A small bathroom containing a step, toilette and sink.'},
#  {'image_id': 90359,
#   'id': 8430,
#   'caption': 'A young man rides his bicycle on top of a cement bench.'},
#  {'image_id': 550126,
#   'id': 8470,
#   'caption': 'A bathroom with a close shower curtain next to a toilette.'},
#  {'image_id': 194698,
#   'id': 8471,
#   'caption': "A small dog cradled in his loving owner's arm as he falls asleep."},
#  {'image_id': 28149,
#   'id': 8489,
#   'caption': 'A flat screen TV sits next to a box of tissues and a remote control.'},
#  {'image_id': 579846,
#   'id': 8500,
#   'caption': 'A nearly empty house with a bicycle mounted on the wall.'},
#  {'image_id': 503598,
#   'id': 8589,
#   'caption': 'A kitchen with a pets food dishes on the floor.'},
#  {'image_id': 186620,
#   'id': 8610,
#   'caption': 'College student playing frisbee on a campus lawn.'},
#  {'image_id': 377955,
#   'id': 8628,
#   'caption': 'A car is parked in a empty parking lot.'},
#  {'image_id': 321194,
#   'id': 8665,
#   'caption': 'A back splash is added to the wall in the kitchen.'},
#  {'image_id': 416172,
#   'id': 8671,
#   'caption': 'An a kitchen is being cleaned and decluttered.'},
#  {'image_id': 186620,
#   'id': 8766,
#   'caption': 'A man has a frisbee in mid air just out of his hand.'},
#  {'image_id': 274682,
#   'id': 8802,
#   'caption': ' A bathroom under construction with a double sink vanity that has a mirrir and light strip over it'},
#  {'image_id': 515040,
#   'id': 8827,
#   'caption': 'Single seagull sits on a white van with others flying in background'},
#  {'image_id': 9469,
#   'id': 8853,
#   'caption': 'A teenage boy is in a field looking at a wire.'},
#  {'image_id': 230843,
#   'id': 8861,
#   'caption': 'A young boy is standing on a surfboard in the ocean. '},
#  {'image_id': 14750,
#   'id': 8963,
#   'caption': 'A bicycle leaning against a building near a window.'},
#  {'image_id': 257263,
#   'id': 8980,
#   'caption': 'A bathroom toilet is surrounded with silver handrails.'},
#  {'image_id': 101891,
#   'id': 8991,
#   'caption': 'A garage filled with old cards and old bicycles.'},
#  {'image_id': 348595,
#   'id': 9018,
#   'caption': 'A man in a parade has red and white face and umbrella.'},
#  {'image_id': 226658,
#   'id': 9026,
#   'caption': 'A woman sitting at a table with win and bread.'},
#  {'image_id': 24091,
#   'id': 9049,
#   'caption': "A car is loaded down with many bicycles attached to it's roof."},
#  {'image_id': 189278,
#   'id': 9114,
#   'caption': 'This is a restaurant kitchen with two industrial ovens.'},
#  {'image_id': 374873,
#   'id': 9117,
#   'caption': 'Skiers are standing at the top of a snow-covered mountain.'},
#  {'image_id': 379340,
#   'id': 9125,
#   'caption': 'A stop sign that has been vandalized is pictured in front of a parked car.'},
#  {'image_id': 279939,
#   'id': 9159,
#   'caption': 'A bathroom with toilet and bowl for sink.'},
#  {'image_id': 101891,
#   'id': 9168,
#   'caption': 'Some antique cars sit in a garage with some bicycles'},
#  {'image_id': 79143,
#   'id': 9184,
#   'caption': 'A small bathroom has separate tub and shower.'},
#  {'image_id': 435091,
#   'id': 9224,
#   'caption': 'A man in a pink sarong showing scissors to a woman with wine.'},
#  {'image_id': 9469,
#   'id': 9240,
#   'caption': 'The boy is inspecting the wire for a project.'},
#  {'image_id': 44816,
#   'id': 9241,
#   'caption': 'This is a photo of a small hotel bathroom'},
#  {'image_id': 346909,
#   'id': 9271,
#   'caption': 'Two dogs are laying down next to each other.'},
#  {'image_id': 543882,
#   'id': 9291,
#   'caption': 'The two banquet tables held a variety of meats, dips, and pastries.'},
#  {'image_id': 377955,
#   'id': 9342,
#   'caption': 'The shopping plaza has many stores and one parked car.'},
#  {'image_id': 377955,
#   'id': 9396,
#   'caption': 'A silver sedan is parked in a plaza lot on a cloudy day.'},
#  {'image_id': 2448,
#   'id': 9464,
#   'caption': 'A picture of a kitchen area with refrigerator and stove.'},
#  {'image_id': 180141,
#   'id': 9487,
#   'caption': 'A family watches two boys singing into microphones.'},
#  {'image_id': 330238,
#   'id': 9489,
#   'caption': 'Skiers of all ages skiing down a slope and gathering at the bottom.'},
#  {'image_id': 376047,
#   'id': 9560,
#   'caption': 'A modern lighted kitchen with stainless steel appliances.'},
#  {'image_id': 2448,
#   'id': 9566,
#   'caption': 'A kitchen with a refrigerator, oven, and counter.'},
#  {'image_id': 170045,
#   'id': 9576,
#   'caption': 'A woman making something in a kitchen. '},
#  {'image_id': 351191,
#   'id': 9590,
#   'caption': 'A woman crossing a city street while carrying groceries.'},
#  {'image_id': 165350,
#   'id': 9611,
#   'caption': 'A group of bike riders race down a busy street.'},
#  {'image_id': 47093,
#   'id': 9736,
#   'caption': 'Two young women walking while one is on a cell phone'},
#  {'image_id': 350235,
#   'id': 9775,
#   'caption': 'Several athletes appear to be having a disagreement.'},
#  {'image_id': 549575,
#   'id': 9799,
#   'caption': 'A kitchen filled with many cupboards and lots of counter space.'},
#  {'image_id': 550126,
#   'id': 9802,
#   'caption': 'A white shower curtain with a spiral pattern hanging in the bathroom.'},
#  {'image_id': 194698,
#   'id': 9803,
#   'caption': "A person holding a chihuahua sleeping on it's back in their arm. "},
#  {'image_id': 387408,
#   'id': 9824,
#   'caption': 'An attractive woman taking a selfie in a bathroom.'},
#  {'image_id': 28149,
#   'id': 9836,
#   'caption': 'A TV is behind glass in a bathroom.'},
#  {'image_id': 253464,
#   'id': 9846,
#   'caption': 'A very clean bathroom with the lights on.'},
#  {'image_id': 331863,
#   'id': 9867,
#   'caption': 'A group of people sitting on a couch while a brown dog looks at them '},
#  {'image_id': 350553,
#   'id': 9886,
#   'caption': 'An older woman walking a bicycle with a bus in the background.'},
#  {'image_id': 513461,
#   'id': 9893,
#   'caption': 'A man getting ready to surf as lookers walk by'},
#  {'image_id': 376047,
#   'id': 9911,
#   'caption': 'A picture of some appliances stove, dishwasher, refridgerator and microwave, in a kitchen.'},
#  {'image_id': 4377,
#   'id': 9916,
#   'caption': 'A group of friends enjoy a game of croquet on a grassy fenced in field.'},
#  {'image_id': 24091,
#   'id': 9943,
#   'caption': "A car has multiple bikes hooked onto it's roof."},
#  {'image_id': 9469,
#   'id': 9963,
#   'caption': 'A young guy checking on a wire as he holds onto a dog leash.'},
#  {'image_id': 161749,
#   'id': 9976,
#   'caption': 'Two dogs with a woman in the kitchen.'},
#  {'image_id': 38682,
#   'id': 9993,
#   'caption': 'A man riding a bike down the street at night.'},
#  {'image_id': 64941,
#   'id': 9998,
#   'caption': 'Three people riding bikes on the side of a road.'},
#  {'image_id': 219409,
#   'id': 10010,
#   'caption': 'A fridge that is halfway open during the night.'},
#  {'image_id': 520049,
#   'id': 10038,
#   'caption': 'A man on an old-fashioned bicycle, biking across a bridge.'},
#  {'image_id': 293605,
#   'id': 10098,
#   'caption': 'A storefront with two bicycles and a woman walking past.'},
#  {'image_id': 524679,
#   'id': 10112,
#   'caption': 'Sister on her bike trying to race the bus.'},
#  {'image_id': 476220,
#   'id': 10148,
#   'caption': 'A small kitchen with sink, stove and refrigerator.'},
#  {'image_id': 524679,
#   'id': 10160,
#   'caption': 'A person riding a very high bike on the road.'},
#  {'image_id': 9469,
#   'id': 10182,
#   'caption': 'A boy is outside with his dog in a field surrounded by a sign and other items.'},
#  {'image_id': 279939,
#   'id': 10185,
#   'caption': 'A bathroom with a toilet, sink, and bathtub.'},
#  {'image_id': 2448,
#   'id': 10220,
#   'caption': 'A very clean kitchen with the light on.'},
#  {'image_id': 351191,
#   'id': 10379,
#   'caption': 'Shopper crossing a street in the downtown of a city.'},
#  {'image_id': 377955,
#   'id': 10425,
#   'caption': 'a small strip mall with a few cars in the parking lot'},
#  {'image_id': 180141,
#   'id': 10426,
#   'caption': 'Kids and their moms are singing karaoke at the table.'},
#  {'image_id': 330238,
#   'id': 10428,
#   'caption': 'A group of people are skiing on a mountain.'},
#  {'image_id': 274682,
#   'id': 10440,
#   'caption': 'A master bedroom with a closet and attached bathroom.'},
#  {'image_id': 471895,
#   'id': 10463,
#   'caption': 'A bathroom featuring an oddly shaped toilette, shower and sink.'},
#  {'image_id': 425135,
#   'id': 10489,
#   'caption': 'The inside of a bathroom with two sinks.'},
#  {'image_id': 478007,
#   'id': 10497,
#   'caption': 'A wood bathroom vanity with a granite countertop.'},
#  {'image_id': 348595,
#   'id': 10503,
#   'caption': 'A young person with red and white face paint holds an umbrella.'},
#  {'image_id': 9469,
#   'id': 10506,
#   'caption': 'A boy building something with wires and poles.'},
#  {'image_id': 579846,
#   'id': 10540,
#   'caption': 'A hall opening onto a bathroom, bedroom, and two other rooms.'},
#  {'image_id': 389006,
#   'id': 10711,
#   'caption': 'A nicely decorated kitchen with metallic refrigerator and blue counter.'},
#  {'image_id': 189278,
#   'id': 10734,
#   'caption': 'There are two ovens in a kitchen restaurant, and one of them is being used.'},
#  {'image_id': 334790,
#   'id': 10769,
#   'caption': 'Boy riding skateboard and doing trick in air.'},
#  {'image_id': 425135,
#   'id': 10798,
#   'caption': 'A large bathroom with two sinks and three windows.'},
#  {'image_id': 425135,
#   'id': 10834,
#   'caption': 'A view of a communal bathroom with multiple sinks and windows.'},
#  {'image_id': 350553,
#   'id': 10852,
#   'caption': 'A woman walks her bike past a city bus.'},
#  {'image_id': 28149,
#   'id': 10859,
#   'caption': 'A hotel bathroom that has technology in the mirror.'},
#  {'image_id': 360053,
#   'id': 10987,
#   'caption': 'A bed with blue bed spread on it in front of a window.'},
#  {'image_id': 56972,
#   'id': 10996,
#   'caption': 'A bathroom with a sink, cabinet, mirror and picture.'},
#  {'image_id': 175565,
#   'id': 11037,
#   'caption': 'A cocker spaniel sitting next to a woman holding a baby. '},
#  {'image_id': 479495,
#   'id': 11039,
#   'caption': 'A bicycle leans on a bench at a subway stop.'},
#  {'image_id': 178771,
#   'id': 11070,
#   'caption': 'A man on his skateboard at a basketball court.'},
#  {'image_id': 175565,
#   'id': 11091,
#   'caption': 'A dog lays on a couch next to a woman holding a baby.'},
#  {'image_id': 432201,
#   'id': 11093,
#   'caption': 'Clean stainless steel kitchen with large cabinets and counter.'},
#  {'image_id': 56972,
#   'id': 11131,
#   'caption': 'A white pedestal sink below a white cabinet in a white bathroom. '},
#  {'image_id': 253464,
#   'id': 11139,
#   'caption': 'The yellow flowers sits atop the counter in a clean bathroom.'},
#  {'image_id': 51644,
#   'id': 11164,
#   'caption': 'A srfer perches on his board precariously as he hits a big wave.'},
#  {'image_id': 331863,
#   'id': 11301,
#   'caption': 'A group of friends spending the day watching TV together.'},
#  {'image_id': 565401,
#   'id': 11334,
#   'caption': 'A bicycle leans against a park bench with a flowering tree nearby.'},
#  {'image_id': 346909,
#   'id': 11347,
#   'caption': 'Two dogs were captured in a photo with the lighting of the image altered.'},
#  {'image_id': 466800,
#   'id': 11419,
#   'caption': 'Different types of tiles are on the walls, floor and tub.'},
#  {'image_id': 256950,
#   'id': 11435,
#   'caption': 'The serving counter of a restaurant is quiet.'},
#  {'image_id': 64941,
#   'id': 11477,
#   'caption': 'A group of two adults and a child biking down a road.'},
#  {'image_id': 474031,
#   'id': 11497,
#   'caption': 'A house with a white decorated kitchen. '},
#  {'image_id': 175565,
#   'id': 11586,
#   'caption': 'A dog is laying next to a woman holding a baby.'},
#  {'image_id': 276961,
#   'id': 11593,
#   'caption': 'A bathroom mirror with items in front of it.'},
#  {'image_id': 530832,
#   'id': 11639,
#   'caption': 'Two women prepare a meal in a large kitchen.'},
#  {'image_id': 579846,
#   'id': 11665,
#   'caption': 'A view of a hallway in a house.'},
#  {'image_id': 211265,
#   'id': 11684,
#   'caption': 'An empty bathroom featuring a toilette and window.'},
#  {'image_id': 170045,
#   'id': 11778,
#   'caption': 'A woman stands in the kitchen, surrounded by wood cabinets and stainless steel appliances.'},
#  {'image_id': 474031,
#   'id': 11806,
#   'caption': 'A large kitchen featuring a counter top and refrigerator.'},
#  {'image_id': 334790,
#   'id': 11864,
#   'caption': 'A man in a blue shirt and jeans doing a trick on a skateboard. '},
#  {'image_id': 189278,
#   'id': 11934,
#   'caption': 'Two ovens in use in a professional kitchen .'},
#  {'image_id': 385626,
#   'id': 11940,
#   'caption': 'A woman in green is riding a bike.'},
#  {'image_id': 389006,
#   'id': 11950,
#   'caption': 'A clean kitchen with a phone and laptop on the counter.'},
#  {'image_id': 161657,
#   'id': 11968,
#   'caption': 'A bathroom with a white toilet and a white bath'},
#  {'image_id': 279672,
#   'id': 11978,
#   'caption': 'A microwave is next to sage or some kind of spice.'},
#  {'image_id': 256950,
#   'id': 12104,
#   'caption': 'A kitchen filled with dishes and bowls stacked on top of each other.'},
#  {'image_id': 226517,
#   'id': 12124,
#   'caption': 'A kitchen with a wooden kitchen table and appliances in it.'},
#  {'image_id': 209040,
#   'id': 12126,
#   'caption': 'A bathroom sink with mirror placed above it.'},
#  {'image_id': 351191,
#   'id': 12128,
#   'caption': 'A person crossing at a crosswalk with bags in his hands.'},
#  {'image_id': 478007,
#   'id': 12132,
#   'caption': 'This is a bathroom sink in a hotel'},
#  {'image_id': 461221,
#   'id': 12170,
#   'caption': 'A kitchen, with sink, stove, and a white cabinet.'},
#  {'image_id': 416909,
#   'id': 12171,
#   'caption': 'A clean bathroom with sink, toilet and shower.'},
#  {'image_id': 178771,
#   'id': 12195,
#   'caption': 'A young boy riding a skate board at a public skate park.'},
#  {'image_id': 64941,
#   'id': 12200,
#   'caption': 'Two adults and a child riding bicycles on the side of a road.'},
#  {'image_id': 79143,
#   'id': 12256,
#   'caption': 'A spacious bathroom with a fancy bathtub and sink.'},
#  {'image_id': 524679,
#   'id': 12269,
#   'caption': 'A nun riding a very tallk bike next to a purple bus.'},
#  {'image_id': 199743,
#   'id': 12282,
#   'caption': 'A person on a bicycle waiting to cross a street at the intersection.'},
#  {'image_id': 461221,
#   'id': 12314,
#   'caption': 'A kitchen cupboard in a kitchen with a stove and a sink.'},
#  {'image_id': 416909,
#   'id': 12315,
#   'caption': 'A small bathroom showing the sink and toilet area.'},
#  {'image_id': 178771,
#   'id': 12339,
#   'caption': 'A person skateboarding on an outside basketball court.'},
#  {'image_id': 427180,
#   'id': 12368,
#   'caption': 'A woman in a fushia shirt cooking in an industrial kitchen. '},
#  {'image_id': 416565,
#   'id': 12441,
#   'caption': 'A small wood paneled bathroom with a sink, mirror and toilette.'},
#  {'image_id': 276961,
#   'id': 12457,
#   'caption': 'A mirror reflecting the opposite wall of a bathroom. '},
#  {'image_id': 565401,
#   'id': 12486,
#   'caption': 'A bicycle parked in the grass by a tree. '},
#  {'image_id': 573518,
#   'id': 12489,
#   'caption': 'A black computer keyboard with lcd panel and numeric pad.'},
#  {'image_id': 375878,
#   'id': 12532,
#   'caption': 'A pink tub and sink in a white bathroom. '},
#  {'image_id': 471895,
#   'id': 12560,
#   'caption': 'A small bathroom decorated with pretty red flowers.'},
#  {'image_id': 233201,
#   'id': 12566,
#   'caption': 'An empty bathroom with a sink and mirror next to a toilette.'},
#  {'image_id': 550126,
#   'id': 12646,
#   'caption': 'A bathroom with a toilet bowl and shower curtain.'},
#  {'image_id': 194698,
#   'id': 12647,
#   'caption': 'A person holding a small sleeping dog in their arms.'},
#  {'image_id': 256950,
#   'id': 12683,
#   'caption': 'Kitchen ware sitting behind the counter top at a restaurant.'},
#  {'image_id': 432201,
#   'id': 12698,
#   'caption': 'A small spotless and clean stainless steel kitchen.'},
#  {'image_id': 161657,
#   'id': 12712,
#   'caption': 'The overhead view of a tiled bathroom  with a tub, shower, toilet, bidet, and sink.'},
#  {'image_id': 360871,
#   'id': 12716,
#   'caption': 'A kitchen filled with appliances and cupboards green painted walls..'},
#  {'image_id': 14698,
#   'id': 12780,
#   'caption': 'A beautiful blonde woman rides a skateboard across a busy street.'},
#  {'image_id': 213532,
#   'id': 12839,
#   'caption': 'Two children sitting down, one with his arm over the other.'},
#  {'image_id': 429065,
#   'id': 12927,
#   'caption': 'A multicolored kiosk for cyclists in a city'},
#  {'image_id': 64941,
#   'id': 12947,
#   'caption': 'A couple and their child riding bikes down an asphalt road.'},
#  {'image_id': 425135,
#   'id': 12994,
#   'caption': 'A bathroom with two porcelain sinks and hexagonal tiles.'},
#  {'image_id': 350553,
#   'id': 13015,
#   'caption': 'A lady waking a bike by a bus.'},
#  {'image_id': 520049,
#   'id': 13044,
#   'caption': 'A man in a yellow coat rides an old-fashioned bicycle'},
#  {'image_id': 573518,
#   'id': 13059,
#   'caption': 'A wireless keyboard compatible with role playing games.'},
#  {'image_id': 51644,
#   'id': 13126,
#   'caption': 'A man riding a wave with a surfboard.'},
#  {'image_id': 376731,
#   'id': 13163,
#   'caption': 'A lady in a large hat riding a bike.'},
#  {'image_id': 425135,
#   'id': 13183,
#   'caption': 'A bathroom with two sinks a bathtub and a shower with lots of lighting from the windows'},
#  {'image_id': 63943,
#   'id': 13204,
#   'caption': 'A black car traveling past parked cars on a tree filled street.'},
#  {'image_id': 219409,
#   'id': 13241,
#   'caption': 'An open refrigerator in a kitchen next to a cupboard.'},
#  {'image_id': 143358,
#   'id': 13247,
#   'caption': 'A man wearing plate armor and metal helmet while talking on a cell phone.'},
#  {'image_id': 478007,
#   'id': 13263,
#   'caption': 'An indoor bathroom with reflective marble counter tops'},
#  {'image_id': 12876,
#   'id': 13276,
#   'caption': 'A bicycle parked up against a rust covered filthy alley wall.'},
#  {'image_id': 166130,
#   'id': 13297,
#   'caption': 'A kitchen filled with appliances next to a hard wood floor.'},
#  {'image_id': 199743,
#   'id': 13311,
# ...
#   'id': 23706,
#   'caption': 'A man with a bike posing by two street signs.'},
#  {'image_id': 230700,
#   'id': 23717,
#   'caption': 'a double basin sing in the corner of a room'},
#  {'image_id': 362278,
#   'id': 23729,
#   'caption': 'A bathroom features white tiles and countertops with red accents including floor tiles, a toilet seat and towel racks.'},
#  {'image_id': 63943,
#   'id': 23764,
#   'caption': 'A street that has been blocked off and a tree is down, covering the street.'},
#  {'image_id': 63512,
#   'id': 23810,
#   'caption': 'A bathroom is heavily decorated with lacy cloths.'},
#  {'image_id': 233201,
#   'id': 23813,
#   'caption': 'A bathroom with a sink and red curtains'},
#  {'image_id': 435124,
#   'id': 23832,
#   'caption': 'A bicycle is parked by a bench overlooking the ocean.'},
#  {'image_id': 511577,
#   'id': 23884,
#   'caption': 'Sun shines through the window in a darkened bathroom.'},
#  {'image_id': 96056,
#   'id': 23893,
#   'caption': 'A cat watches another cat sit in a sink'},
#  {'image_id': 435124,
#   'id': 23925,
#   'caption': 'There is a bicycle leaning against a bench on a pier.'},
#  {'image_id': 257815,
#   'id': 23935,
#   'caption': 'A man is sitting on a one wheeled bicycle next to a smoothie.'},
#  {'image_id': 457667,
#   'id': 23938,
#   'caption': 'A young man standing in front of a bathroom sink with a mirror.'},
#  {'image_id': 492151,
#   'id': 23957,
#   'caption': 'A kitchen filled with appliances and lots of clutter.'},
#  {'image_id': 461543,
#   'id': 23969,
#   'caption': 'A skateboarder coming airborne while riding a skateboard.'},
#  {'image_id': 237514,
#   'id': 23991,
#   'caption': 'A man and woman posing all dressed up.'},
#  {'image_id': 562862,
#   'id': 23998,
#   'caption': 'A shiny black car makes its way down a street.'},
#  {'image_id': 565906,
#   'id': 24001,
#   'caption': 'A white tile bathroom with blue walls and no mirror.'},
#  {'image_id': 133329,
#   'id': 24020,
#   'caption': 'The whole view of a full bathroom. '},
#  {'image_id': 141065,
#   'id': 24063,
#   'caption': 'A bathroom with a toilette, sink and bathtub.'},
#  {'image_id': 393291,
#   'id': 24077,
#   'caption': 'A bathroom with a shower sink and windows.'},
#  {'image_id': 324809,
#   'id': 24079,
#   'caption': 'A man holding a banana to his ear like a phone.'},
#  {'image_id': 301549,
#   'id': 24094,
#   'caption': 'A cat standing on a tiled floor next to an orange container.'},
#  {'image_id': 17866,
#   'id': 24098,
#   'caption': 'A bathroom with, blue shower curtains, a toilet, and sink. '},
#  {'image_id': 237514,
#   'id': 24102,
#   'caption': 'A couple standing in front of a stone wall holding each other.'},
#  {'image_id': 168287,
#   'id': 24107,
#   'caption': 'A woman standing in a bathroom by a shower.'},
#  {'image_id': 136949,
#   'id': 24172,
#   'caption': 'two people standing in an industrial kitchen talking.'},
#  {'image_id': 204606,
#   'id': 24193,
#   'caption': 'A man brushing his teeth with a dinosaur head in front of a bathroom mirror.'},
#  {'image_id': 457667,
#   'id': 24199,
#   'caption': 'A guy standing in a bathroom with his hands in his pockets.'},
#  {'image_id': 518552,
#   'id': 24223,
#   'caption': "Two men's bathroom urinals side by side on a tiled floor."},
#  {'image_id': 306705,
#   'id': 24285,
#   'caption': 'Three people in a kitchen with the counter cluttered. '},
#  {'image_id': 12876,
#   'id': 24295,
#   'caption': 'A bike with a basket leans against a rusty wall.'},
#  {'image_id': 34551,
#   'id': 24307,
#   'caption': 'A woman riding a bicycle in front of a mountain while holding an umbrella.'},
#  {'image_id': 505980,
#   'id': 24316,
#   'caption': 'A young man looking into a cracked mirror in a bathroom with a whole behind him.'},
#  {'image_id': 445573,
#   'id': 24358,
#   'caption': 'A kitchen with a dining room and tables.'},
#  {'image_id': 411690,
#   'id': 24399,
#   'caption': 'A beautiful young woman standing next to a man with her bicycle'},
#  {'image_id': 492151,
#   'id': 24464,
#   'caption': 'A very small kitchen separated from the next room by a shelf'},
#  {'image_id': 53803,
#   'id': 24468,
#   'caption': 'A vespa park next to a bicycle on the street'},
#  {'image_id': 302433,
#   'id': 24477,
#   'caption': 'A man with his through a fake tv.'},
#  {'image_id': 250054,
#   'id': 24486,
#   'caption': 'a bicycle leaning against a fence with a bus in the background'},
#  {'image_id': 287098,
#   'id': 24491,
#   'caption': 'A young woman holding an old teddy bear'},
#  {'image_id': 505980,
#   'id': 24505,
#   'caption': 'A man standing in at a sink looking in the mirror.'},
#  {'image_id': 445573,
#   'id': 24529,
#   'caption': 'a photo of a well lit country style kitchen'},
#  {'image_id': 362278,
#   'id': 24533,
#   'caption': 'Two picture of different sides of a bathroom.'},
#  {'image_id': 87737,
#   'id': 24540,
#   'caption': 'The bathroom is not clean and is ill attended.'},
#  {'image_id': 250054,
#   'id': 24603,
#   'caption': 'A London double decker bus behind a bike '},
#  {'image_id': 287098,
#   'id': 24608,
#   'caption': 'A woman holding a teddy bear by a table'},
#  {'image_id': 393291,
#   'id': 24614,
#   'caption': 'A small standing shower next to a sink and vanity'},
#  {'image_id': 133329,
#   'id': 24629,
#   'caption': 'a bathroom with a shower toilet and sink'},
#  {'image_id': 276620,
#   'id': 24654,
#   'caption': 'Patterned cushions adorn a banquette around a table.'},
#  {'image_id': 140682,
#   'id': 24691,
#   'caption': 'Three sinks in a bathroom of an old building.'},
#  {'image_id': 279034,
#   'id': 24714,
#   'caption': 'A Dairy Queen Sign near a street filled with gas stations and stores'},
#  {'image_id': 539197,
#   'id': 24764,
#   'caption': 'A bike parked on the side of a building in the snow.'},
#  {'image_id': 511577,
#   'id': 24850,
#   'caption': 'A very narrow and dimly lit bathroom picture.'},
#  {'image_id': 280235,
#   'id': 24853,
#   'caption': 'A cat is standing on a toilet in the bathroom.'},
#  {'image_id': 14698,
#   'id': 24894,
#   'caption': 'A girl in a pink shirt is riding a skateboard across an intersection.'},
#  {'image_id': 136949,
#   'id': 24895,
#   'caption': 'Two employees standing behind the counter of a diner'},
#  {'image_id': 317764,
#   'id': 24922,
#   'caption': 'A family preparing a meal by doing various tasks.'},
#  {'image_id': 17866,
#   'id': 24929,
#   'caption': 'Bathroom with shower, toilet and sink and vanity view.'},
#  {'image_id': 465940,
#   'id': 24995,
#   'caption': 'A person and bikes on a mass transit vehicle. '},
#  {'image_id': 39680,
#   'id': 24996,
#   'caption': 'A man in the air above a bed in a bedroom.'},
#  {'image_id': 87737,
#   'id': 24999,
#   'caption': 'An oddly shaped toilet and urinal in a public restroom.\n'},
#  {'image_id': 368629,
#   'id': 25000,
#   'caption': 'A white bathroom sink with a toothbrush and orange on it.'},
#  {'image_id': 502554,
#   'id': 25017,
#   'caption': 'A stop sign at a residential street intersection.'},
#  {'image_id': 467318,
#   'id': 25078,
#   'caption': 'A woman walking her dog on a leash next to a blue storefront.'},
#  {'image_id': 531465,
#   'id': 25081,
#   'caption': 'A person hula hooping while holding a frisbee'},
#  {'image_id': 13158,
#   'id': 25121,
#   'caption': 'A fluffy cat resting comfortably on a blue chair '},
#  {'image_id': 371654,
#   'id': 25141,
#   'caption': 'A table in a kitchen full of ingredients.'},
#  {'image_id': 313798,
#   'id': 25143,
#   'caption': 'People preparing food surrounded by many bowls, buckets and baskets.'},
#  {'image_id': 317555,
#   'id': 25144,
#   'caption': 'A clean bathroom with his and hers sinks.'},
#  {'image_id': 317764,
#   'id': 25156,
#   'caption': 'A group of people cooking in a kitchen.'},
#  {'image_id': 293763,
#   'id': 25168,
#   'caption': 'The inside of a bathroom with a toilet and a sink.'},
#  {'image_id': 347167,
#   'id': 25182,
#   'caption': 'A woman sitting at a sidewalk cafe working on her laptop and having a drink. '},
#  {'image_id': 518117,
#   'id': 25187,
#   'caption': 'Two chefs in a kitchen garnishing a couple plates.'},
#  {'image_id': 412599,
#   'id': 25249,
#   'caption': 'A stark white bathroom with a toilet bowl and tub'},
#  {'image_id': 518415,
#   'id': 25289,
#   'caption': 'A bathroom with a sliding shower door next to a toilet and sink.'},
#  {'image_id': 518117,
#   'id': 25304,
#   'caption': 'Two chefs in a kitchen preparing fresh food.'},
#  {'image_id': 483645,
#   'id': 25306,
#   'caption': 'A kitchen with  a large window and sink.'},
#  {'image_id': 279034,
#   'id': 25320,
#   'caption': 'a dairy queen drive thru sign with a sky background'},
#  {'image_id': 539197,
#   'id': 25334,
#   'caption': 'A bicycle pulling a trailer in the snow leaning against a brick building.'},
#  {'image_id': 383730,
#   'id': 25352,
#   'caption': 'A strange pink bathroom with toilet and sink'},
#  {'image_id': 474283,
#   'id': 25419,
#   'caption': 'A bathroom with a double sink and large mirror.'},
#  {'image_id': 13158,
#   'id': 25454,
#   'caption': 'A fluffy cat sleeping on the hood of a car.'},
#  {'image_id': 324809,
#   'id': 25468,
#   'caption': 'a man holding a banana as if it were a phone'},
#  {'image_id': 399465,
#   'id': 25543,
#   'caption': 'A person sitting on a park bench with their dog.'},
#  {'image_id': 136949,
#   'id': 25567,
#   'caption': 'Two ladies talking in the kitchen area of a restaurant. '},
#  {'image_id': 237514,
#   'id': 25572,
#   'caption': 'A man and a women dressed up posing for a picture.'},
#  {'image_id': 371654,
#   'id': 25624,
#   'caption': 'a kitchen with wooden furniture and many items on the table'},
#  {'image_id': 313798,
#   'id': 25626,
#   'caption': 'a kitchen area with many pots and containers'},
#  {'image_id': 518321,
#   'id': 25631,
#   'caption': 'A man leaning against a stove in  a kitchen.'},
#  {'image_id': 12876,
#   'id': 25669,
#   'caption': 'a bicycle with a basket on the wall of a building'},
#  {'image_id': 494817,
#   'id': 25679,
#   'caption': 'A collection of pictures showing the before and after of a bathroom remodel'},
#  {'image_id': 17866,
#   'id': 25700,
#   'caption': 'The side view of the entrance to a bathroom.'},
#  {'image_id': 399465,
#   'id': 25708,
#   'caption': 'Two women walking on a sidewalk past a bench where a man sits with his dog.'},
#  {'image_id': 492151,
#   'id': 25736,
#   'caption': 'A compact kitchen set-up with shelves for storage and a small stove.'},
#  {'image_id': 280235,
#   'id': 25738,
#   'caption': 'a cat in a bathroom standing on a toilet'},
#  {'image_id': 393291,
#   'id': 25772,
#   'caption': 'A white bathroom with a stand-up shower and wood sink.'},
#  {'image_id': 230700,
#   'id': 25835,
#   'caption': 'A new kitchen sink being remodeled and leveled'},
#  {'image_id': 173185,
#   'id': 25839,
#   'caption': 'a person serving them self a bowl of soup'},
#  {'image_id': 293763,
#   'id': 25867,
#   'caption': 'A white toilet and sink in a white tiled bathroom. '},
#  {'image_id': 237886,
#   'id': 25873,
#   'caption': 'His and hers bathroom sink with the lights turn on by mirror.'},
#  {'image_id': 173185,
#   'id': 25884,
#   'caption': 'A cook dishes a stew from a pan onto a plate.'},
#  {'image_id': 440827,
#   'id': 25893,
#   'caption': 'two white robes hanging in a large bathroom'},
#  {'image_id': 531465,
#   'id': 25969,
#   'caption': 'A man is in the park with a hula hoop.'},
#  {'image_id': 290410,
#   'id': 25991,
#   'caption': 'A restroom with a black seat on the toilet next to a piles of shoes.'},
#  {'image_id': 141065,
#   'id': 25998,
#   'caption': 'A bathroom with a white toilet an d claw foot tub.'},
#  {'image_id': 226517,
#   'id': 26068,
#   'caption': 'a kitchen with a table and chairs and various kitchen appliances '},
#  {'image_id': 209040,
#   'id': 26070,
#   'caption': 'a bathroom with a sink and a mirror'},
#  {'image_id': 70755,
#   'id': 26106,
#   'caption': 'A bathroom counter with toiletries arranged on top.'},
#  {'image_id': 483645,
#   'id': 26110,
#   'caption': 'A kitchen in a state of construction without cabinet doors'},
#  {'image_id': 412599,
#   'id': 26161,
#   'caption': 'A toilet and a tub in a bathroom.'},
#  {'image_id': 518321,
#   'id': 26165,
#   'caption': 'A man with a black hat is leaning against a stove.'},
#  {'image_id': 168858,
#   'id': 26170,
#   'caption': 'a yellow colored kitchen with a silver refrigerator and dishwasher'},
#  {'image_id': 236294,
#   'id': 26195,
#   'caption': 'A modern restroom that has an open shower with an opaque glass wall.'},
#  {'image_id': 376731,
#   'id': 26258,
#   'caption': 'A woman with a pointed hat riding a bicycle.'},
#  {'image_id': 84277,
#   'id': 26297,
#   'caption': 'Traffic driving by a very tall building in a downtown area.'},
#  {'image_id': 368629,
#   'id': 26326,
#   'caption': 'An old style bathroom sink with a toothbrush and orange on it.'},
#  {'image_id': 237514,
#   'id': 26361,
#   'caption': 'A couple dressed up and posing for a picture.'},
#  {'image_id': 168858,
#   'id': 26365,
#   'caption': 'A kitchen scene with the photo focused on the floor.'},
#  {'image_id': 13279,
#   'id': 26373,
#   'caption': 'The United States Postal Service delivers mail regardless of the weather, in this case, deep snow.'},
#  {'image_id': 13279,
#   'id': 26421,
#   'caption': 'A mail truck driving down a snowy road.'},
#  {'image_id': 87737,
#   'id': 26430,
#   'caption': 'A very unpleasant looking bathroom with a urinal and commode'},
#  {'image_id': 53803,
#   'id': 26481,
#   'caption': 'A yellow vespa parked in a lot with other cars.'},
#  {'image_id': 111813,
#   'id': 26505,
#   'caption': 'Three mirrors mounted on a tiled wall with lights.'},
#  {'image_id': 376731,
#   'id': 26513,
#   'caption': 'Asian woman riding her bike downtown  with a little hat on her head '},
#  {'image_id': 140682,
#   'id': 26665,
#   'caption': 'An old bathroom with broken tiles on the wall.'},
#  {'image_id': 133329,
#   'id': 26696,
#   'caption': 'a photo of a bathroom wth lights on'},
#  {'image_id': 458592,
#   'id': 26715,
#   'caption': 'A bathroom with a toilet, sink, and mirror.'},
#  {'image_id': 567797,
#   'id': 26732,
#   'caption': 'A woman with glasses kissing a black and white cat.'},
#  {'image_id': 457667,
#   'id': 26812,
#   'caption': 'a man standing in a bathroom with a sink'},
#  {'image_id': 411690,
#   'id': 26829,
#   'caption': 'A man and a woman waiting with bikes at a crosswalk.'},
#  {'image_id': 237514,
#   'id': 26832,
#   'caption': 'A young hipster couple dressed in fine clothing posing for picture.'},
#  {'image_id': 511031,
#   'id': 26835,
#   'caption': 'A chef preparing something in a big kitchen.'},
#  {'image_id': 276620,
#   'id': 26853,
#   'caption': 'A dining booth having a bold fabric pattern.'},
#  {'image_id': 367951,
#   'id': 26855,
#   'caption': 'A dog sitting on the floor of a bathroom next to the tub'},
#  {'image_id': 167506,
#   'id': 26882,
#   'caption': 'A red stop sign next to a street with a red car driving over it.'},
#  {'image_id': 290410,
#   'id': 26912,
#   'caption': 'White boots and plastic pieces on the bathroom floor.'},
#  {'image_id': 497528,
#   'id': 26918,
#   'caption': "An automatic dishwasher in a kitchen with it's door open."},
#  {'image_id': 317555,
#   'id': 26932,
#   'caption': 'A bathroom with two mirrors and two sinks.  '},
#  {'image_id': 294090,
#   'id': 26961,
#   'caption': 'A bike chained to a parking to a parking meter.'},
#  {'image_id': 483645,
#   'id': 26962,
#   'caption': 'A disorganized kitchen with missing appliances and cabinets.'},
#  {'image_id': 440827,
#   'id': 26973,
#   'caption': 'A large bathroom with a huge mirror, bathtub and toilet.'},
#  {'image_id': 293763,
#   'id': 26977,
#   'caption': 'A small bathroom with a sink and toilet underneath a window.'},
#  {'image_id': 250054,
#   'id': 26982,
#   'caption': 'A bicycle in front of a double-decker bus and Big Ben in London.'},
#  {'image_id': 466800,
#   'id': 26983,
#   'caption': 'A nice bathroom with a standalone shower and a shower curtain.'},
#  {'image_id': 63140,
#   'id': 26994,
#   'caption': 'A man sitting on picnic bench in a field.'},
#  {'image_id': 371654,
#   'id': 27016,
#   'caption': 'A rustic kitchen with condiments set out and copper cookware.'},
#  {'image_id': 313798,
#   'id': 27018,
#   'caption': 'An open washroom with multiple bowls, buckets, and pots.'},
#  {'image_id': 63140,
#   'id': 27024,
#   'caption': 'A man sitting at a picnic table in the grass.'},
#  {'image_id': 511577,
#   'id': 27037,
#   'caption': 'A narrow bathroom with a sink, shower and toilet.\n'},
#  ...]

# %%
def split_file(split):
    return os.path.join('/home/dchesakov/fairseq-image-captioning/splits', f'karpathy_{split}_images.txt')


def read_split_image_ids_and_paths(split):
    split_df = pd.read_csv(split_file(split), sep=' ', header=None)
    return np.array(split_df.iloc[:,1]), np.array(split_df.iloc[:,0])

# %%
image_ids = read_split_image_ids_and_paths('train')[0]

# %%
captions, caption_image_ids = select_captions(annotations, image_ids)

# %%
captions = tokenize_captions(tqdm.tqdm(captions))
# Out:
# 100%|██████████| 566747/566747 [01:12<00:00, 7793.13it/s]

# %%
captions
# Out:
# ['A very clean and well decorated empty bathroom',
#  'A panoramic view of a kitchen and all of its appliances .',
#  'A blue and white bathroom with butterfly themed wall tiles .',
#  'A panoramic photo of a kitchen and dining room',
#  'A graffiti-ed stop sign across the street from a red car',
#  'A vandalized stop sign and a red beetle on the road',
#  'A bathroom with a border of butterflies and blue paint on the walls above it .',
#  'An angled view of a beautifully decorated bathroom .',
#  'The two people are walking down the beach .',
#  'A sink and a toilet inside a small bathroom .',
#  'An empty kitchen with white and black appliances .',
#  'A white square kitchen with tile floor that needs repairs',
#  'The vanity contains two sinks with a towel for each .',
#  'Several metal balls sit in the sand near a group of people .',
#  'Two people carrying surf boards on a beach .',
#  'A kitchen with brown cabinets , tile backsplash , and grey counters .',
#  'A surfer , a woman , and a child walk on the beach .',
#  'A few people sit on a dim transportation system .',
#  'A person , protected from the rain by their umbrella , walks down the road .',
#  'The bathroom with a toilet has an interesting sink .',
#  'Two women preparing food in a kitchen , one at the sink and one at the table',
#  'A white kitchen in a home with the light on .',
#  'A cat stuck in a car with a slightly opened window .',
#  'Two bicycles and a woman walking in front of a shop',
#  'Green tiled backsplash highlighted by low overhead lighting .',
#  'A bicycle is parked by a bench at night .',
#  'A brown horse is grazing grass near a red house .',
#  'A black car is near someone riding a bike .',
#  'White pedestal sink and toilet located in a poorly lit bathroom .',
#  'This is a pick-up game of shirts and skins basketball',
#  'A toilet , sink , bathtub with shower , mirror and cabinet',
#  'A kitchen with a countertop that includes an Apple phone .',
#  'Two teenagers at a white sanded beach with surfboards .',
#  'A surfer riding his bike to the beach .',
#  'Clean indoor bathroom with tiled floor and good lighting .',
#  'A closeup of a red fire hydrant including the chains .',
#  'A man standing in the kitchen with his arms crossed',
#  'A purple bus and a man dressed as a nun on a tall bicycle .',
#  'An herb that is in front of a toaster oven .',
#  'Lady carrying a purse walking along side a man .',
#  'Clean bathroom that is brightly colored and has a window',
#  'A wide angle view of the kitchen work area',
#  'People standing around many silver round balls on the ground .',
#  'A man working at a kitchen counter in a room illuminated by sunlight .',
#  'A man standing in a kitchen with granite countertops .',
#  'A skinny horse is grazing in a field .',
#  'A person on a bicycle is riding in front of a car .',
#  'Seagulls flying overhead while trucks sit in a parking lot .',
#  'A kitchen with a tile floor has cabinets with no doors , a dishwasher , a sink , and a refrigerator .',
#  'A modern bathroom contains many glass and tile pieces',
#  'A demonstration of a well maintained hotel bathroom',
#  'A black cat making an angry face while sitting on the bathroom floor',
#  'A clean , mediocre motel bathroom with a nice sink .',
#  'A kitchen counter is illuminated by a hood light',
#  'A city sidewalk is lined with lamp posts',
#  'A bathroom with a TV near the mirror',
#  'A public restroom toilet has been photographed in sepia',
#  'Photo of a man riding an old styled bicycle near what appears to be the Golden Gate Bridge .',
#  'A cat peeking out a car window that is rolled down',
#  'There is some pet food in the floor in an empty kitchen',
#  'A young boy surfing in low waves .',
#  'The top of a kitchen cabinet covered with brass pots and pans .',
#  'A woman is shaving her face while sitting on a wooden bench .',
#  'The sky is full of colorful kites along a mountain .',
#  'A man rides a bicycle across the river .',
#  'A man and a woman stand on the sidewalk lined with street lights .',
#  'a bathroom with toilet and sink and blue wall',
#  'A bathroom in white has a cupboard above the sink .',
#  'A bike and a raft sit atop a boat on the water .',
#  'a surfer rides his bike down the street',
#  'Bicycles , cars and a trash can in a garage .',
#  'A man in shorts standing at the kitchen sink .',
#  'A cat standing on a car seat looking out the car window .',
#  'A man jumping his bicycle onto a bench .',
#  'young man with folded arms standing in the kitchen',
#  'A man balancing a bike on a bench .',
#  'Black and white image of two children paying attention .',
#  'Silver balls are lined up in the sand as people mill about in the background .',
#  'A compact car with bicycles mounted on the roof .',
#  'Silver balls on sand with people walking around .',
#  'A crisp neutral bathroom embellished with modern treatments .',
#  'A kitchen scene with stainless steel appliance and a checkered pattern floor .',
#  'A lady talking a self portrait in a fancy bathroom .',
#  'A woman walking and talking on a cell phone .',
#  'A modern hotel bathroom with accessories set out .',
#  'A white kitchen without doors on the cabinets .',
#  'A man on top of a snowy mountain with skis .',
#  'A clean restroom with towels and washcloths laid out .',
#  'A man standing in a white kitchen with his arms folded .',
#  'A stuffed animal is laying on the bed by a window .',
#  'A kitchen contains black countertops , brown cabinets , and a red and white tile blacksplash .',
#  'A wooden toilet seat sits open in an empty bathroom .',
#  'A decorated table covered with plates of food and vegetables .',
#  'A couple at the beach walking with their surf boards .',
#  'A bathroom with a sink shower and toilette .',
#  'A phone and a computer on a kitchen counter .',
#  'A person is taking a photo of a cat in a car .',
#  'a picture of a man riding a bicycle at night',
#  'A large hours is eating grass in a field .',
#  'A blurry bike rider zooms past a new Mercedes .',
#  'A group of skiers stand atop a snowy peak .',
#  'Thee cats sleeping on a bed with a person .',
#  'A bathroom sink and cabinet featuring everything white',
#  'A phone lies on the counter in a modern kitchen .',
#  'silver balls laying on the ground around a smaller red ball .',
#  'A man riding a bicycle on a road carrying a surf board .',
#  'A young man playing a game of Frisbee .',
#  'A man is washing dishes in the kitchen sink .',
#  'A man with a backpack rides a bicycle .',
#  'A boy holding his arm around the shoulders of the girl sitting next to him .',
#  'Three cats sleeping with their owners on a bed .',
#  'A man using his bicycle to go down a street .',
#  'A man standing in a kitchen with a baby and dog .',
#  'A clock that blends in with the wall hangs in a bathroom .',
#  'multiple photos of a brown and white kitchen .',
#  'A man extends his hand out to catch a frisbee .',
#  'A set table with silverware , glasses and a bottle of wine .',
#  'A vegetable in front of a toaster oven .',
#  'A kitchen with new age appliances and equipment .',
#  'A large kite in the shape of the bottom half of a woman .',
#  'A bathroom with a toilet and a sink .',
#  'A kitchen with some old fashioned kitchen ware .',
#  'An old man in the middle of his kitchen .',
#  'A group of people playing a game of croquet .',
#  'A small bathroom painted white with an empty shower .',
#  'a man does a trick on a bike on a bench',
#  'A man on a bike carrying a surfboard under his arm .',
#  'A car with a bunch of bicycles strapped to its roof .',
#  'six people on a bus at night time',
#  'A brown horse is grazing in the grass .',
#  'A blurry bicycle riders goes by a black car .',
#  'Bathroom shot of an open toilet and sink .',
#  'a black cat sits next to laundry on the floor',
#  'a white bear laying on a bed with someone &apos;s hand on the other side',
#  'A boy places his arm around a friend .',
#  'A seagull perches on top of a van .',
#  'The parachutes fly through the sky next to each other .',
#  'two girls sitting on a bench eating lunch',
#  'The bathroom counter is stocked with towels and supplies .',
#  'A kitchen sink , counter , pots , and a dog dish .',
#  'A chef opens up an oven in a kitchen .',
#  'a woman standing beside a clean kitchen island',
#  'random people sitting in a public tranport bus .',
#  'A kitchen being prepared to get newly painted .',
#  'A man in a kitchen with his family in a house .',
#  'a black cat sitting next to dirty clothes on the bathroom floor',
#  'Group of skiers atop a mountain looking over edge .',
#  'A person standing in front of a large body of water as the sun sets .',
#  'A woman walks by a couple of shop windows .',
#  'A group of people playing a game of basketball .',
#  'An empty bathroom with a large mirror and sink .',
#  'A man poses for a picture on top of a snowy hill .',
#  'A girl demonstrating the act of shaving sitting on a bench .',
#  'White bathroom with glass shelves and wood sink .',
#  'assorted decorations laying around on a plastic tarp',
#  'A man in a courtyard reaches out to catch a Frisbee .',
#  'A young boy is standing on a surfboard and riding a wave .',
#  'a group of men standing around while one seems angry at the others .',
#  'A set of stairs lead to a toilet and cabinet in a bathroom .',
#  'Double doors open into a bathroom with a footed tub .',
#  'A red stop sign with a Bush bumper sticker under the word stop .',
#  'A toilet sits next to a sink in a bathroom .',
#  'An empty kitchen has walls painted white .',
#  'A buffet of different types of food sitting on a buffet table .',
#  'A clean , organized , kitchen cabinet and countertop area .',
#  'A bathroom with two sinks and a closet .',
#  'A female student is talking on her phone while walking .',
#  'There is a small kitchen with wooden cabinets and pet bowls on the floor .',
#  'There is a clean bathroom counter and sink .',
#  'A kitchen area with a microwave and refrigerator .',
#  'A city sidewalk with storefronts on the right .',
#  'A black cat sits on a bathroom floor next to some laundry .',
#  'A person with a backpack on riding by on a bike .',
#  'A bike on the platform of a public transportation stop at night .',
#  'The silhouette of a person standing in front of a sunset over water .',
#  'A colorful tent is stationed on a bike lane .',
#  'A cat sitting on a bath rug next to a pile of clothes .',
#  'A car with several bikes on a bike rack .',
#  'A person walking outside in the rain with a green umbrella .',
#  'A fire hydrant with chains is painted red .',
#  'Two kitchen stools sitting in front of an island in a kitchen',
#  'A woman takes a selfie in front of a restroom mirror .',
#  'A red fire hydrant wrapped in a red chain on a sidewalk .',
#  'An evergreen sprig is sitting on top of an appliance .',
#  'A brown horse grazes in an open field next to trees .',
#  'A man rides a bike past a black car in a parking lot .',
#  'Two dogs stand in a kitchen beneath their owner .',
#  'A pristine bathroom sits waiting to be used',
#  'A woman smiles at a man who is wearing a colorful sarong .',
#  'Woman riding a bicycle down an empty street .',
#  'A family sits at a table together enjoying each other &apos;s company',
#  'A crowd of skiers prepare to ski down snow covered slopes .',
#  'A family is playing a karaoke video game .',
#  'Many skiiers are gathered at the base of a hill , while several travel down it .',
#  'A guy and a girl are walking on the beach holding surfboards .',
#  'A surfer rides his surf board on some very small waves .',
#  'A young woman walking down the street while talking on her cell phone',
#  'A white van parked out side of a large white building .',
#  'a blue bathroom with a sink and toilet',
#  'A white van sits outside of a white building .',
#  'A girl trusts another girl to shave her while sitting back to back .',
#  'A student walks in the rain with a green umbrella .',
#  'Towels are neatly stacked on a shelf in the bathroom .',
#  'A game of croquet is being played in a back yard .',
#  'A kitchen with copper pots on pot racks and on the stove',
#  'A buffet table at a restaurant , covered with food .',
#  'A white kitchen filled with pots , pans and dishes .',
#  'A man folds his arms in a kitchen .',
#  'A family watches while two boys play a singing game .',
#  'Hikers climb up a snow-covered mountain in the winter .',
#  'Clutter blocks antique cars from leaving the garage',
#  'A woman takes a photo of her reflection in a bathroom mirror .',
#  'Two guys and a girl playing croquet in the yard .',
#  'A white van parked with a seagull standing on top of it .',
#  'One kid has his arm wrapped around the other kid',
#  'A view of a fancy spa like bathroom with a blue tiled tub .',
#  'A bathroom contains a toilet , sink , and bathtub .',
#  'A white bathroom with a walk in closet is shown .',
#  'There are only a few people in the bus .',
#  'Man and woman with group of scissors on table .',
#  'A boat in the water with a raft and a bike loaded at one end of it',
#  'The white bathroom has orange , blue , and gray accents .',
#  'A free-standing bathroom near an open door and table .',
#  'A woman standing behind the island in the kitchen',
#  'A group of people are riding the bus .',
#  'A woman takes her picture in the mirror in the bathroom .',
#  'A restroom with the toilet in the corner .',
#  'A kitchen has red bricks lining the counter .',
#  'A white teddy bear is laying on a bed in a dimly lit room .',
#  'A teddy bear lying face down on a bedspread covered mattress in front of a window',
#  'A young boy is standing on a surfboard in the water .',
#  'A man rides a bike down the street while holding a surfboard .',
#  'Three cats are sleeping on a bed with a person .',
#  'A person holding a surf board on a beach .',
#  'A person is standing in front of the ocean at sunset .',
#  'Loving couple pose together behind a fruit-adorned cake .',
#  'A biker rides through a tent in a bike lane .',
#  'Two stands standing on the floor by their owner &apos;s legs',
#  'A hotel bathroom with stone counter and mirror',
#  'A refrigerator and stove are in a small kitchen area .',
#  'The chain of a red fire hydrant is the focus .',
#  'A shirtless man wearing a pink towel in the kitchen with a woman drinking wine .',
#  'A dark profile of a person set before a sunset on the beach .',
#  'A kitchen with wood cabinets and granite counter tops .',
#  'An individual covers himself under an umbrella on a rainy day .',
#  'The corner of an empty kitchen with cleaning products all over the counter .',
#  'A group of four people playing croquet on a lawn .',
#  'two females sitting on a bench one is being the arms for the other .',
#  'A man stands in the middle of his granite counter-topped kitchen .',
#  'A restaurant kitchen with bowls and pans ready for the night .',
#  'A young man jumping his skate board over a cement seating area .',
#  'An empty bathroom with the toilet seat up .',
#  'A bicycle with a basket is parked at the side of a building',
#  'An empty bathroom painted yellow with an open window .',
#  'A black colored keyboard for a computer system .',
#  'A woman having a slice of bread with jelly .',
#  'A man walking in the rain crossing a street while holding an umbrella .',
#  'A table with towels on top of it placed under a mirror .',
#  'A cat sitting on top of the passenger seat of a car .',
#  'A person is sleeping on the same bed as three cats',
#  'A kitchen counter with chairs , refrigerator , and cupboards .',
#  'A family standing next to the ocean on a sandy beach with a surf board .',
#  'A kitchen sink next to an empty counter with a tiled wall .',
#  'A mid sized bathroom with toilette , shower and vanity mirror above a sink .',
#  'A man leaning forward on a counter top .',
#  'A toilet is equipped with support bars for the disabled .',
#  'A television reflected off a mirror near a counter top .',
#  'Two black cats nap as a white cat lays on a sleeping person &apos;s chest .',
#  'A fire hydrant and the chain attached to it .',
#  'Man riding on a very old version of a personal bicycle .',
#  'Small kitchen in a personal home with dual sinks .',
#  'Man dressed in a wrap in a personal kitchen .',
#  'Two boys with surf boards walking out into the ocean .',
#  'The bathroom door next to the laundry room is open .',
#  'A bathroom sink and counter with a large mirror above it .',
#  'Man standing like a shadow in front of the ocean .',
#  'A small bathroom with a white toilette and bath tub .',
#  'A kitchen with a over stove and toaster oven including a microwave .',
#  'An un occupied bathroom with a shower toilette and sink .',
#  'Through the door view of a small white bathroom .',
#  'Dirty kitchen with cleaning supplies placed allover the counters .',
#  'Silver and white colored personal kitchen with yellow tiling .',
#  'Woman walking down the street past a wig shop .',
#  'A silver car parked in a shopping center parking lot .',
#  'A small bathroom containing a step , toilette and sink .',
#  'A young man rides his bicycle on top of a cement bench .',
#  'A bathroom with a close shower curtain next to a toilette .',
#  'A small dog cradled in his loving owner &apos;s arm as he falls asleep .',
#  'A flat screen TV sits next to a box of tissues and a remote control .',
#  'A nearly empty house with a bicycle mounted on the wall .',
#  'A kitchen with a pets food dishes on the floor .',
#  'College student playing frisbee on a campus lawn .',
#  'A car is parked in a empty parking lot .',
#  'A back splash is added to the wall in the kitchen .',
#  'An a kitchen is being cleaned and decluttered .',
#  'A man has a frisbee in mid air just out of his hand .',
#  'A bathroom under construction with a double sink vanity that has a mirrir and light strip over it',
#  'Single seagull sits on a white van with others flying in background',
#  'A teenage boy is in a field looking at a wire .',
#  'A young boy is standing on a surfboard in the ocean .',
#  'A bicycle leaning against a building near a window .',
#  'A bathroom toilet is surrounded with silver handrails .',
#  'A garage filled with old cards and old bicycles .',
#  'A man in a parade has red and white face and umbrella .',
#  'A woman sitting at a table with win and bread .',
#  'A car is loaded down with many bicycles attached to it &apos;s roof .',
#  'This is a restaurant kitchen with two industrial ovens .',
#  'Skiers are standing at the top of a snow-covered mountain .',
#  'A stop sign that has been vandalized is pictured in front of a parked car .',
#  'A bathroom with toilet and bowl for sink .',
#  'Some antique cars sit in a garage with some bicycles',
#  'A small bathroom has separate tub and shower .',
#  'A man in a pink sarong showing scissors to a woman with wine .',
#  'The boy is inspecting the wire for a project .',
#  'This is a photo of a small hotel bathroom',
#  'Two dogs are laying down next to each other .',
#  'The two banquet tables held a variety of meats , dips , and pastries .',
#  'The shopping plaza has many stores and one parked car .',
#  'A silver sedan is parked in a plaza lot on a cloudy day .',
#  'A picture of a kitchen area with refrigerator and stove .',
#  'A family watches two boys singing into microphones .',
#  'Skiers of all ages skiing down a slope and gathering at the bottom .',
#  'A modern lighted kitchen with stainless steel appliances .',
#  'A kitchen with a refrigerator , oven , and counter .',
#  'A woman making something in a kitchen .',
#  'A woman crossing a city street while carrying groceries .',
#  'A group of bike riders race down a busy street .',
#  'Two young women walking while one is on a cell phone',
#  'Several athletes appear to be having a disagreement .',
#  'A kitchen filled with many cupboards and lots of counter space .',
#  'A white shower curtain with a spiral pattern hanging in the bathroom .',
#  'A person holding a chihuahua sleeping on it &apos;s back in their arm .',
#  'An attractive woman taking a selfie in a bathroom .',
#  'A TV is behind glass in a bathroom .',
#  'A very clean bathroom with the lights on .',
#  'A group of people sitting on a couch while a brown dog looks at them',
#  'An older woman walking a bicycle with a bus in the background .',
#  'A man getting ready to surf as lookers walk by',
#  'A picture of some appliances stove , dishwasher , refridgerator and microwave , in a kitchen .',
#  'A group of friends enjoy a game of croquet on a grassy fenced in field .',
#  'A car has multiple bikes hooked onto it &apos;s roof .',
#  'A young guy checking on a wire as he holds onto a dog leash .',
#  'Two dogs with a woman in the kitchen .',
#  'A man riding a bike down the street at night .',
#  'Three people riding bikes on the side of a road .',
#  'A fridge that is halfway open during the night .',
#  'A man on an old-fashioned bicycle , biking across a bridge .',
#  'A storefront with two bicycles and a woman walking past .',
#  'Sister on her bike trying to race the bus .',
#  'A small kitchen with sink , stove and refrigerator .',
#  'A person riding a very high bike on the road .',
#  'A boy is outside with his dog in a field surrounded by a sign and other items .',
#  'A bathroom with a toilet , sink , and bathtub .',
#  'A very clean kitchen with the light on .',
#  'Shopper crossing a street in the downtown of a city .',
#  'a small strip mall with a few cars in the parking lot',
#  'Kids and their moms are singing karaoke at the table .',
#  'A group of people are skiing on a mountain .',
#  'A master bedroom with a closet and attached bathroom .',
#  'A bathroom featuring an oddly shaped toilette , shower and sink .',
#  'The inside of a bathroom with two sinks .',
#  'A wood bathroom vanity with a granite countertop .',
#  'A young person with red and white face paint holds an umbrella .',
#  'A boy building something with wires and poles .',
#  'A hall opening onto a bathroom , bedroom , and two other rooms .',
#  'A nicely decorated kitchen with metallic refrigerator and blue counter .',
#  'There are two ovens in a kitchen restaurant , and one of them is being used .',
#  'Boy riding skateboard and doing trick in air .',
#  'A large bathroom with two sinks and three windows .',
#  'A view of a communal bathroom with multiple sinks and windows .',
#  'A woman walks her bike past a city bus .',
#  'A hotel bathroom that has technology in the mirror .',
#  'A bed with blue bed spread on it in front of a window .',
#  'A bathroom with a sink , cabinet , mirror and picture .',
#  'A cocker spaniel sitting next to a woman holding a baby .',
#  'A bicycle leans on a bench at a subway stop .',
#  'A man on his skateboard at a basketball court .',
#  'A dog lays on a couch next to a woman holding a baby .',
#  'Clean stainless steel kitchen with large cabinets and counter .',
#  'A white pedestal sink below a white cabinet in a white bathroom .',
#  'The yellow flowers sits atop the counter in a clean bathroom .',
#  'A srfer perches on his board precariously as he hits a big wave .',
#  'A group of friends spending the day watching TV together .',
#  'A bicycle leans against a park bench with a flowering tree nearby .',
#  'Two dogs were captured in a photo with the lighting of the image altered .',
#  'Different types of tiles are on the walls , floor and tub .',
#  'The serving counter of a restaurant is quiet .',
#  'A group of two adults and a child biking down a road .',
#  'A house with a white decorated kitchen .',
#  'A dog is laying next to a woman holding a baby .',
#  'A bathroom mirror with items in front of it .',
#  'Two women prepare a meal in a large kitchen .',
#  'A view of a hallway in a house .',
#  'An empty bathroom featuring a toilette and window .',
#  'A woman stands in the kitchen , surrounded by wood cabinets and stainless steel appliances .',
#  'A large kitchen featuring a counter top and refrigerator .',
#  'A man in a blue shirt and jeans doing a trick on a skateboard .',
#  'Two ovens in use in a professional kitchen .',
#  'A woman in green is riding a bike .',
#  'A clean kitchen with a phone and laptop on the counter .',
#  'A bathroom with a white toilet and a white bath',
#  'A microwave is next to sage or some kind of spice .',
#  'A kitchen filled with dishes and bowls stacked on top of each other .',
#  'A kitchen with a wooden kitchen table and appliances in it .',
#  'A bathroom sink with mirror placed above it .',
#  'A person crossing at a crosswalk with bags in his hands .',
#  'This is a bathroom sink in a hotel',
#  'A kitchen , with sink , stove , and a white cabinet .',
#  'A clean bathroom with sink , toilet and shower .',
#  'A young boy riding a skate board at a public skate park .',
#  'Two adults and a child riding bicycles on the side of a road .',
#  'A spacious bathroom with a fancy bathtub and sink .',
#  'A nun riding a very tallk bike next to a purple bus .',
#  'A person on a bicycle waiting to cross a street at the intersection .',
#  'A kitchen cupboard in a kitchen with a stove and a sink .',
#  'A small bathroom showing the sink and toilet area .',
#  'A person skateboarding on an outside basketball court .',
#  'A woman in a fushia shirt cooking in an industrial kitchen .',
#  'A small wood paneled bathroom with a sink , mirror and toilette .',
#  'A mirror reflecting the opposite wall of a bathroom .',
#  'A bicycle parked in the grass by a tree .',
#  'A black computer keyboard with lcd panel and numeric pad .',
#  'A pink tub and sink in a white bathroom .',
#  'A small bathroom decorated with pretty red flowers .',
#  'An empty bathroom with a sink and mirror next to a toilette .',
#  'A bathroom with a toilet bowl and shower curtain .',
#  'A person holding a small sleeping dog in their arms .',
#  'Kitchen ware sitting behind the counter top at a restaurant .',
#  'A small spotless and clean stainless steel kitchen .',
#  'The overhead view of a tiled bathroom with a tub , shower , toilet , bidet , and sink .',
#  'A kitchen filled with appliances and cupboards green painted walls ..',
#  'A beautiful blonde woman rides a skateboard across a busy street .',
#  'Two children sitting down , one with his arm over the other .',
#  'A multicolored kiosk for cyclists in a city',
#  'A couple and their child riding bikes down an asphalt road .',
#  'A bathroom with two porcelain sinks and hexagonal tiles .',
#  'A lady waking a bike by a bus .',
#  'A man in a yellow coat rides an old-fashioned bicycle',
#  'A wireless keyboard compatible with role playing games .',
#  'A man riding a wave with a surfboard .',
#  'A lady in a large hat riding a bike .',
#  'A bathroom with two sinks a bathtub and a shower with lots of lighting from the windows',
#  'A black car traveling past parked cars on a tree filled street .',
#  'An open refrigerator in a kitchen next to a cupboard .',
#  'A man wearing plate armor and metal helmet while talking on a cell phone .',
#  'An indoor bathroom with reflective marble counter tops',
#  'A bicycle parked up against a rust covered filthy alley wall .',
#  'A kitchen filled with appliances next to a hard wood floor .',
#  'A man on a bike waiting at a crosswalk .',
#  'A man waits at the crosswalk with his bicycle .',
#  'A dirty kitchen that looks to be under construction .',
#  'A bathroom decorated with white frilly towels and accessories .',
#  'A family carrying a surfboard to the ocean .',
#  'A young man riding his skate board up a ramp .',
#  'An Asian man dressed in armor talking on a cell phone .',
#  'A bicycle leaning up against a park bench .',
#  'Women walk by a person sitting on a public bench with a dog .',
#  'Four friends lounge on a couch with a dog .',
#  'A man with baskets of goods stands next to his bicycle .',
#  'A bathroom with tile floors and a walk in shower .',
#  'A selfie of a young woman in her bathroom .',
#  'An older gentleman holding his hat standing alongside a car .',
#  'A bathroom with a shower and his and her sinks .',
#  'A stainless Steele kitchen with sinks and lots of storage .',
#  'A skateboarder is airborne as he does a trick .',
#  'A man holds a banana as if it were a telephone receiver .',
#  'A bathroom that is very clean and nice .',
#  'A skateboarder that is doing a trick on a ramp .',
#  'Colorful tent on a street is a stop for bicyclists .',
#  'A man preparing food in a kitchen underneath a clock .',
#  'An empty bathroom with a sink and toilette underneath a hand drying towel .',
#  'A couple of people prepare food while working in a kitchen .',
#  'A street sign modified to read stop bush .',
#  'Young woman in white dress brushing teeth over bathroom sink .',
#  'The restaurant kitchen is highly lit , displaying the colorful bowls .',
#  'A bicycle parked next to a bench in a train station .',
#  'A bathroom with a bathtub and a door made out of glass .',
#  'an open kitchen and living room in a daylit house',
#  'A female is brushing their teeth using a toothbrush .',
#  'There is a hallway leading to a door where bicycle tires are showing .',
#  'A bathroom scene with open double doors , double sinks and a bathtub .',
#  'A man examines his reflection in the bathroom mirror .',
#  'A bathroom with an over the toilet cabinet .',
#  'A view of a mirror in a bathroom .',
#  'A clean bathroom toilet , shower , and sink with a tiled floor .',
#  'Surfers waiting for the right wave to ride .',
#  'A group of people waiting to get off the ferry on vespas .',
#  'A bathroom vanity with towels folded under the sink .',
#  'a large kitchen decorated with white flowers and books',
#  'A young family is biking in the bike lane of a road .',
#  'A person sitting in a chair holding a baby and a dog .',
#  'A tiled bathroom vanity with a small mirror .',
#  'A couple of people sitting on the ground in a house .',
#  'A bike and a bench on the side of a street .',
#  'Several bicycles parked outside of a corner store .',
#  'A doll holds a cup of coffee and brushes her teeth .',
#  'A very clean kitchen with some animal food on the ground .',
#  'A bathroom that is very clean showing a door .',
#  'Two woman standing in a kitchen preparing food .',
#  'A restaurant kitchen stocked with stainless steel appliances .',
#  'A group of bikers round a turn on a road .',
#  'A picture of a sink top with dim lighting .',
#  'A fountain in the middle of town , with places to sit nearby .',
#  'A bicycle parked against the side of a stone house .',
#  'A bicyclist and cars wait at a busy intersection .',
#  'Light shines into a bathroom with toilet and shower .',
#  'A computer keyboard , with black keys and white lettering .',
#  'Cyclists competing in a race round a corner .',
#  'A bathroom toilet next to a window with a handicap bar next to it and a cabinet over it',
#  'two women working in a large kitchen with natural lighting',
#  'A very clean bathroom is shown with wood cabinets .',
#  'A fridge door is open in a kitchen at night .',
#  'A pedestal sink with vanity sits below a mirror .',
#  'Looking from a kitchen area out into a living area .',
#  'A small bathroom with a glass fronted shower tub combo',
#  'A shower in a bathroom with a glass door',
#  'Two dogs sitting one the ground looking at something .',
#  'A peleton of cyclists leaning into a turn',
#  'A woman passing a store front wearing a long blue coat',
#  'A bicycle leans on a bench in a park .',
#  'A person on a bicycle at a cross walk',
#  'A dog sits staring at a group of people .',
#  'A bathroom is lit by a light over a sink .',
#  'A picture of a kitchen that is very clean .',
#  'An open stove oven has an open umbrella facing it',
#  'A man in a knight costume on a cell phone .',
#  'A light is on in an empty , clean bathroom .',
#  'A person on a motorcycle driving on the road .',
#  'A bathroom with a toilet and a shower .',
#  'A boy doing a skate-board trick on a ramp .',
#  'A man riding a bike carrying a large stack of beverages',
#  'A small bathroom with a small standup shower',
#  'An older white male standing in front a dump truck and beside a car',
#  'A person in a commercial kitchen preparing food .',
#  'Three mirrors with lights inside of a room .',
#  'A tiled bathroom with toothbrushes and shaving accessories .',
#  'A woman walks her bicycle near a bus .',
#  'A view from a kitchen of a sink and some windows .',
#  'a small building next to a pole and many power lines',
#  'Multiple cyclists riding their bikes on the street .',
#  'A table surrounded by a set of seats .',
#  'An older woman preparing to blow out the candle on her birthday cake standing besides an older man',
#  'Soccer fan is showing his support by dressing up .',
#  'a man in japanese armor talking on a cell phone',
#  'A nicely displayed bathroom sink in a hotel .',
#  'A married couple posing in front of a piece of birthday cake .',
#  'a cat standing on the edge of the toilet bowl',
#  'A picture of a white kitchen with all appliances .',
#  'A bathroom dimly lit with a bathtub and a shower',
#  'A young man performing a trick on a skateboard ,',
#  'A bicycle leaning against an old white building .',
#  'A woman walking a bike , while a bus passes by .',
#  'an open refrigerator with a shinning bright light',
#  'a bathroom with the door open and a tub',
#  'this is the kitchen and entryway of a house',
#  'A photo on a kitchen floor with a person &apos;s legs and two dogs .',
#  'A man is riding on a yellow motorcycle .',
#  'A boy is doing tricks on his skateboard .',
#  'An empty and very clean white and tan kitchen .',
#  'Large modern bathroom with jacuzzi in a house .',
#  'a woman wearing a bright green sweater riding a bicycle',
#  'a bathroom with a toilet , sink and a mirror',
#  'A house hallway with all the bedroom doors open .',
#  'A city street scene with cars and a person crossing the street .',
#  'There is an Asian inspired bathroom with double doors .',
#  'A bathroom with dual sinks and a stand alone shower .',
#  'a bathroom with a mirorror and a sink with a large counter',
#  'A bicycle locked up on a parking meter .',
#  'A surfer catches a wave but is about to fall off his board',
#  'A car is stopped in front of downed trees on the street .',
#  'A kitchen with a lot of clutter on the countertop .',
#  'Man standing at his bike full of drink products .',
#  'Scene of a bathroom up close shower and toilet .',
#  'A bathroom with a toilet and hanging towels .',
#  'A woman with a dog on a leash , a bike , and a fancy outfit .',
#  'A skateboarder on a wooden ramp in the middle of the street .',
#  'A small with white appliances , cupboards and floor .',
#  'A kitchen with a cutout into the living area .',
#  'A bathroom with a bathtub , toilet and vanity sink .',
#  'A bathroom with white sheer toilet covers and curtains .',
#  'A person dressing in a warrior costume on a cell phone .',
#  'A bathroom with a shower and a sink .',
#  'three people in a kitchen preparing a meal',
#  'A man is surfing on some small ocean waves .',
#  'A man skiis down a hill as snow falls .',
#  'A hotel room bathroom sink and tissue dispenser .',
#  'A man with a painted red and white face is standing in the street .',
#  'A bathroom with wooden wall panelling and white sink and toilet .',
#  'Two women cooking in a small kitchen with a fire .',
#  'A modern bathtub in a bathroom is displayed .',
#  'unused kitchen stove , sink and counter topsand cabinettes',
#  '2 women sitting on a floor in a ceramic house preparing dinner .',
#  'A bunch of umbrella covered tables with people sitting there .',
#  'The tiny bathroom contains a small sink and toilet .',
#  'A little boy is reaching for the silverware drawer .',
#  'A biker and a skateboarder ride across the road in front of cars .',
#  'Toothbrushes are arranged in a cup on the bathroom counter .',
#  'A display of many prepared food dishes arranged decoratively on serving table .',
#  'Two dogs are resting together on the floor .',
#  'A white bathroom with a matching pink sink and bathing tub .',
#  'A small hot pink bathroom with a few touches of royal blue on the toilet is shown .',
#  'Two large refrigerators and long workstation indicate a commercial kitchen .',
#  'A man is looking in the bathroom mirror .',
#  'The bathroom has a shower area , toilet and sink .',
#  'Three lighted doors have gold rectangular lights above them .',
#  'A little boy putting silverware away in a drawer .',
#  'A man sitting on a park bench after a bike ride .',
#  'The toilet is next to a curtained window .',
#  'A man is standing with his hat in his hand next to a car',
#  'A store on a corner with Asian writing has many bicycles parked in front .',
#  'A kitchen with a double sink looks out into a living area with windows .',
#  'A red bicycle locked to a parking meter .',
#  'Man pretending to talk into a banana as though it were a telephone .',
#  'A black sports car driving through an intersection .',
#  'A woman brushing her teeth in front of a mirror .',
#  'A man is crossing a city intersection carrying bags .',
#  'Women sitting on a bench with a dog and a blue bike .',
#  'A woman on a bicycle is going down the small town street .',
#  'A man and woman smiling in front of a cake .',
#  'A wide angle view of a kitchen with two women working .',
#  'A bicycle is parked up against a white stucco building .',
#  'A bathroom has walls made of wooden planks .',
#  'A group of women stand around in the kitchen .',
#  'A bathroom has a glass door on the shower and tub .',
#  'A man and woman celebrating a special occasion , about to blow out a candle .',
#  'A woman has a cat pressed up to her lips .',
#  'A container holding several different color toothbrushes in front of blue tile',
#  'A fresh airy white and pink clean bathroom .',
#  'Two doge have their paws out in an overexposed picture .',
#  'A modern kitchen in a new apartment with sparse furniture and moving boxes .',
#  'An older man standing next to an old fashioned car .',
#  'A bathroom counter has purple orchids on it .',
#  'Guys on their way to surfboard at the beach',
#  'A woman sitting on a bench with her bike and dog .',
#  'An empty bathroom with a very clean sink .',
#  'Small bathroom consisting of a tub with curtain and a toilet .',
#  'A bathroom has a green and white striped shower curtain .',
#  'A child putting away utensils from the dishwasher .',
#  'A white bathroom has a pink tub and sink .',
#  'A shiny bathroom has an old fashioned bathtub and gold walls .',
#  'The bathroom has a wall-to-wall double sink with wood vanity and a shower stall .',
#  'Appliances and a carton of half and half are sitting on a kitchen counter .',
#  'Several people wearing skis are traveling up the mountain on a ski lift .',
#  'A white bathroom with a tan toilet and a hand rail',
#  'A man is on a yellow motorcycle at night with the background scene blurred .',
#  'A boat has a raft and a bicycle on it .',
#  'A lone skier working their way through the snow',
#  'A skateboarder has one end of the board in the air on top of a bench .',
#  'A girl with glasses is holding a teddy bear in the kitchen .',
#  'A group of skiers some in costume in the snow .',
#  'A white tiled bathroom in a home .',
#  'Curtains hanging in a bathroom window beside a toilet .',
#  'Skiers are all bundled up , one person is wearing a cow suit .',
#  'A girl brushing her teeth in the bathroom mirror .',
#  'Man holding his hat standing next to a car .',
#  'A person working alone in a large kitchen .',
#  'A man sitting on a park bench looking towards a fountain and sculpture .',
#  'A lady sitting on a bench next to a bicycle holds the leash to a dog .',
#  'People with surf boards going into the ocean .',
#  'A woman is taking a picture of herself in the bathroom .',
#  'Person on skateboard at the top of ramp .',
#  'A Mr. Coffee coffeemaker sits on a countertop with some other appliances and dishes .',
#  'An old couple cooking food in a kitchen .',
#  'Bathroom pictures are seen decorated with frilly accessories .',
#  'An elegant bathroom with two sink and mirror sets .',
#  'Several cars approach a cone barrier on a suburban street .',
#  'A large kitchen cabinet or pantry in a small kitchen .',
#  'A door leading to a bathroom with a sink visible .',
#  'A small bathroom has been very neatly organized',
#  'People from a formal affair are eating at the buffet .',
#  'A bike rider is locking his bike to a road sign .',
#  'Four people sitting on a ski lift going up a snowy mountain .',
#  'Two women sitting inside a hut cooking and preparing food .',
#  'A teenage girl on a skateboard glides down an urban street following a cyclist .',
#  'A man on a bicycle performing tricks on a bench .',
#  'this is an image of a bathroom which is empty',
#  'A small bathroom has four identical wooden walls',
#  'A view of a bathroom including a shower , toilet and sink .',
#  'A toilet and a shower tub with a blue bath mat .',
#  'A bathroom with a shower curtain tucked into the bathtub .',
#  'A girl sits by herself working on a small laptop',
#  'A young woman riding a skateboard down the road .',
#  'A store with Asian signs with bicycles parked outside',
#  'An antique kitchen with a table , sink , stove and a fridge .',
#  'A white toilet and bathtub in a narrow bathroom .',
#  'Five people , all dressed in costumes , wearing skis on a mountain .',
#  'A small bathroom has been fitted in a wood motif',
#  'A clean kitchen that is empty and white .',
#  'A building with a foreign sign has numerous bicycles parked in front',
#  'A brown and orange towel hanging in the bathroom .',
#  'A level laying across a white sink in a white room .',
#  'Two women in a hut preparing a meal .',
#  'A kitchen counter with various appliances on it .',
#  'In the bathroom there is a shower , sink , and toilet .',
#  'Small dog sitting in middle of bathroom floor next to tub .',
#  'A vanity and sink next to a window in a home .',
#  'A woman kisses and hugs her Siamese cat .',
#  'The yellow motorcycle is carrying only one rider .',
#  'A girl swings a hula hoop around her legs',
#  'The front of a boat with a raft and bicycle on it .',
#  'A small bathroom has a small sink and window',
#  'A woman sitting a table on a laptop .',
#  'Guy reading with a dog on his lap .',
#  'A dairy queen sign alongside a road with cars going by .',
#  'Two cooks talking in the kitchen of a restuarant .',
#  'A gathering of people in a kitchen chatting .',
#  'People on scooters are parked and viewing something .',
#  'People dressed for a special occasion gather around a large kitchen island .',
#  'A cyclist giving the &quot; thumbs up &quot; poses with his bicycle by a right of way sign at a park .',
#  'In a small bathroom , the toilet is beside the sink',
#  'An unfurnished kitchen in a tropical house hold .',
#  'A three sink bathroom with a mirror and a window .',
#  'A bathroom with wooden floors and a white tub .',
#  'A group of people ride up a ski lift together',
#  'A fountain with a sculpture in the middle .',
#  'A kitchen under renovation with all the shelves exposed .',
#  'A bike next to a fence on a city street .',
#  'A kitchen has a wooden table and capinets .',
#  'A nice bathroom has a clean counter with makeup toothbrushes .',
#  'A kitchen has an open cabinet on the side .',
#  'Objects on a kitchen counter including a coffee pot and blender .',
#  'A street is blocked off with green tape .',
#  'A woman with a cold drink is staring at a laptop .',
#  'A red bike locked up next to a a pay meter .',
#  'A purple bicycle attached to a parking meter .',
#  'People on a boat crossing a body of water',
#  'An assortment of vegetables sitting on the kitchen counter .',
#  'A car driving along a street in the daytime .',
#  'A bathroom window reveals a snowy day outside .',
#  'The man stares at his reflection in the mirror .',
#  'A bathroom has a large shower curtain with design .',
#  'A little dog is laying on a man &apos;s arm .',
#  'A bathroom with a blue shower curtain over the bathtub .',
#  'A man sitting on a park bench next to a bicycle .',
#  'Table top booth sitting area in a home kitchen .',
#  'A group is gathered around a kitchen island .',
#  'A man is next to a bicycle and bike path signs .',
#  'Lower door of refrigerator open in dark kitchen .',
#  'A white bathroom with orange and brown towels hanging .',
#  'A kitchen with a microwave , refrigerator , and sink',
#  'A group of people well dressed standing around a kitchen with lots of food .',
#  'A man standing next to a bicycle under a sign that reads &quot; Bicycles have right of way &quot; .',
#  'The cats are in the bathroom with one inside the sink and the other at the edge of the bathtub .',
#  'A toilet bowl with a handicap rail next to it .',
#  'A sink is shown in front of a window .',
#  'A very attractive young woman turning on the water in the shower .',
#  'A black dog sitting in the middle of a bathroom .',
#  'a man carting goods through a city on his bike .',
#  'A bathroom with a toilet and a shower .',
#  'A man holding a banana to his ear like a telephone .',
#  'A handsome man stands in front of the bathroom mirror and smirks .',
#  'A small boat with a raft and bike strapped to it in a body of water .',
#  'Boyfriend and girlfriend riding bikes through the city .',
#  'A Kitchen with a Refrigerator Stove and table',
#  'A bicycle sitting on a ledge near a building .',
#  'A closed shower curtain in a tiled bathroom .',
#  'A small dog taking a nap on the arm of a person .',
#  'A view of a kitchen with vegetables on the counter and a white fridge .',
#  'A man takes a picture of a woman turning on the shower .',
#  'A car is shown next to other cars .',
#  'A young toddler opening a drawer to reach for a utensil .',
#  'A man is on a bicycle loaded down with items .',
#  'The bathroom has towels hanging in the corner .',
#  'A bicycle parked on the side walk while a double decker bus passes by near Big Ben .',
#  'The sunlight is shining brightly in the bathroom',
#  'A chef is cooking in a large kitchen with pans overhead .',
#  'A kitchen sink with a cut out above it .',
#  'A white kitchen has green and lime accents .',
#  'Two people stand and talk in a kitchen .',
#  'A man sits on a bench with a dog in lap reading .',
#  'A close up of toothbrushes and lotion in a bathroom .',
#  'A large bathroom with a sink underneath a window .',
#  'An orange tiled bathroom with colorful accents of orange all over .',
#  'An adorable woman holding a brown teddy bear in her hands .',
#  'A woman with a sun hat riding a bicycle .',
#  'A group of people riding up a snow covered ski slope on a ski lift .',
#  '5 toothbrushes in a holder in the bathroom .',
#  'A cat standing on the toilet bowl rim .',
#  'Multiple tooth brushes sitting on the counter next to a bathroom sink .',
#  'shiny fancy black car driving on a street .',
#  'A WOMAN RIDING A BICYCLE UNDER AN UMBRELLA .',
#  'The corner of a kitchen showing a dishwasher , sink and household items .',
#  'The bottom drawer of a dishwasher that is open .',
#  'A man reading a newspaper while on a train next to bicycles .',
#  'A man falling back on a bed in a bedroom .',
#  'A single serve coffee maker sitting on a counter next to a blender .',
#  'A group of surfers wade into the sea .',
#  'Chefs preparing food in a kitchen side by side .',
#  'People sitting under table umbrellas beside a fountain .',
#  'A man riding a yellow motorcycle down a street a night .',
#  'A small restroom with a toilette and kitchen sink .',
#  'A cross country skier pushes on through the snow .',
#  'A young child getting utensils from a drawer .',
#  'A clean bathroom with a big glass shower door .',
#  'A bathroom showing a sink and shower stall .',
#  'A small sink in a room that &apos;s being remodled .',
#  'Three towels hanging in the bathroom above the toilet .',
#  'A room with damaged walls and sink with two areas',
#  'A bathroom sink next to a very large mirror .',
#  'A dirty looking bathroom with bad lighting and a window',
#  'Earth toned towels hang on a rod in a stark bathroom .',
#  'A girl testing out the water in a shower with a man taking a pic in the mirror',
#  'A bicycle with wagon propped against a building .',
#  'A his and hers bathroom sink with a lighted mirror .',
#  'A bathroom with orange as an accent color .',
#  'A well-appointed kitchen includes ample seating and modern appliances .',
#  'A large pool of water with a flower shaped ornament in the center .',
#  'A sink built under a window in the bathroom area .',
#  'A long haired cat sleeps on the hood of a car .',
#  'A restroom with multiple sinks and a wide open window .',
#  'A picture of bathroom lighting fixtures above mirrors .',
#  'A woman cutting a fourth of july cake next to a friend .',
#  'A recently renovated kitchen done in earth tones .',
#  'A ladle of soup being placed into a bowl .',
#  'A nice but stark bathroom with a skylight is pictured .',
#  'A stop sign with street labels on top of it .',
#  'A girl sitting at an outdoor cafe using her laptop',
#  'A bathroom that is primarily white and gray .',
#  'A train &apos;s bathroom with a sink and a toilet .',
#  'A black and white photo of two urinals .',
#  'A minimalist bathroom with toilet paper that needs to be cleaned .',
#  'A woman taking a selfie in a bathroom',
#  '5 adults strangely dressed about to snow ski',
#  'A pair of white urinals with white tile and white walls .',
#  'Cats standing in and next to a restroom sink .',
#  'A kitchen that is being remodeled with cabinet doors off',
#  'The front view of a full kitchen area .',
#  'An antique bathtub in a house about to be renovated or demolished .',
#  'A Dairy Queen sign on a major road advertising it &apos;s special .',
#  'A woman is photographed turning on the shower faucet .',
#  'A stop sign is topped by street signs on a residential street .',
#  'A man with his head stuck in a T.V. made of cardboard .',
#  'A group of people sanding around a kitchen having conversation .',
#  'A shelf of various cooking things inside a small kitchen .',
#  'A rusty old tub sits in a bathroom .',
#  'A man and a woman pausing at a crosswalk on their bicycles .',
#  'Two pictures of an orange and white bathroom with toilet , shower stall , and counter / sink area .',
#  'A kitchen is being used to cook for a family dinner .',
#  'A kitchen scene with a dining room table and chairs .',
#  'A bathroom scene looking at the sink and mirror .',
#  'A group of four people on a ski lift looking back at the camera .',
#  'A run down bathroom with three dingy sinks .',
#  'A man sits at a park with his bike .',
#  'A white bathroom with granite countertops and white tile flooring .',
#  'A kitchen with wooden drawers , table , chairs and stone counter tops .',
#  'A white background with white counter top and white walls .',
#  'Two urinals side by side in a bathroom .',
#  'A camera and flash setup to take a pic of the inside of a oven .',
#  'A bicycle parked against a dirty wall on a ledge',
#  'wood panaled bathroom with sink , mirror and a toilet',
#  'A group of well dressed people standing around a counter holding food .',
#  'A man with a bike posing by two street signs .',
#  'a double basin sing in the corner of a room',
#  'A bathroom features white tiles and countertops with red accents including floor tiles , a toilet seat and towel racks .',
#  'A street that has been blocked off and a tree is down , covering the street .',
#  'A bathroom is heavily decorated with lacy cloths .',
#  'A bathroom with a sink and red curtains',
#  'A bicycle is parked by a bench overlooking the ocean .',
#  'Sun shines through the window in a darkened bathroom .',
#  'A cat watches another cat sit in a sink',
#  'There is a bicycle leaning against a bench on a pier .',
#  'A man is sitting on a one wheeled bicycle next to a smoothie .',
#  'A young man standing in front of a bathroom sink with a mirror .',
#  'A kitchen filled with appliances and lots of clutter .',
#  'A skateboarder coming airborne while riding a skateboard .',
#  'A man and woman posing all dressed up .',
#  'A shiny black car makes its way down a street .',
#  'A white tile bathroom with blue walls and no mirror .',
#  'The whole view of a full bathroom .',
#  'A bathroom with a toilette , sink and bathtub .',
#  'A bathroom with a shower sink and windows .',
#  'A man holding a banana to his ear like a phone .',
#  'A cat standing on a tiled floor next to an orange container .',
#  'A bathroom with , blue shower curtains , a toilet , and sink .',
#  'A couple standing in front of a stone wall holding each other .',
#  'A woman standing in a bathroom by a shower .',
#  'two people standing in an industrial kitchen talking .',
#  'A man brushing his teeth with a dinosaur head in front of a bathroom mirror .',
#  'A guy standing in a bathroom with his hands in his pockets .',
#  'Two men &apos;s bathroom urinals side by side on a tiled floor .',
#  'Three people in a kitchen with the counter cluttered .',
#  'A bike with a basket leans against a rusty wall .',
#  'A woman riding a bicycle in front of a mountain while holding an umbrella .',
#  'A young man looking into a cracked mirror in a bathroom with a whole behind him .',
#  'A kitchen with a dining room and tables .',
#  'A beautiful young woman standing next to a man with her bicycle',
#  'A very small kitchen separated from the next room by a shelf',
#  'A vespa park next to a bicycle on the street',
#  'A man with his through a fake tv .',
#  'a bicycle leaning against a fence with a bus in the background',
#  'A young woman holding an old teddy bear',
#  'A man standing in at a sink looking in the mirror .',
#  'a photo of a well lit country style kitchen',
#  'Two picture of different sides of a bathroom .',
#  'The bathroom is not clean and is ill attended .',
#  'A London double decker bus behind a bike',
#  'A woman holding a teddy bear by a table',
#  'A small standing shower next to a sink and vanity',
#  'a bathroom with a shower toilet and sink',
#  'Patterned cushions adorn a banquette around a table .',
#  'Three sinks in a bathroom of an old building .',
#  'A Dairy Queen Sign near a street filled with gas stations and stores',
#  'A bike parked on the side of a building in the snow .',
#  'A very narrow and dimly lit bathroom picture .',
#  'A cat is standing on a toilet in the bathroom .',
#  'A girl in a pink shirt is riding a skateboard across an intersection .',
#  'Two employees standing behind the counter of a diner',
#  'A family preparing a meal by doing various tasks .',
#  'Bathroom with shower , toilet and sink and vanity view .',
#  'A person and bikes on a mass transit vehicle .',
#  'A man in the air above a bed in a bedroom .',
#  'An oddly shaped toilet and urinal in a public restroom .',
#  'A white bathroom sink with a toothbrush and orange on it .',
#  'A stop sign at a residential street intersection .',
#  'A woman walking her dog on a leash next to a blue storefront .',
#  'A person hula hooping while holding a frisbee',
#  'A fluffy cat resting comfortably on a blue chair',
#  'A table in a kitchen full of ingredients .',
#  'People preparing food surrounded by many bowls , buckets and baskets .',
#  'A clean bathroom with his and hers sinks .',
#  'A group of people cooking in a kitchen .',
#  'The inside of a bathroom with a toilet and a sink .',
#  'A woman sitting at a sidewalk cafe working on her laptop and having a drink .',
#  'Two chefs in a kitchen garnishing a couple plates .',
#  'A stark white bathroom with a toilet bowl and tub',
#  'A bathroom with a sliding shower door next to a toilet and sink .',
#  'Two chefs in a kitchen preparing fresh food .',
#  'A kitchen with a large window and sink .',
#  'a dairy queen drive thru sign with a sky background',
#  'A bicycle pulling a trailer in the snow leaning against a brick building .',
#  'A strange pink bathroom with toilet and sink',
#  'A bathroom with a double sink and large mirror .',
#  'A fluffy cat sleeping on the hood of a car .',
#  'a man holding a banana as if it were a phone',
#  'A person sitting on a park bench with their dog .',
#  'Two ladies talking in the kitchen area of a restaurant .',
#  'A man and a women dressed up posing for a picture .',
#  'a kitchen with wooden furniture and many items on the table',
#  'a kitchen area with many pots and containers',
#  'A man leaning against a stove in a kitchen .',
#  'a bicycle with a basket on the wall of a building',
#  'A collection of pictures showing the before and after of a bathroom remodel',
#  'The side view of the entrance to a bathroom .',
#  'Two women walking on a sidewalk past a bench where a man sits with his dog .',
#  'A compact kitchen set-up with shelves for storage and a small stove .',
#  'a cat in a bathroom standing on a toilet',
#  'A white bathroom with a stand-up shower and wood sink .',
#  'A new kitchen sink being remodeled and leveled',
#  'a person serving them self a bowl of soup',
#  'A white toilet and sink in a white tiled bathroom .',
#  'His and hers bathroom sink with the lights turn on by mirror .',
#  'A cook dishes a stew from a pan onto a plate .',
#  'two white robes hanging in a large bathroom',
#  'A man is in the park with a hula hoop .',
#  'A restroom with a black seat on the toilet next to a piles of shoes .',
#  'A bathroom with a white toilet an d claw foot tub .',
#  'a kitchen with a table and chairs and various kitchen appliances',
#  'a bathroom with a sink and a mirror',
#  'A bathroom counter with toiletries arranged on top .',
#  'A kitchen in a state of construction without cabinet doors',
#  'A toilet and a tub in a bathroom .',
#  'A man with a black hat is leaning against a stove .',
#  'a yellow colored kitchen with a silver refrigerator and dishwasher',
#  'A modern restroom that has an open shower with an opaque glass wall .',
#  'A woman with a pointed hat riding a bicycle .',
#  'Traffic driving by a very tall building in a downtown area .',
#  'An old style bathroom sink with a toothbrush and orange on it .',
#  'A couple dressed up and posing for a picture .',
#  'A kitchen scene with the photo focused on the floor .',
#  'The United States Postal Service delivers mail regardless of the weather , in this case , deep snow .',
#  'A mail truck driving down a snowy road .',
#  'A very unpleasant looking bathroom with a urinal and commode',
#  'A yellow vespa parked in a lot with other cars .',
#  'Three mirrors mounted on a tiled wall with lights .',
#  'Asian woman riding her bike downtown with a little hat on her head',
#  'An old bathroom with broken tiles on the wall .',
#  'a photo of a bathroom wth lights on',
#  'A bathroom with a toilet , sink , and mirror .',
#  'A woman with glasses kissing a black and white cat .',
#  'a man standing in a bathroom with a sink',
#  'A man and a woman waiting with bikes at a crosswalk .',
#  'A young hipster couple dressed in fine clothing posing for picture .',
#  'A chef preparing something in a big kitchen .',
#  'A dining booth having a bold fabric pattern .',
#  'A dog sitting on the floor of a bathroom next to the tub',
#  'A red stop sign next to a street with a red car driving over it .',
#  'White boots and plastic pieces on the bathroom floor .',
#  'An automatic dishwasher in a kitchen with it &apos;s door open .',
#  'A bathroom with two mirrors and two sinks .',
#  'A bike chained to a parking to a parking meter .',
#  'A disorganized kitchen with missing appliances and cabinets .',
#  'A large bathroom with a huge mirror , bathtub and toilet .',
#  'A small bathroom with a sink and toilet underneath a window .',
#  'A bicycle in front of a double-decker bus and Big Ben in London .',
#  'A nice bathroom with a standalone shower and a shower curtain .',
#  'A man sitting on picnic bench in a field .',
#  'A rustic kitchen with condiments set out and copper cookware .',
#  'An open washroom with multiple bowls , buckets , and pots .',
#  'A man sitting at a picnic table in the grass .',
#  'A narrow bathroom with a sink , shower and toilet .',
#  ...]

# %%
import argparse
import os
import torch
import tqdm
import numpy as np
import pandas as pd

import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="3"

from torchvision import transforms

from data import ImageDataset
from model.inception import inception_v3_base

# %%
def split_file(split):
    return os.path.join('/home/dchesakov/fairseq-image-captioning/splits', f'mysplit_{split}_images.txt')


def read_split_image_ids_and_paths(split):
    split_df = pd.read_csv(split_file(split), sep=' ', header=None)
    return np.array(split_df.iloc[:,1]), np.array(split_df.iloc[:,0])

# %%
def main(args):
    image_ids, image_paths = read_split_image_ids_and_paths(args.split)
    image_paths = [image_path for image_path in image_paths]
    features_dir = os.path.join('/home/dchesakov/fairseq-image-captioning/output_cxr', f'{args.split}-features-grid-cxr')

    os.makedirs(features_dir, exist_ok=True)

    inception = inception_v3_base(pretrained=True)
    inception.eval()
    inception.to(args.device)

    transform = transforms.Compose([
        transforms.Resize((299, 299)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    dataset = ImageDataset(image_ids, image_paths, transform=transform)
    loader = torch.utils.data.DataLoader(dataset,
                                         batch_size=args.batch_size,
                                         num_workers=args.num_workers,
                                         pin_memory=args.device.type == 'cuda',
                                         shuffle=False)

    with torch.no_grad():
        for imgs, ids in tqdm.tqdm(loader):
            outs = inception(imgs.to(args.device)).permute(0, 2, 3, 1).view(-1, 64, 2048)
            for out, id in zip(outs, ids):
                out = out.cpu().numpy()
                id = str(id.item())
                np.save(os.path.join(features_dir, id), out)

# %%
image_ids, image_paths = read_split_image_ids_and_paths('train')
image_paths = [image_path for image_path in image_paths]
# features_dir = os.path.join('/home/dchesakov/fairseq-image-captioning/output_cxr', f'{args.split}-features-grid-cxr')

# os.makedirs(features_dir, exist_ok=True)

inception = inception_v3_base(pretrained=True)
inception.eval()
inception.to('cuda')

transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
dataset = ImageDataset(image_ids, image_paths, transform=transform)

# %%
loader = torch.utils.data.DataLoader(dataset,
                                     batch_size=8,
                                     num_workers=2,
                                     pin_memory=True,
                                     shuffle=False)

# %%
for imgs, ids in tqdm.tqdm(loader):
    pass
# Out:
# 100%|██████████| 836/836 [00:44<00:00, 18.69it/s]
